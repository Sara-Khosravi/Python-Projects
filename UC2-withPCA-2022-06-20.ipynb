# %% [markdown]
# ###############################################################################################################################
#
# ## Predicting Root Cause by Implementing Supervised Mechine Learning Classifier

# %% [markdown]
#  ---------------------------
#
#
# ------------------------------------
#
# ###############################################################################################################################

# %% [markdown]
# #### ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Introduction
# ###############################################################################################################################

# %% [markdown]
# ### 1.1. Problem Statement

# %% [raw]
# Data Gathering
# Data proccessing and cleaning the data
# feature engineering
# feature scaling
# choosing model
# Modeling evaluation & Tunning
# Deployment & Monitoring

# %% [raw]
# The data contains Network Automation attributes from November 2021 to YTD.
#
# The aim is to build a predictive model and find out the root cause of the network.
#
# Using this model will try to understand the network, and predict the root cause.
#
# Data Set Information:
#
# The Network Operation Automation dataset contains 18 attributes all of which are Categorical.
# The first one being IMT Number.  The most important columns is the class which has been
# coded as follows :
#         1 Flow (Bot Name)
#         2
#
#
#
# Validation set:

# %% [raw]
# in this project, the root cause is predicted and the best classification is found in the network data. The models build in the project are as follows:
#
# 1. LinearClassifier
# 2. KNeighbors
# 3. RandomForestClassifier
# 4. AdaBoostClassifier
# 5. SVR

# %% [raw]
# Recall that we are interested in knowing if there is a relationship between 'Root Cause' and ('Status','State','Recovery Prime', 'Automation Name (Bot)','Automation Type','Automation Framework','Rule Name','Create Date','Imt Id','Responsibility Department','Submitter','Resolution','Workflow State','Responsibility','Automation Status','Team Name'). In order to do so, we would have to use the Chi-squared test. But first, let's state our null hypothesis and the alternative hypothesis.
#
# H0:There is no statistically significant relationship between Root Cause and Automation Name (Bot).
#
# Ha:There is a statistically significant relationship between Root Cause and Automation Name (Bot).
#
# and so on...
#
#
# ('Status','State','Recovery Prime', 'Automation Name (Bot)','Automation Type','Automation Framework','Rule Name','Create Date','Imt Id','Responsibility Department','Submitter','Resolution','Workflow State','Responsibility','Automation Status','Team Name')
#
# Metrics	Definition
# Precision	Precision is defined as the ratio of true positives to the sum of true and false positives.
# Recall	Recall is defined as the ratio of true positives to the sum of true positives and false negatives.
# F1 Score	The F1 is the weighted harmonic mean of precision and recall. The closer the value of the F1 score is to 1.0, the better the expected performance of the model is.
# Support	Support is the number of actual occurrences of the class in the dataset. It doesn’t vary between models, it just diagnoses the performance evaluation process.
#
#
# Popular algorithms that can be used for multi-class classification include:
#
# k-Nearest Neighbors.
# Decision Trees.
# Naive Bayes.
# Random Forest.
# Gradient Boosting.
#
# Binary classification algorithms that can use these strategies for multi-class classification include:
#
# Logistic Regression.
# Support Vector Machine.

# %% [markdown]
# ## 2. DATA COLLECTION
#
# ###############################################################################################################################

# %% [markdown]
# ### 2.1. Connect to dataset

# %%
# SETTING UP WORKING DIRECTORY
import os
os.getcwd()
os.chdir(r'C:\Users\sara.khosravi\Documents\Sara\Data Analysis\ML')
os.getcwd()
# Out:
# 'C:\\Users\\sara.khosravi\\Documents\\Sara\\Data Analysis\\ML'

# %% [markdown]
# ### 2.2. combine the datasets

# %%
# IMPORTING PACKAGES AND LIBRARIES
import warnings
warnings.filterwarnings('ignore')

#import libraries for the data-structures
# Importing the numpy and pandas package
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra

#import sys
#!pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#import pandas_profiling


# EDA Package
#!pip install sweetviz
#import sweetviz as sv

#import libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# !pip3 install plotly
import plotly
import plotly.figure_factory as ff

from datetime import datetime
from matplotlib import dates
from datetime import datetime
import time

import statsmodels.api as sm
from scipy.stats import norm

#import libraries for modeling
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import metrics
import math
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.tree import plot_tree
from sklearn.linear_model import LassoCV 
from sklearn.linear_model import RidgeCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.linear_model import LogisticRegressionCV
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import VotingRegressor
# !pip install xgboost
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, roc_auc_score
from sklearn.metrics import classification_report

print('Libraries imported and installed.')
# Out:
# Requirement already satisfied: plotly in c:\users\sara.khosravi\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\sara.khosravi\anaconda3\lib\site-packages (from plotly) (1.16.0)
# Requirement already satisfied: xgboost in c:\users\sara.khosravi\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy in c:\users\sara.khosravi\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\sara.khosravi\anaconda3\lib\site-packages (from xgboost) (1.7.3)
# Libraries imported and installed.

# %%
# a list with all missing value formats
missing_value_formats = ["n.a.","?","NA","n/a", "na", "--"]

# %%
#Read files:

# READING THE DATA

#Row data for Train
df = pd.read_excel(r'C:\Users\sara.khosravi\Documents\Sara\Data Analysis\ML\Data\Raw_Data_YTD _2022-04-04.xlsx',na_values=missing_value_formats)
print(df.shape)

#ESAP 
dfesap = pd.read_excel(r'C:\Users\sara.khosravi\Documents\Sara\Data Analysis\ML\Data\ESAP.xlsx',na_values=missing_value_formats)
print(dfesap.shape)

#Test Data for Current Month
dftest = pd.read_excel(r'C:\Users\sara.khosravi\Documents\Sara\Data Analysis\ML\Data\Raw_Data__2022-04-04.xlsx',na_values=missing_value_formats)
print(dftest.shape)
# Out:
# (97001, 18)
# (6762, 8)
# (6283, 18)

# %%
# UNDERSTANDING THE DATASET
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97001 entries, 0 to 97000
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Imt Id                     97001 non-null  object
#  1   Create Date                97001 non-null  datetime64[ns]
#  2   Rule Name                  97001 non-null  object
#  3   Root Cause                 87215 non-null  object
#  4   Resolution                 91311 non-null  object
#  5   Recovery Prime             71950 non-null  object
#  6   Workflow State             52472 non-null  object
#  7   Incident Start             97001 non-null  datetime64[ns]
#  8   Incident End               91403 non-null  datetime64[ns]
#  9   Duration of Incident       92684 non-null  object
#  10  Target Time To Restore     95904 non-null  datetime64[ns]
#  11  Event Source               97001 non-null  object
#  12  Responsibility             96997 non-null  object
#  13  Responsibility Department  97001 non-null  object
#  14  State                      97001 non-null  object
#  15  Status                     97001 non-null  object
#  16  Submitter                  97001 non-null  object
#  17  Submitter Department       97001 non-null  object
# dtypes: datetime64[ns](4), object(14)
# memory usage: 13.3+ MB

# %%
# UNDERSTANDING THE DATASET
dfesap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6762 entries, 0 to 6761
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rule Name              6762 non-null   object
#  1   Automation Name (Bot)  654 non-null    object
#  2   Automation Suite Name  654 non-null    object
#  3   Team Name              6762 non-null   object
#  4   Automation Type        654 non-null    object
#  5   Automation Status      654 non-null    object
#  6   Automation Framework   6762 non-null   object
#  7   Auto-Dispatch To       936 non-null    object
# dtypes: object(8)
# memory usage: 422.8+ KB

# %%
# UNDERSTANDING THE DATASET
dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6283 entries, 0 to 6282
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Imt Id                     6283 non-null   object
#  1   Create Date                6283 non-null   datetime64[ns]
#  2   Rule Name                  6283 non-null   object
#  3   Root Cause                 5082 non-null   object
#  4   Resolution                 5340 non-null   object
#  5   Recovery Prime             3962 non-null   object
#  6   Workflow State             3013 non-null   object
#  7   Incident Start             6283 non-null   datetime64[ns]
#  8   Incident End               5341 non-null   datetime64[ns]
#  9   Duration of Incident       5998 non-null   object
#  10  Target Time To Restore     6107 non-null   datetime64[ns]
#  11  Event Source               6283 non-null   object
#  12  Responsibility             6283 non-null   object
#  13  Responsibility Department  6283 non-null   object
#  14  State                      6283 non-null   object
#  15  Status                     6283 non-null   object
#  16  Submitter                  6283 non-null   object
#  17  Submitter Department       6283 non-null   object
# dtypes: datetime64[ns](4), object(14)
# memory usage: 883.7+ KB

# %%
# UNDERSTANDING THE DATASET
df
# Out:
#                 Imt Id         Create Date  \
# 0      IMT.2112.043195 2022-01-01 00:02:31
# 1      IMT.2112.043196 2022-01-01 00:03:41
# 2      IMT.2112.043197 2022-01-01 00:06:41
# 3      IMT.2112.043198 2022-01-01 00:09:38
# 4      IMT.2112.043199 2022-01-01 00:09:43
# ...                ...                 ...
# 96996  IMT.2204.002571 2022-04-03 23:43:10
# 96997  IMT.2204.002572 2022-04-03 23:45:10
# 96998  IMT.2204.002574 2022-04-03 23:49:06
# 96999  IMT.2204.002575 2022-04-03 23:52:11
# 97000  IMT.2204.002576 2022-04-03 23:53:10
#
#                                                Rule Name  \
# 0                                    UMTS UL RSSI -85dBm
# 1      BMC - IUM Evolution - Parameter Count changed ...
# 2                                      TLAN_HVAC_Failure
# 3                      SB_SYNTH_IPTV - Medius - Critical
# 4          CCAP - CASA System Monitoring UPS Switch over
# ...                                                  ...
# 96996                  MiniLinkTN_SNMP_Reserved Position
# 96997                           SB_SYNTH_IPRAN Link Down
# 96998                           SB_SYNTH_IPRAN Link Down
# 96999           Core Security - peakflowSPTraps CRITICAL
# 97000                 RCBIN Core - Link Down Proprietary
#
#                      Root Cause                   Resolution  Recovery Prime  \
# 0          Cause Not Identified  Network / Service Validated  Field Resolved
# 1              Software Failure  Network / Service Validated    NOC Resolved
# 2              Hardware Failure  Network / Service Validated  Field Resolved
# 3              Broadcast Source              Source Restored    NOC Resolved
# 4              Software Failure                       Re-Set    NOC Resolved
# ...                         ...                          ...             ...
# 96996                       NaN                          NaN             NaN
# 96997            No Fault Found  Network / Service Validated    NOC Resolved
# 96998            No Fault Found  Network / Service Validated    NOC Resolved
# 96999            Security Issue  Network / Service Validated    NOC Resolved
# 97000  Customer Equipment Fault  Network / Service Validated    NOC Resolved
#
#             Workflow State      Incident Start        Incident End  \
# 0                      NaN 2022-01-01 00:00:03 2022-01-11 16:24:39
# 1                      NaN 2021-12-31 23:50:35 2022-01-01 00:37:21
# 2                      NaN 2022-01-01 00:05:24 2022-01-05 16:17:24
# 3                      NaN 2022-01-01 00:02:29 2022-01-01 07:57:32
# 4      Requires Specialist 2021-12-31 02:48:48 2022-01-02 05:58:14
# ...                    ...                 ...                 ...
# 96996                  NaN 2022-04-03 22:40:34                 NaT
# 96997  Requires Specialist 2022-04-03 23:42:45 2022-04-04 00:00:12
# 96998  Requires Specialist 2022-04-03 23:48:12 2022-04-04 00:02:45
# 96999  Requires Specialist 2022-04-03 23:50:07 2022-04-04 01:37:10
# 97000  Requires Specialist 2022-04-03 23:50:00 2022-04-04 02:15:03
#
#               Duration of Incident Target Time To Restore Event Source  \
# 0      10 days, 16 Hrs, 24 Minutes    2022-01-08 00:00:03    ESAP-AUTO
# 1        0 days, 0 Hrs, 46 Minutes    2022-01-03 23:50:35    ESAP-AUTO
# 2       4 days, 16 Hrs, 12 Minutes    2022-01-08 00:05:24    ESAP-AUTO
# 3        0 days, 7 Hrs, 55 Minutes    2022-01-08 00:02:29    ESAP-AUTO
# 4         2 days, 3 Hrs, 9 Minutes    2022-01-03 02:48:48    ESAP-AUTO
# ...                            ...                    ...          ...
# 96996    0 days, 9 Hrs, 58 Minutes                    NaT    ESAP-AUTO
# 96997    0 days, 0 Hrs, 17 Minutes    2022-04-06 23:42:45    ESAP-AUTO
# 96998    0 days, 0 Hrs, 14 Minutes    2022-04-06 23:48:12    ESAP-AUTO
# 96999    0 days, 1 Hrs, 47 Minutes    2022-04-10 23:50:07    ESAP-AUTO
# 97000    0 days, 2 Hrs, 25 Minutes    2022-04-06 23:50:00    ESAP-AUTO
#
#                        Responsibility              Responsibility Department  \
# 0      Ops Cable and Wireless Ontario                 Field Ops Wireless SWO
# 1                                 NOC   NOC Data Voice and Enhanced Services
# 2          Ops Cable and Wireless GTA                  Ops Wireless GTA West
# 3                                 NOC  NOC Digital Video and Hosted Services
# 4                                 NOC           NOC Enterprise and Core Data
# ...                               ...                                    ...
# 96996  Ops Cable and Wireless Ontario     Field Ops Wireless Eastern Ontario
# 96997                             NOC                     NOC IM and HFC_RAN
# 96998                             NOC                     NOC IM and HFC_RAN
# 96999                             NOC           NOC Enterprise and Core Data
# 97000                             NOC           NOC Enterprise and Core Data
#
#         State  Status          Submitter                Submitter Department
# 0      Closed  Closed  FOPS_CENTRALSOUTH              Field Ops Wireless SWO
# 1      Closed  Closed               ESAP                          Automation
# 2      Closed  Closed               ESAP                          Automation
# 3      Closed  Closed               ESAP                          Automation
# 4      Closed  Closed               ESAP                          Automation
# ...       ...     ...                ...                                 ...
# 96996     New     New   FOPS_CENTRALEAST  Field Ops Wireless Eastern Ontario
# 96997  Closed  Closed               ESAP                          Automation
# 96998  Closed  Closed               ESAP                          Automation
# 96999  Closed  Closed               ESAP                          Automation
# 97000  Closed  Closed               ESAP                          Automation
#
# [97001 rows x 18 columns]

# %%
# UNDERSTANDING THE DATASET
dfesap
# Out:
#                                 Rule Name          Automation Name (Bot)  \
# 0         100199_Intrusion - Critical ATL                            NaN
# 1     100199_Intrusion - Critical Midwest                            NaN
# 2        100199_Intrusion - Critical - QC                            NaN
# 3       5G_Antenna Calibration DL Failure                            NaN
# 4       5G_Antenna Calibration UL Failure                            NaN
# ...                                   ...                            ...
# 6757                        zHCL_Batch_38                            NaN
# 6758           peakflowSPTraps - CRITICAL         DIAGNOSTIC-ARBOR-ALARM
# 6759                        peakflowTraps                            NaN
# 6760                   TLAN Generator Run  DIAGNOSTIC-TLAN-GENERATOR-RUN
# 6761                     TLAN Temperature    DIAGNOSTIC-TLAN-TEMPERATURE
#
#      Automation Suite Name                     Team Name Automation Type  \
# 0                      NaN            NOC IM and HFC_RAN             NaN
# 1                      NaN            NOC IM and HFC_RAN             NaN
# 2                      NaN            NOC IM and HFC_RAN             NaN
# 3                      NaN            NOC IM and HFC_RAN             NaN
# 4                      NaN            NOC IM and HFC_RAN             NaN
# ...                    ...                           ...             ...
# 6757                   NaN                 HCL-INFRA-GOC             NaN
# 6758           Arbor-Alarm  NOC Enterprise and Core Data      Diagnostic
# 6759                   NaN  NOC Enterprise and Core Data             NaN
# 6760      TLAN-Temperature            NOC IM and HFC_RAN      Diagnostic
# 6761      TLAN-Temperature            NOC IM and HFC_RAN      Diagnostic
#
#      Automation Status Automation Framework  \
# 0                  NaN     Unexpected Value
# 1                  NaN     Unexpected Value
# 2                  NaN     Unexpected Value
# 3                  NaN     Unexpected Value
# 4                  NaN     Unexpected Value
# ...                ...                  ...
# 6757               NaN     Unexpected Value
# 6758           enabled                  TAF
# 6759               NaN     Unexpected Value
# 6760           enabled                  TAF
# 6761           enabled                  TAF
#
#                           Auto-Dispatch To
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3     Auto assign to site prime department
# 4     Auto assign to site prime department
# ...                                    ...
# 6757                   RSO-VST-COMMISSIONS
# 6758                                   NaN
# 6759                                   NaN
# 6760                                   NaN
# 6761                                   NaN
#
# [6762 rows x 8 columns]

# %%
# UNDERSTANDING THE DATASET
dftest
# Out:
#                Imt Id         Create Date  \
# 0     IMT.2203.039717 2022-03-28 00:07:53
# 1     IMT.2203.039718 2022-03-28 00:20:48
# 2     IMT.2203.039719 2022-03-28 00:22:51
# 3     IMT.2203.039720 2022-03-28 00:22:55
# 4     IMT.2203.039721 2022-03-28 00:23:50
# ...               ...                 ...
# 6278  IMT.2204.002571 2022-04-03 23:43:10
# 6279  IMT.2204.002572 2022-04-03 23:45:10
# 6280  IMT.2204.002574 2022-04-03 23:49:06
# 6281  IMT.2204.002575 2022-04-03 23:52:11
# 6282  IMT.2204.002576 2022-04-03 23:53:10
#
#                                               Rule Name  \
# 0       Ericsson LTE_Inter Node Feature Incompatibility
# 1     SDE Core - Infoblox AuthDNS - Critical - Proce...
# 2     SDE Core - Infoblox AuthDNS - Critical - Proce...
# 3     SDE Core - Infoblox AuthDNS - Critical - Proce...
# 4                     Site Commercial Power Failure_GTA
# ...                                                 ...
# 6278                  MiniLinkTN_SNMP_Reserved Position
# 6279                           SB_SYNTH_IPRAN Link Down
# 6280                           SB_SYNTH_IPRAN Link Down
# 6281           Core Security - peakflowSPTraps CRITICAL
# 6282                 RCBIN Core - Link Down Proprietary
#
#                     Root Cause                   Resolution Recovery Prime  \
# 0                 Provisioning                 Reconfigured   TAC Resolved
# 1                   Automation   Network/Service Validation     Automation
# 2                   Automation   Network/Service Validation     Automation
# 3                   Automation   Network/Service Validation     Automation
# 4     Commercial Power Failure               Hydro Restored   NOC Resolved
# ...                        ...                          ...            ...
# 6278                       NaN                          NaN            NaN
# 6279            No Fault Found  Network / Service Validated   NOC Resolved
# 6280            No Fault Found  Network / Service Validated   NOC Resolved
# 6281            Security Issue  Network / Service Validated   NOC Resolved
# 6282  Customer Equipment Fault  Network / Service Validated   NOC Resolved
#
#            Workflow State      Incident Start        Incident End  \
# 0     Requires Specialist 2022-03-27 23:05:59 2022-03-29 14:49:56
# 1     Closed by Auto Diag 2022-03-28 00:18:57 2022-03-28 00:31:00
# 2     Closed by Auto Diag 2022-03-28 00:21:09 2022-03-28 00:33:30
# 3     Closed by Auto Diag 2022-03-28 00:20:23 2022-03-28 00:33:57
# 4     Requires Specialist 2022-03-28 00:11:08 2022-03-28 01:43:33
# ...                   ...                 ...                 ...
# 6278                  NaN 2022-04-03 22:40:34                 NaT
# 6279  Requires Specialist 2022-04-03 23:42:45 2022-04-04 00:00:12
# 6280  Requires Specialist 2022-04-03 23:48:12 2022-04-04 00:02:45
# 6281  Requires Specialist 2022-04-03 23:50:07 2022-04-04 01:37:10
# 6282  Requires Specialist 2022-04-03 23:50:00 2022-04-04 02:15:03
#
#             Duration of Incident Target Time To Restore Event Source  \
# 0     1 days, 15 Hrs, 43 Minutes    2022-04-03 23:05:59    ESAP-AUTO
# 1      0 days, 0 Hrs, 12 Minutes    2022-04-04 00:18:57    ESAP-AUTO
# 2      0 days, 0 Hrs, 12 Minutes    2022-04-04 00:21:09    ESAP-AUTO
# 3      0 days, 0 Hrs, 13 Minutes    2022-04-04 00:20:23    ESAP-AUTO
# 4      0 days, 1 Hrs, 32 Minutes    2022-04-04 00:11:08    ESAP-AUTO
# ...                          ...                    ...          ...
# 6278   0 days, 9 Hrs, 58 Minutes                    NaT    ESAP-AUTO
# 6279   0 days, 0 Hrs, 17 Minutes    2022-04-06 23:42:45    ESAP-AUTO
# 6280   0 days, 0 Hrs, 14 Minutes    2022-04-06 23:48:12    ESAP-AUTO
# 6281   0 days, 1 Hrs, 47 Minutes    2022-04-10 23:50:07    ESAP-AUTO
# 6282   0 days, 2 Hrs, 25 Minutes    2022-04-06 23:50:00    ESAP-AUTO
#
#                       Responsibility           Responsibility Department  \
# 0           Wireless Access Planning   Radio Technical Assistance Centre
# 1                                NOC        NOC Enterprise and Core Data
# 2                                NOC        NOC Enterprise and Core Data
# 3                                NOC        NOC Enterprise and Core Data
# 4                                NOC                  NOC IM and HFC_RAN
# ...                              ...                                 ...
# 6278  Ops Cable and Wireless Ontario  Field Ops Wireless Eastern Ontario
# 6279                             NOC                  NOC IM and HFC_RAN
# 6280                             NOC                  NOC IM and HFC_RAN
# 6281                             NOC        NOC Enterprise and Core Data
# 6282                             NOC        NOC Enterprise and Core Data
#
#        State  Status         Submitter                Submitter Department
# 0     Closed  Closed              ESAP                          Automation
# 1     Closed  Closed              ESAP                          Automation
# 2     Closed  Closed              ESAP                          Automation
# 3     Closed  Closed              ESAP                          Automation
# 4     Closed  Closed              ESAP                          Automation
# ...      ...     ...               ...                                 ...
# 6278     New     New  FOPS_CENTRALEAST  Field Ops Wireless Eastern Ontario
# 6279  Closed  Closed              ESAP                          Automation
# 6280  Closed  Closed              ESAP                          Automation
# 6281  Closed  Closed              ESAP                          Automation
# 6282  Closed  Closed              ESAP                          Automation
#
# [6283 rows x 18 columns]

# %%
# MAPPING 

df_esap= df.join(dfesap.set_index('Rule Name'), on='Rule Name')
df_esap
train=df_esap

# %% [raw]
# # EDA USING SWEETVIZ PACKAGE
# #analyzing the dataset
# eda_report = sv.analyze(train)
# #display the report
# eda_report.show_html('eda.html')

# %% [raw]
# # EDA USING PANDAS PROFILING
# pandas_profiling.ProfileReport(df_esap)

# %%
data= df_esap

# %% [markdown]
# ### 2.3. Find the top 10 records

# %%
#getting number of rows(obs)
data.shape[0]
# Out:
# 97100

# %%
#getting number of collumns
data.shape[1]
# Out:
# 25

# %%
#df2=df #copy by refrences
# getting copy of data ( copy by value)
#method1:
data_orginal=data.copy()
#method2:
data_orginal2=data[:]

# %%
data=data.iloc[:97100, :]
data.shape
# Out:
# (97100, 25)

# %% [raw]
# pd.set_option('max_columns', 50)
# data.head(5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97100 entries, 0 to 97000
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Imt Id                     97100 non-null  object
#  1   Create Date                97100 non-null  datetime64[ns]
#  2   Rule Name                  97100 non-null  object
#  3   Root Cause                 87310 non-null  object
#  4   Resolution                 91410 non-null  object
#  5   Recovery Prime             72045 non-null  object
#  6   Workflow State             52571 non-null  object
#  7   Incident Start             97100 non-null  datetime64[ns]
#  8   Incident End               91502 non-null  datetime64[ns]
#  9   Duration of Incident       92778 non-null  object
#  10  Target Time To Restore     96003 non-null  datetime64[ns]
#  11  Event Source               97100 non-null  object
#  12  Responsibility             97096 non-null  object
#  13  Responsibility Department  97100 non-null  object
#  14  State                      97100 non-null  object
#  15  Status                     97100 non-null  object
#  16  Submitter                  97100 non-null  object
#  17  Submitter Department       97100 non-null  object
#  18  Automation Name (Bot)      55896 non-null  object
#  19  Automation Suite Name      55896 non-null  object
#  20  Team Name                  95207 non-null  object
#  21  Automation Type            55896 non-null  object
#  22  Automation Status          55896 non-null  object
#  23  Automation Framework       95207 non-null  object
#  24  Auto-Dispatch To           17795 non-null  object
# dtypes: datetime64[ns](4), object(21)
# memory usage: 19.3+ MB

# %%
#making a copy of data before preprocessing
data_raw=data.copy()

# %% [raw]
# pandas_profiling.ProfileReport(data)

# %% [markdown]
# ### 2.4. Describe Dataset

# %%
data.describe()
# Out:
#                  Imt Id          Create Date  \
# count             97100                97100
# unique            97001                96951
# top     IMT.2201.018303  2022-01-14 23:51:40
# freq                  2                    2
# first               NaN  2022-01-01 00:02:31
# last                NaN  2022-04-03 23:53:10
#
#                                             Rule Name  Root Cause  \
# count                                           97100       87310
# unique                                           1831          32
# top     CCAP - CASA System Monitoring UPS Switch over  Automation
# freq                                             8789       15974
# first                                             NaN         NaN
# last                                              NaN         NaN
#
#                          Resolution Recovery Prime       Workflow State  \
# count                         91410          72045                52571
# unique                           38              7                    6
# top     Network / Service Validated   NOC Resolved  Requires Specialist
# freq                          34748          35008                35629
# first                           NaN            NaN                  NaN
# last                            NaN            NaN                  NaN
#
#              Incident Start         Incident End       Duration of Incident  \
# count                 97100                91502                      92778
# unique                66664                87833                      10559
# top     2022-02-24 01:22:02  2022-03-02 10:03:14  0 days, 0 Hrs, 14 Minutes
# freq                     95                   41                        837
# first   2018-03-29 19:19:35  2018-03-29 19:19:35                        NaN
# last    2022-04-03 23:50:07  2022-04-04 08:38:37                        NaN
#
#         ...  Status Submitter Submitter Department  \
# count   ...   97100     97100                97100
# unique  ...       4        12                   12
# top     ...  Closed      ESAP           Automation
# freq    ...   91263     91193                91193
# first   ...     NaN       NaN                  NaN
# last    ...     NaN       NaN                  NaN
#
#                   Automation Name (Bot) Automation Suite Name  \
# count                             55896                 55896
# unique                              100                    99
# top     DIAGNOSTIC-CASA-UPS-SWITCH-OVER  Casa-UPS-Switch-Over
# freq                               8789                  8789
# first                               NaN                   NaN
# last                                NaN                   NaN
#
#                  Team Name Automation Type Automation Status  \
# count                95207           55896             55896
# unique                   6               2                 1
# top     NOC IM and HFC_RAN      Diagnostic           enabled
# freq                 47130           52728             55896
# first                  NaN             NaN               NaN
# last                   NaN             NaN               NaN
#
#        Automation Framework                      Auto-Dispatch To
# count                 95207                                 17795
# unique                    2                                    19
# top                     TAF  Auto assign to site prime department
# freq                  55896                                 10513
# first                   NaN                                   NaN
# last                    NaN                                   NaN
#
# [6 rows x 25 columns]

# %% [raw]
# from pandas_profiling import ProfileReport

# %% [markdown]
# pandas_profiling.ProfileReport(data)

# %% [markdown]
# =======================================================================================================================
#
# # ---------------------------------------------  PART ONE   ----------------------------------------------
#
# ========================================================================================================================

# %% [markdown]
# # 3. Data Preprocessing
#
# ###############################################################################################################################

# %% [markdown]
# ## ''''''''''''''''''''''''''''''''''''''''''''''''' Data Exploration Analyasis Step One '''''''''''''''''''''''''''''''''''''''''''''''''''

# %% [raw]
# 1. Find Missing Values
# 2. Find Outliers
# 3. Transform Variables
# 4. Create Variables

# %% [markdown]
# ## ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''

# %% [markdown]
# ## 4. Data Exploration Analyasis Step " ONE"
#
# ###############################################################################################################################

# %% [markdown]
# ### 4.1. Handling Duplicate Data

# %% [markdown]
# #### 4.1.1. Handling Duplicate Observation

# %%
data=data.drop_duplicates()

# %% [markdown]
# ### 4.2. Handling Missing Values

# %% [markdown]
# #### 4.2.1. Sorting Data by Date

# %% [markdown]
# ###### --Sort by date help us to filling missing value reasnable

# %%
data.sort_values(by="Create Date" , ascending=True)
# Out:
#                 Imt Id         Create Date  \
# 0      IMT.2112.043195 2022-01-01 00:02:31
# 1      IMT.2112.043196 2022-01-01 00:03:41
# 2      IMT.2112.043197 2022-01-01 00:06:41
# 3      IMT.2112.043198 2022-01-01 00:09:38
# 4      IMT.2112.043199 2022-01-01 00:09:43
# ...                ...                 ...
# 96996  IMT.2204.002571 2022-04-03 23:43:10
# 96997  IMT.2204.002572 2022-04-03 23:45:10
# 96998  IMT.2204.002574 2022-04-03 23:49:06
# 96999  IMT.2204.002575 2022-04-03 23:52:11
# 97000  IMT.2204.002576 2022-04-03 23:53:10
#
#                                                Rule Name  \
# 0                                    UMTS UL RSSI -85dBm
# 1      BMC - IUM Evolution - Parameter Count changed ...
# 2                                      TLAN_HVAC_Failure
# 3                      SB_SYNTH_IPTV - Medius - Critical
# 4          CCAP - CASA System Monitoring UPS Switch over
# ...                                                  ...
# 96996                  MiniLinkTN_SNMP_Reserved Position
# 96997                           SB_SYNTH_IPRAN Link Down
# 96998                           SB_SYNTH_IPRAN Link Down
# 96999           Core Security - peakflowSPTraps CRITICAL
# 97000                 RCBIN Core - Link Down Proprietary
#
#                      Root Cause                   Resolution  Recovery Prime  \
# 0          Cause Not Identified  Network / Service Validated  Field Resolved
# 1              Software Failure  Network / Service Validated    NOC Resolved
# 2              Hardware Failure  Network / Service Validated  Field Resolved
# 3              Broadcast Source              Source Restored    NOC Resolved
# 4              Software Failure                       Re-Set    NOC Resolved
# ...                         ...                          ...             ...
# 96996                       NaN                          NaN             NaN
# 96997            No Fault Found  Network / Service Validated    NOC Resolved
# 96998            No Fault Found  Network / Service Validated    NOC Resolved
# 96999            Security Issue  Network / Service Validated    NOC Resolved
# 97000  Customer Equipment Fault  Network / Service Validated    NOC Resolved
#
#             Workflow State      Incident Start        Incident End  \
# 0                      NaN 2022-01-01 00:00:03 2022-01-11 16:24:39
# 1                      NaN 2021-12-31 23:50:35 2022-01-01 00:37:21
# 2                      NaN 2022-01-01 00:05:24 2022-01-05 16:17:24
# 3                      NaN 2022-01-01 00:02:29 2022-01-01 07:57:32
# 4      Requires Specialist 2021-12-31 02:48:48 2022-01-02 05:58:14
# ...                    ...                 ...                 ...
# 96996                  NaN 2022-04-03 22:40:34                 NaT
# 96997  Requires Specialist 2022-04-03 23:42:45 2022-04-04 00:00:12
# 96998  Requires Specialist 2022-04-03 23:48:12 2022-04-04 00:02:45
# 96999  Requires Specialist 2022-04-03 23:50:07 2022-04-04 01:37:10
# 97000  Requires Specialist 2022-04-03 23:50:00 2022-04-04 02:15:03
#
#               Duration of Incident  ...  Status          Submitter  \
# 0      10 days, 16 Hrs, 24 Minutes  ...  Closed  FOPS_CENTRALSOUTH
# 1        0 days, 0 Hrs, 46 Minutes  ...  Closed               ESAP
# 2       4 days, 16 Hrs, 12 Minutes  ...  Closed               ESAP
# 3        0 days, 7 Hrs, 55 Minutes  ...  Closed               ESAP
# 4         2 days, 3 Hrs, 9 Minutes  ...  Closed               ESAP
# ...                            ...  ...     ...                ...
# 96996    0 days, 9 Hrs, 58 Minutes  ...     New   FOPS_CENTRALEAST
# 96997    0 days, 0 Hrs, 17 Minutes  ...  Closed               ESAP
# 96998    0 days, 0 Hrs, 14 Minutes  ...  Closed               ESAP
# 96999    0 days, 1 Hrs, 47 Minutes  ...  Closed               ESAP
# 97000    0 days, 2 Hrs, 25 Minutes  ...  Closed               ESAP
#
#                      Submitter Department  \
# 0                  Field Ops Wireless SWO
# 1                              Automation
# 2                              Automation
# 3                              Automation
# 4                              Automation
# ...                                   ...
# 96996  Field Ops Wireless Eastern Ontario
# 96997                          Automation
# 96998                          Automation
# 96999                          Automation
# 97000                          Automation
#
#                                    Automation Name (Bot)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                        DIAGNOSTIC-CASA-UPS-SWITCH-OVER
# ...                                                  ...
# 96996                                                NaN
# 96997  DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-AL...
# 96998  DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-AL...
# 96999                             DIAGNOSTIC-ARBOR-ALARM
# 97000                         DIAGNOSTIC-RCBIN-LINK-DOWN
#
#                         Automation Suite Name  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                        Casa-UPS-Switch-Over
# ...                                       ...
# 96996                                     NaN
# 96997  IPRAN-SYNTH-Link-Down-Correlated-Alarm
# 96998  IPRAN-SYNTH-Link-Down-Correlated-Alarm
# 96999                             Arbor-Alarm
# 97000                         RCBIN-Link-Down
#
#                                    Team Name Automation Type  \
# 0                         NOC IM and HFC_RAN             NaN
# 1       NOC Data Voice and Enhanced Services             NaN
# 2                         NOC IM and HFC_RAN             NaN
# 3      NOC Digital Video and Hosted Services             NaN
# 4               NOC Enterprise and Core Data      Diagnostic
# ...                                      ...             ...
# 96996                     NOC IM and HFC_RAN             NaN
# 96997                     NOC IM and HFC_RAN      Diagnostic
# 96998                     NOC IM and HFC_RAN      Diagnostic
# 96999           NOC Enterprise and Core Data      Diagnostic
# 97000           NOC Enterprise and Core Data      Diagnostic
#
#       Automation Status Automation Framework  \
# 0                   NaN     Unexpected Value
# 1                   NaN     Unexpected Value
# 2                   NaN     Unexpected Value
# 3                   NaN     Unexpected Value
# 4               enabled                  TAF
# ...                 ...                  ...
# 96996               NaN     Unexpected Value
# 96997           enabled                  TAF
# 96998           enabled                  TAF
# 96999           enabled                  TAF
# 97000           enabled                  TAF
#
#                            Auto-Dispatch To
# 0      Auto assign to site prime department
# 1                                       NaN
# 2      Auto assign to site prime department
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 96996  Auto assign to site prime department
# 96997                                   NaN
# 96998                                   NaN
# 96999                                   NaN
# 97000                                   NaN
#
# [97100 rows x 25 columns]

# %%
df
# Out:
#                 Imt Id         Create Date  \
# 0      IMT.2112.043195 2022-01-01 00:02:31
# 1      IMT.2112.043196 2022-01-01 00:03:41
# 2      IMT.2112.043197 2022-01-01 00:06:41
# 3      IMT.2112.043198 2022-01-01 00:09:38
# 4      IMT.2112.043199 2022-01-01 00:09:43
# ...                ...                 ...
# 96996  IMT.2204.002571 2022-04-03 23:43:10
# 96997  IMT.2204.002572 2022-04-03 23:45:10
# 96998  IMT.2204.002574 2022-04-03 23:49:06
# 96999  IMT.2204.002575 2022-04-03 23:52:11
# 97000  IMT.2204.002576 2022-04-03 23:53:10
#
#                                                Rule Name  \
# 0                                    UMTS UL RSSI -85dBm
# 1      BMC - IUM Evolution - Parameter Count changed ...
# 2                                      TLAN_HVAC_Failure
# 3                      SB_SYNTH_IPTV - Medius - Critical
# 4          CCAP - CASA System Monitoring UPS Switch over
# ...                                                  ...
# 96996                  MiniLinkTN_SNMP_Reserved Position
# 96997                           SB_SYNTH_IPRAN Link Down
# 96998                           SB_SYNTH_IPRAN Link Down
# 96999           Core Security - peakflowSPTraps CRITICAL
# 97000                 RCBIN Core - Link Down Proprietary
#
#                      Root Cause                   Resolution  Recovery Prime  \
# 0          Cause Not Identified  Network / Service Validated  Field Resolved
# 1              Software Failure  Network / Service Validated    NOC Resolved
# 2              Hardware Failure  Network / Service Validated  Field Resolved
# 3              Broadcast Source              Source Restored    NOC Resolved
# 4              Software Failure                       Re-Set    NOC Resolved
# ...                         ...                          ...             ...
# 96996                       NaN                          NaN             NaN
# 96997            No Fault Found  Network / Service Validated    NOC Resolved
# 96998            No Fault Found  Network / Service Validated    NOC Resolved
# 96999            Security Issue  Network / Service Validated    NOC Resolved
# 97000  Customer Equipment Fault  Network / Service Validated    NOC Resolved
#
#             Workflow State      Incident Start        Incident End  \
# 0                      NaN 2022-01-01 00:00:03 2022-01-11 16:24:39
# 1                      NaN 2021-12-31 23:50:35 2022-01-01 00:37:21
# 2                      NaN 2022-01-01 00:05:24 2022-01-05 16:17:24
# 3                      NaN 2022-01-01 00:02:29 2022-01-01 07:57:32
# 4      Requires Specialist 2021-12-31 02:48:48 2022-01-02 05:58:14
# ...                    ...                 ...                 ...
# 96996                  NaN 2022-04-03 22:40:34                 NaT
# 96997  Requires Specialist 2022-04-03 23:42:45 2022-04-04 00:00:12
# 96998  Requires Specialist 2022-04-03 23:48:12 2022-04-04 00:02:45
# 96999  Requires Specialist 2022-04-03 23:50:07 2022-04-04 01:37:10
# 97000  Requires Specialist 2022-04-03 23:50:00 2022-04-04 02:15:03
#
#               Duration of Incident Target Time To Restore Event Source  \
# 0      10 days, 16 Hrs, 24 Minutes    2022-01-08 00:00:03    ESAP-AUTO
# 1        0 days, 0 Hrs, 46 Minutes    2022-01-03 23:50:35    ESAP-AUTO
# 2       4 days, 16 Hrs, 12 Minutes    2022-01-08 00:05:24    ESAP-AUTO
# 3        0 days, 7 Hrs, 55 Minutes    2022-01-08 00:02:29    ESAP-AUTO
# 4         2 days, 3 Hrs, 9 Minutes    2022-01-03 02:48:48    ESAP-AUTO
# ...                            ...                    ...          ...
# 96996    0 days, 9 Hrs, 58 Minutes                    NaT    ESAP-AUTO
# 96997    0 days, 0 Hrs, 17 Minutes    2022-04-06 23:42:45    ESAP-AUTO
# 96998    0 days, 0 Hrs, 14 Minutes    2022-04-06 23:48:12    ESAP-AUTO
# 96999    0 days, 1 Hrs, 47 Minutes    2022-04-10 23:50:07    ESAP-AUTO
# 97000    0 days, 2 Hrs, 25 Minutes    2022-04-06 23:50:00    ESAP-AUTO
#
#                        Responsibility              Responsibility Department  \
# 0      Ops Cable and Wireless Ontario                 Field Ops Wireless SWO
# 1                                 NOC   NOC Data Voice and Enhanced Services
# 2          Ops Cable and Wireless GTA                  Ops Wireless GTA West
# 3                                 NOC  NOC Digital Video and Hosted Services
# 4                                 NOC           NOC Enterprise and Core Data
# ...                               ...                                    ...
# 96996  Ops Cable and Wireless Ontario     Field Ops Wireless Eastern Ontario
# 96997                             NOC                     NOC IM and HFC_RAN
# 96998                             NOC                     NOC IM and HFC_RAN
# 96999                             NOC           NOC Enterprise and Core Data
# 97000                             NOC           NOC Enterprise and Core Data
#
#         State  Status          Submitter                Submitter Department
# 0      Closed  Closed  FOPS_CENTRALSOUTH              Field Ops Wireless SWO
# 1      Closed  Closed               ESAP                          Automation
# 2      Closed  Closed               ESAP                          Automation
# 3      Closed  Closed               ESAP                          Automation
# 4      Closed  Closed               ESAP                          Automation
# ...       ...     ...                ...                                 ...
# 96996     New     New   FOPS_CENTRALEAST  Field Ops Wireless Eastern Ontario
# 96997  Closed  Closed               ESAP                          Automation
# 96998  Closed  Closed               ESAP                          Automation
# 96999  Closed  Closed               ESAP                          Automation
# 97000  Closed  Closed               ESAP                          Automation
#
# [97001 rows x 18 columns]

# %% [markdown]
# #### 4.2.2.  Finding the Missing values

# %%
#calculatin no. of missing values for each column and it's percentage
def percentage_of_miss():
  data1=data[data.columns[data.isnull().sum()>=1]] # I did slicing by condition( I get s subset of dataframe that contains columns that have atleast one missing values) )
  total_miss = data1.isnull().sum().sort_values(ascending=False)
  percent_miss = ((data1.isnull().sum()/data1.isnull().count())*100).sort_values(ascending=False) #df1.isnull().sum() returns only number of missing values,df1.isnull().count() returns whole number of observations (True=1 for null and False=0 for not missing ) 
  missing_data = pd.concat([total_miss, percent_miss], axis=1, keys=['Number of Missing', 'Percentage'])
  return(missing_data)

# %%
percentage_of_miss()
# Out:
#                         Number of Missing  Percentage
# Auto-Dispatch To                    79305   81.673532
# Workflow State                      44529   45.858908
# Automation Name (Bot)               41204   42.434604
# Automation Suite Name               41204   42.434604
# Automation Type                     41204   42.434604
# Automation Status                   41204   42.434604
# Recovery Prime                      25055   25.803296
# Root Cause                           9790   10.082389
# Resolution                           5690    5.859938
# Incident End                         5598    5.765191
# Duration of Incident                 4322    4.451081
# Team Name                            1893    1.949537
# Automation Framework                 1893    1.949537
# Target Time To Restore               1097    1.129763
# Responsibility                          4    0.004119

# %% [markdown]
# #### 4.2.3. Drop columns that have 80% or more missing values

# %%
df = data.dropna(axis=1, thresh=19420)

# %% [markdown]
# ### 4.3. Filling Missing Values

# %% [raw]
# Columns=['Recovery Prime','Resolution','Incident End','Duration of Incident','Target Time To Restore','Responsibility']
#
#
# #1. Function to impute null value with new category
# #Call function to create new category for variables
#
# def impute_nan_create_category(df,Columns):
#      df[Columns] = df['Columns'].fillna("0")
#
# print("Data:",df[Columns])

# %% [raw]
# #Method1
# df.fillna({
#             #name unkown for null values in Root Cause
#             'Root Cause' : df['Root Cause'].fillna('Unknown'),
#
#             #name unkown for null values in Resolution
#             'Resolution':df.Resolution.fillna('Unknown'),
#
#             #name unkown for null values in Resolution
#             'Recovery Prime':df['Recovery Prime'].fillna('Unknown'),
#             },
#         inplace = True)

# %%
df['Root Cause'] = df['Root Cause'].fillna("Unknown") 
df['Resolution'] = df['Resolution'].fillna("Unknown") 
df['Recovery Prime'] = df['Recovery Prime'].fillna("Unknown") 
df['Incident End'] = df['Incident End'].fillna("Unknown") 
df['Duration of Incident'] = df['Duration of Incident'].fillna("Unknown") 
df['Target Time To Restore'] = df['Target Time To Restore'].fillna("Unknown") 
df['Responsibility'] = df['Responsibility'].fillna("Unknown") 
df['Automation Name (Bot)'] = df['Automation Name (Bot)'].fillna("Unknown") 
df['Automation Suite Name'] = df['Automation Suite Name'].fillna("Unknown") 
df['Recovery Prime'] = df['Recovery Prime'].fillna("Unknown") 
df['Team Name'] = df['Team Name'].fillna("Unknown") 
df['Automation Type'] = df['Automation Type'].fillna("Unknown") 
df['Automation Status'] = df['Automation Status'].fillna("Unknown") 
df['Automation Framework'] = df['Automation Framework'].fillna("Unknown") 
df['Workflow State'] = df['Workflow State'].fillna("Unknown")

# %%
# REVIEWING MISSING VALUES IN CORE DATASET - IMT
df.apply(lambda X:sum(X.isnull()))
# Out:
# Imt Id                       0
# Create Date                  0
# Rule Name                    0
# Root Cause                   0
# Resolution                   0
# Recovery Prime               0
# Workflow State               0
# Incident Start               0
# Incident End                 0
# Duration of Incident         0
# Target Time To Restore       0
# Event Source                 0
# Responsibility               0
# Responsibility Department    0
# State                        0
# Status                       0
# Submitter                    0
# Submitter Department         0
# Automation Name (Bot)        0
# Automation Suite Name        0
# Team Name                    0
# Automation Type              0
# Automation Status            0
# Automation Framework         0
# dtype: int64

# %% [markdown]
# ### Rename Column

# %%
df.rename(columns={'Imt Id':'ImtId',
                     'Create Date':'CreateDate',
                     'Rule Name':'RuleName',
                     'Root Cause':'RootCause',
                     'Recovery Prime':'RecoveryPrime',
                     'Workflow State':'WorkflowState',
                     'Incident Start':'IncidentStart',
                     'Incident End':'IncidentEnd',
                     'Duration of Incident':'DurationOfIncident',
                     'Target Time To Restore':'TargetTimeToRestore',
                     'Event Source':'EventSource',
                     'Responsibility Department':'ResponsibilityDepartment',
                     'Submitter Department':'SubmitterDepartment',
                     'Automation Name (Bot)':'Bot',
                     'Automation Suite Name':'AutomationSuiteName',
                     'Automation Type':'AutomationType',
                     'Automation Status':'AutomationStatus',
                     'Automation Framework':'AutomationFramework',
                     'Automation Framework':'AutomationFramework',
                     
                    },inplace=True)
df.head(2)
# Out:
#              ImtId          CreateDate  \
# 0  IMT.2112.043195 2022-01-01 00:02:31
# 1  IMT.2112.043196 2022-01-01 00:03:41
#
#                                             RuleName             RootCause  \
# 0                                UMTS UL RSSI -85dBm  Cause Not Identified
# 1  BMC - IUM Evolution - Parameter Count changed ...      Software Failure
#
#                     Resolution   RecoveryPrime WorkflowState  \
# 0  Network / Service Validated  Field Resolved       Unknown
# 1  Network / Service Validated    NOC Resolved       Unknown
#
#         IncidentStart          IncidentEnd           DurationOfIncident  ...  \
# 0 2022-01-01 00:00:03  2022-01-11 16:24:39  10 days, 16 Hrs, 24 Minutes  ...
# 1 2021-12-31 23:50:35  2022-01-01 00:37:21    0 days, 0 Hrs, 46 Minutes  ...
#
#     State  Status          Submitter     SubmitterDepartment      Bot  \
# 0  Closed  Closed  FOPS_CENTRALSOUTH  Field Ops Wireless SWO  Unknown
# 1  Closed  Closed               ESAP              Automation  Unknown
#
#   AutomationSuiteName                             Team Name AutomationType  \
# 0             Unknown                    NOC IM and HFC_RAN        Unknown
# 1             Unknown  NOC Data Voice and Enhanced Services        Unknown
#
#   AutomationStatus AutomationFramework
# 0          Unknown    Unexpected Value
# 1          Unknown    Unexpected Value
#
# [2 rows x 24 columns]

# %% [raw]
# Change Management Activity

# %% [raw]
# #let's create as a single column 'ontime/delay' from 'ontime' and 'delay' columns
# data['RootCauseP']=data.RootCause.replace({"Change Management Activity", ' '}, {0, 1})

# %% [raw]
# pd.Series(np.where(data.RootCause.values == 'Change Management Activity', 1, 0),
#           data.index)

# %% [raw]
# data=pd.concat([data, df['RootCauseP']])
# data

# %%
df['RootCause_original'] = df['RootCause']

# %% [raw]
# df['RootCause'] = df['RootCause'].map(lambda x: 1 if x == 'Change Management Activity' else 0)
# df['RootCause'] = df['RootCause'].astype(int)

# %%
df
# Out:
#                  ImtId          CreateDate  \
# 0      IMT.2112.043195 2022-01-01 00:02:31
# 1      IMT.2112.043196 2022-01-01 00:03:41
# 2      IMT.2112.043197 2022-01-01 00:06:41
# 3      IMT.2112.043198 2022-01-01 00:09:38
# 4      IMT.2112.043199 2022-01-01 00:09:43
# ...                ...                 ...
# 96996  IMT.2204.002571 2022-04-03 23:43:10
# 96997  IMT.2204.002572 2022-04-03 23:45:10
# 96998  IMT.2204.002574 2022-04-03 23:49:06
# 96999  IMT.2204.002575 2022-04-03 23:52:11
# 97000  IMT.2204.002576 2022-04-03 23:53:10
#
#                                                 RuleName  \
# 0                                    UMTS UL RSSI -85dBm
# 1      BMC - IUM Evolution - Parameter Count changed ...
# 2                                      TLAN_HVAC_Failure
# 3                      SB_SYNTH_IPTV - Medius - Critical
# 4          CCAP - CASA System Monitoring UPS Switch over
# ...                                                  ...
# 96996                  MiniLinkTN_SNMP_Reserved Position
# 96997                           SB_SYNTH_IPRAN Link Down
# 96998                           SB_SYNTH_IPRAN Link Down
# 96999           Core Security - peakflowSPTraps CRITICAL
# 97000                 RCBIN Core - Link Down Proprietary
#
#                       RootCause                   Resolution   RecoveryPrime  \
# 0          Cause Not Identified  Network / Service Validated  Field Resolved
# 1              Software Failure  Network / Service Validated    NOC Resolved
# 2              Hardware Failure  Network / Service Validated  Field Resolved
# 3              Broadcast Source              Source Restored    NOC Resolved
# 4              Software Failure                       Re-Set    NOC Resolved
# ...                         ...                          ...             ...
# 96996                   Unknown                      Unknown         Unknown
# 96997            No Fault Found  Network / Service Validated    NOC Resolved
# 96998            No Fault Found  Network / Service Validated    NOC Resolved
# 96999            Security Issue  Network / Service Validated    NOC Resolved
# 97000  Customer Equipment Fault  Network / Service Validated    NOC Resolved
#
#              WorkflowState       IncidentStart          IncidentEnd  \
# 0                  Unknown 2022-01-01 00:00:03  2022-01-11 16:24:39
# 1                  Unknown 2021-12-31 23:50:35  2022-01-01 00:37:21
# 2                  Unknown 2022-01-01 00:05:24  2022-01-05 16:17:24
# 3                  Unknown 2022-01-01 00:02:29  2022-01-01 07:57:32
# 4      Requires Specialist 2021-12-31 02:48:48  2022-01-02 05:58:14
# ...                    ...                 ...                  ...
# 96996              Unknown 2022-04-03 22:40:34              Unknown
# 96997  Requires Specialist 2022-04-03 23:42:45  2022-04-04 00:00:12
# 96998  Requires Specialist 2022-04-03 23:48:12  2022-04-04 00:02:45
# 96999  Requires Specialist 2022-04-03 23:50:07  2022-04-04 01:37:10
# 97000  Requires Specialist 2022-04-03 23:50:00  2022-04-04 02:15:03
#
#                 DurationOfIncident  ...  Status          Submitter  \
# 0      10 days, 16 Hrs, 24 Minutes  ...  Closed  FOPS_CENTRALSOUTH
# 1        0 days, 0 Hrs, 46 Minutes  ...  Closed               ESAP
# 2       4 days, 16 Hrs, 12 Minutes  ...  Closed               ESAP
# 3        0 days, 7 Hrs, 55 Minutes  ...  Closed               ESAP
# 4         2 days, 3 Hrs, 9 Minutes  ...  Closed               ESAP
# ...                            ...  ...     ...                ...
# 96996    0 days, 9 Hrs, 58 Minutes  ...     New   FOPS_CENTRALEAST
# 96997    0 days, 0 Hrs, 17 Minutes  ...  Closed               ESAP
# 96998    0 days, 0 Hrs, 14 Minutes  ...  Closed               ESAP
# 96999    0 days, 1 Hrs, 47 Minutes  ...  Closed               ESAP
# 97000    0 days, 2 Hrs, 25 Minutes  ...  Closed               ESAP
#
#                       SubmitterDepartment  \
# 0                  Field Ops Wireless SWO
# 1                              Automation
# 2                              Automation
# 3                              Automation
# 4                              Automation
# ...                                   ...
# 96996  Field Ops Wireless Eastern Ontario
# 96997                          Automation
# 96998                          Automation
# 96999                          Automation
# 97000                          Automation
#
#                                                      Bot  \
# 0                                                Unknown
# 1                                                Unknown
# 2                                                Unknown
# 3                                                Unknown
# 4                        DIAGNOSTIC-CASA-UPS-SWITCH-OVER
# ...                                                  ...
# 96996                                            Unknown
# 96997  DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-AL...
# 96998  DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-AL...
# 96999                             DIAGNOSTIC-ARBOR-ALARM
# 97000                         DIAGNOSTIC-RCBIN-LINK-DOWN
#
#                           AutomationSuiteName  \
# 0                                     Unknown
# 1                                     Unknown
# 2                                     Unknown
# 3                                     Unknown
# 4                        Casa-UPS-Switch-Over
# ...                                       ...
# 96996                                 Unknown
# 96997  IPRAN-SYNTH-Link-Down-Correlated-Alarm
# 96998  IPRAN-SYNTH-Link-Down-Correlated-Alarm
# 96999                             Arbor-Alarm
# 97000                         RCBIN-Link-Down
#
#                                    Team Name AutomationType AutomationStatus  \
# 0                         NOC IM and HFC_RAN        Unknown          Unknown
# 1       NOC Data Voice and Enhanced Services        Unknown          Unknown
# 2                         NOC IM and HFC_RAN        Unknown          Unknown
# 3      NOC Digital Video and Hosted Services        Unknown          Unknown
# 4               NOC Enterprise and Core Data     Diagnostic          enabled
# ...                                      ...            ...              ...
# 96996                     NOC IM and HFC_RAN        Unknown          Unknown
# 96997                     NOC IM and HFC_RAN     Diagnostic          enabled
# 96998                     NOC IM and HFC_RAN     Diagnostic          enabled
# 96999           NOC Enterprise and Core Data     Diagnostic          enabled
# 97000           NOC Enterprise and Core Data     Diagnostic          enabled
#
#       AutomationFramework        RootCause_original
# 0        Unexpected Value      Cause Not Identified
# 1        Unexpected Value          Software Failure
# 2        Unexpected Value          Hardware Failure
# 3        Unexpected Value          Broadcast Source
# 4                     TAF          Software Failure
# ...                   ...                       ...
# 96996    Unexpected Value                   Unknown
# 96997                 TAF            No Fault Found
# 96998                 TAF            No Fault Found
# 96999                 TAF            Security Issue
# 97000                 TAF  Customer Equipment Fault
#
# [97100 rows x 25 columns]

# %%
#making a copy of filtered data
df_copy=df.copy()

# %%
df["RootCause"].value_counts()
# Out:
# Automation                      15974
# Cause Identified                11607
# Software Failure                11371
# No Fault Found                  11239
# Change Management Activity      10450
# Unknown                          9790
# Hardware Failure                 6498
# Cause Not Identified             6402
# Commercial Power Failure         3304
# Facilities - Environment         2253
# Fiber                            1671
# Third Party                      1016
# Provisioning                      965
# Mother Nature                     772
# Broadcast Source                  736
# Customer Equipment Fault          730
# Security Issue                    459
# Opened In Error                   443
# Preventive Maintenance Error      385
# Coax Cable                        236
# OSS                               224
# Fiber Cut                         220
# Application Fault                 135
# Switch Maintenance                 60
# Provisioning System Error          59
# Employee Error                     32
# Low RF                             30
# Vandalism                          27
# Damage Network                      6
# Hosted Services                     2
# Client Software                     2
# Coverage                            1
# User Access                         1
# Name: RootCause, dtype: int64

# %%
df["RootCause"].value_counts(normalize=True)
# Out:
# Automation                      0.164511
# Cause Identified                0.119537
# Software Failure                0.117106
# No Fault Found                  0.115747
# Change Management Activity      0.107621
# Unknown                         0.100824
# Hardware Failure                0.066921
# Cause Not Identified            0.065932
# Commercial Power Failure        0.034027
# Facilities - Environment        0.023203
# Fiber                           0.017209
# Third Party                     0.010463
# Provisioning                    0.009938
# Mother Nature                   0.007951
# Broadcast Source                0.007580
# Customer Equipment Fault        0.007518
# Security Issue                  0.004727
# Opened In Error                 0.004562
# Preventive Maintenance Error    0.003965
# Coax Cable                      0.002430
# OSS                             0.002307
# Fiber Cut                       0.002266
# Application Fault               0.001390
# Switch Maintenance              0.000618
# Provisioning System Error       0.000608
# Employee Error                  0.000330
# Low RF                          0.000309
# Vandalism                       0.000278
# Damage Network                  0.000062
# Hosted Services                 0.000021
# Client Software                 0.000021
# Coverage                        0.000010
# User Access                     0.000010
# Name: RootCause, dtype: float64

# %%
plt.rcParams['figure.figsize']=(25,5)
#explode = (.2, 0)
#plt.pie(df['RootCause'].value_counts(), explode = explode, autopct='%1.1f%%')
plt.pie(df['RootCause'].value_counts(), explode = None, autopct='%1.1f%%')
plt.title('percentage of Change Management Activity and others')
plt.legend(['Automation','Broadcast Source','Cause Identified','Cause Not Identified','Change Management Activity'
           ,'Commercial Power Failure','Customer Equipment Fault','Damage Network','Employee Error','Facilities - Environment',
           'Fiber','AutomationFiber Cut','Hardware Failure','Hosted Services','AutomationMother Nature','AutomationMother Nature',
            'N/A','No Fault Found','Opened In Error','OSS','Preventive Maintenance Error','Provisioning','Provisioning System Error',
            'Security Issue','Software Failure','Third Party'
           ],loc=6,borderaxespad=60)


plt.show( )

# %% [raw]
# df[(df["RootCause"] == 0) & (df["Bot"] == "....")][".."].max()

# %%
columns_to_show = ["Resolution", "RuleName", "SubmitterDepartment"]

df.groupby(["RootCause"])[columns_to_show].describe(percentiles=[])
# Out:
#                              Resolution         \
#                                   count unique
# RootCause
# Application Fault                   135      2
# Automation                        15974      2
# Broadcast Source                    736      8
# Cause Identified                  11607      1
# Cause Not Identified               6402      1
# Change Management Activity        10450      8
# Client Software                       2      2
# Coax Cable                          236      3
# Commercial Power Failure           3304      9
# Coverage                              1      1
# Customer Equipment Fault            730      5
# Damage Network                        6      3
# Employee Error                       32      6
# Facilities - Environment           2253     10
# Fiber                              1671      9
# Fiber Cut                           220      4
# Hardware Failure                   6498     14
# Hosted Services                       2      2
# Low RF                               30      3
# Mother Nature                       772      7
# No Fault Found                    11239      3
# OSS                                 224      1
# Opened In Error                     443      1
# Preventive Maintenance Error        385      7
# Provisioning                        965      5
# Provisioning System Error            59      1
# Security Issue                      459      3
# Software Failure                  11371     12
# Switch Maintenance                   60      1
# Third Party                        1016      8
# Unknown                            9790      3
# User Access                           1      1
# Vandalism                            27      3
#
#                                                                     RuleName  \
#                                                          top   freq    count
# RootCause
# Application Fault             Restart Services / Application    117      135
# Automation                        Network/Service Validation  15963    15974
# Broadcast Source                 Network / Service Validated    414      736
# Cause Identified                           See Linked ticket  11607    11607
# Cause Not Identified             Network / Service Validated   6402     6402
# Change Management Activity                 See Linked ticket   6554    10450
# Client Software                       Training / Walkthrough      1        2
# Coax Cable                                          Repaired    226      236
# Commercial Power Failure                      Hydro Restored   2999     3304
# Coverage                                        Reconfigured      1        1
# Customer Equipment Fault         Network / Service Validated    696      730
# Damage Network                                      Replaced      3        6
# Employee Error                                     Reconnect      9       32
# Facilities - Environment         Network / Service Validated   1125     2253
# Fiber                            Network / Service Validated   1103     1671
# Fiber Cut                                  See Linked ticket    106      220
# Hardware Failure                                    Repaired   1563     6498
# Hosted Services                                 Reconfigured      1        2
# Low RF                                              Repaired     15       30
# Mother Nature                    Network / Service Validated    515      772
# No Fault Found                   Network / Service Validated  11234    11239
# OSS                                                 Referred    224      224
# Opened In Error                                    Cancelled    443      443
# Preventive Maintenance Error                    Reconfigured    269      385
# Provisioning                                    Reconfigured    619      965
# Provisioning System Error                           Replaced     59       59
# Security Issue                   Network / Service Validated    404      459
# Software Failure                 Network / Service Validated   7881    11371
# Switch Maintenance               Network / Service Validated     60       60
# Third Party                      Network / Service Validated    759     1016
# Unknown                                              Unknown   5653     9790
# User Access                                   Password Reset      1        1
# Vandalism                                           Repaired     18       27
#
#                                      \
#                              unique
# RootCause
# Application Fault                37
# Automation                       57
# Broadcast Source                 28
# Cause Identified                802
# Cause Not Identified            765
# Change Management Activity      733
# Client Software                   2
# Coax Cable                       10
# Commercial Power Failure        255
# Coverage                          1
# Customer Equipment Fault         73
# Damage Network                    6
# Employee Error                   23
# Facilities - Environment        278
# Fiber                           165
# Fiber Cut                        71
# Hardware Failure                597
# Hosted Services                   2
# Low RF                            7
# Mother Nature                   121
# No Fault Found                  832
# OSS                              58
# Opened In Error                 125
# Preventive Maintenance Error     67
# Provisioning                    201
# Provisioning System Error        37
# Security Issue                   24
# Software Failure                932
# Switch Maintenance               33
# Third Party                     187
# Unknown                         800
# User Access                       1
# Vandalism                        16
#
#                                                                                  \
#                                                                             top
# RootCause
# Application Fault                                      VideoNOC_AT-RuleDisabled
# Automation                        CCAP - CASA System Monitoring UPS Switch over
# Broadcast Source                               SB_SYNTH_Medius - DTV - Critical
# Cause Identified                                 RCBIN Core - Link Down CSMA-CD
# Cause Not Identified                                   SB_SYNTH_IPRAN Link Down
# Change Management Activity                       RCBIN Core - Link Down CSMA-CD
# Client Software                                                       BMC ? ENM
# Coax Cable                                           Platform KPIs_F2 Threshold
# Commercial Power Failure                          Site Commercial Power Failure
# Coverage                                          GSM correlation_all Cells OOS
# Customer Equipment Fault                             REN Core - Link Down MAJOR
# Damage Network                                                 NodeFault - PM01
# Employee Error                                             TLAN-Access_Temp Pro
# Facilities - Environment                                   TLAN-Access_Temp Pro
# Fiber                                            RCBIN Core - Link Down CSMA-CD
# Fiber Cut                                        RCBIN Core - Link Down CSMA-CD
# Hardware Failure                                 RCBIN Core - Link Down CSMA-CD
# Hosted Services                                          TLAN Rectifier - Major
# Low RF                                               Platform KPIs_F2 Threshold
# Mother Nature                                            TLAN Rectifier - Minor
# No Fault Found                                         SB_SYNTH_IPRAN Link Down
# OSS                           OSS - Mediation Connection to an external outp...
# Opened In Error                   5G_Service Unavailable - Cell Downtime Manual
# Preventive Maintenance Error                            Microwave License Major
# Provisioning                                            Microwave License Major
# Provisioning System Error               5G_Sync Time and Phase Accuracy Too Low
# Security Issue                         Core Security - peakflowSPTraps CRITICAL
# Software Failure                                 RCBIN Core - Link Down CSMA-CD
# Switch Maintenance               HP CSA - RTMS has detected collector nsdb_coll
# Third Party                                      RCBIN Core - Link Down CSMA-CD
# Unknown                                              Platform KPIs_F2 Threshold
# User Access                                  BMC - LTE DNS - Generic - CRITICAL
# Vandalism                                         Site Commercial Power Failure
#
#                                    SubmitterDepartment                     \
#                               freq               count unique         top
# RootCause
# Application Fault               52                 135      3  Automation
# Automation                    8042               15974     11  Automation
# Broadcast Source               496                 736      3  Automation
# Cause Identified               803               11607      8  Automation
# Cause Not Identified           268                6402     12  Automation
# Change Management Activity     958               10450     12  Automation
# Client Software                  1                   2      1  Automation
# Coax Cable                     202                 236      5  Automation
# Commercial Power Failure      1197                3304     11  Automation
# Coverage                         1                   1      1  Automation
# Customer Equipment Fault       208                 730     10  Automation
# Damage Network                   1                   6      2  Automation
# Employee Error                   5                  32      5  Automation
# Facilities - Environment       331                2253     10  Automation
# Fiber                          357                1671      9  Automation
# Fiber Cut                       43                 220      5  Automation
# Hardware Failure               272                6498     12  Automation
# Hosted Services                  1                   2      1  Automation
# Low RF                          20                  30      1  Automation
# Mother Nature                  105                 772     11  Automation
# No Fault Found                1159               11239     12  Automation
# OSS                             39                 224      4  Automation
# Opened In Error                 72                 443     12  Automation
# Preventive Maintenance Error   181                 385      5  Automation
# Provisioning                   132                 965     11  Automation
# Provisioning System Error        5                  59      6  Automation
# Security Issue                 387                 459      1  Automation
# Software Failure               716               11371     12  Automation
# Switch Maintenance               8                  60      2  Automation
# Third Party                    154                1016      7  Automation
# Unknown                       2137                9790     12  Automation
# User Access                      1                   1      1  Automation
# Vandalism                        4                  27      2  Automation
#
#
#                                freq
# RootCause
# Application Fault               132
# Automation                    15827
# Broadcast Source                734
# Cause Identified              11594
# Cause Not Identified           6082
# Change Management Activity     9836
# Client Software                   2
# Coax Cable                      231
# Commercial Power Failure       3098
# Coverage                          1
# Customer Equipment Fault        702
# Damage Network                    5
# Employee Error                   25
# Facilities - Environment       2054
# Fiber                          1641
# Fiber Cut                       210
# Hardware Failure               5110
# Hosted Services                   2
# Low RF                           30
# Mother Nature                   528
# No Fault Found                10283
# OSS                             206
# Opened In Error                 343
# Preventive Maintenance Error    322
# Provisioning                    797
# Provisioning System Error        44
# Security Issue                  459
# Software Failure              11105
# Switch Maintenance               56
# Third Party                     955
# Unknown                        8752
# User Access                       1
# Vandalism                        26

# %%
# !pip install Jinja2
# Out:
# Requirement already satisfied: Jinja2 in c:\users\sara.khosravi\anaconda3\lib\site-packages (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from Jinja2) (2.1.1)

# %%
pip install Jinja2
# Out:
# Requirement already satisfied: Jinja2 in c:\users\sara.khosravi\anaconda3\lib\site-packages (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from Jinja2) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
! python -m pip install --upgrade pip
! pip install pandas
# Out:
# Requirement already satisfied: pip in c:\users\sara.khosravi\anaconda3\lib\site-packages (22.1.2)
# Requirement already satisfied: pandas in c:\users\sara.khosravi\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
print('no. of Automation')
df[df['RootCause']=='Automation'][['Bot', 'RuleName']].groupby(['Bot']).agg('count').sort_values('RuleName', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Automation
# <style type="text/css">
# #T_2cbaf_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_2cbaf_row1_col0 {
#   background-color: #ffe719;
#   color: #000000;
# }
# #T_2cbaf_row2_col0 {
#   background-color: #edf759;
#   color: #000000;
# }
# #T_2cbaf_row3_col0, #T_2cbaf_row4_col0 {
#   background-color: #e8fc6c;
#   color: #000000;
# }
# #T_2cbaf_row5_col0 {
#   background-color: #e7fc6f;
#   color: #000000;
# }
# #T_2cbaf_row6_col0, #T_2cbaf_row7_col0 {
#   background-color: #e6fe74;
#   color: #000000;
# }
# #T_2cbaf_row8_col0, #T_2cbaf_row9_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_2cbaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cbaf_level0_col0" class="col_heading level0 col0" >RuleName</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bot</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cbaf_level0_row0" class="row_heading level0 row0" >DIAGNOSTIC-CASA-UPS-SWITCH-OVER</th>
#       <td id="T_2cbaf_row0_col0" class="data row0 col0" >8042</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row1" class="row_heading level0 row1" >DIAGNOSTIC_TWAMP</th>
#       <td id="T_2cbaf_row1_col0" class="data row1 col0" >2352</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row2" class="row_heading level0 row2" >DIAGNOSTIC-ARBOR-ALARM</th>
#       <td id="T_2cbaf_row2_col0" class="data row2 col0" >1074</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row3" class="row_heading level0 row3" >DIAGNOSTIC IPRAN LINK DOWN MAJOR ALARMS</th>
#       <td id="T_2cbaf_row3_col0" class="data row3 col0" >677</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row4" class="row_heading level0 row4" >RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED</th>
#       <td id="T_2cbaf_row4_col0" class="data row4 col0" >676</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row5" class="row_heading level0 row5" >DIAGNOSTIC-TLAN-RECTIFIER</th>
#       <td id="T_2cbaf_row5_col0" class="data row5 col0" >633</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row6" class="row_heading level0 row6" >DIAGNOSTIC-IPRAN-BGP-Peer-Connection-Idle</th>
#       <td id="T_2cbaf_row6_col0" class="data row6 col0" >525</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row7" class="row_heading level0 row7" >DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-ALARMS</th>
#       <td id="T_2cbaf_row7_col0" class="data row7 col0" >524</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row8" class="row_heading level0 row8" >DIAGNOSTIC-TLAN-TEMPERATURE</th>
#       <td id="T_2cbaf_row8_col0" class="data row8 col0" >410</td>
#     </tr>
#     <tr>
#       <th id="T_2cbaf_level0_row9" class="row_heading level0 row9" >DIAGNOSTIC-TLAN-SITE-COMMERCIAL-POWER-FAILURE</th>
#       <td id="T_2cbaf_row9_col0" class="data row9 col0" >402</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('no. of Automation')
df[df['RootCause']=='Automation'][['WorkflowState', 'AutomationStatus']].groupby(['WorkflowState']).agg('count').sort_values('AutomationStatus', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Automation
# <style type="text/css">
# #T_53476_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_53476_row1_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_53476">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53476_level0_col0" class="col_heading level0 col0" >AutomationStatus</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >WorkflowState</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53476_level0_row0" class="row_heading level0 row0" >Closed by Auto Diag</th>
#       <td id="T_53476_row0_col0" class="data row0 col0" >15963</td>
#     </tr>
#     <tr>
#       <th id="T_53476_level0_row1" class="row_heading level0 row1" >Closed by Auto Res/Val</th>
#       <td id="T_53476_row1_col0" class="data row1 col0" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('no. of Automation')
df[df['RootCause']=='Automation'][['Status', 'Resolution']].groupby(['Status']).agg('count').sort_values('Resolution', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Automation
# <style type="text/css">
# #T_e7b88_row0_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_e7b88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7b88_level0_col0" class="col_heading level0 col0" >Resolution</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Status</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7b88_level0_row0" class="row_heading level0 row0" >Closed</th>
#       <td id="T_e7b88_row0_col0" class="data row0 col0" >15974</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('no. of Broadcast Source')
df[df['RootCause']=='Broadcast Source'][['Bot', 'RuleName']].groupby(['Bot']).agg('count').sort_values('RuleName', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Broadcast Source
# <style type="text/css">
# #T_19abd_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_19abd_row1_col0, #T_19abd_row2_col0, #T_19abd_row3_col0, #T_19abd_row4_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_19abd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19abd_level0_col0" class="col_heading level0 col0" >RuleName</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bot</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19abd_level0_row0" class="row_heading level0 row0" >Unknown</th>
#       <td id="T_19abd_row0_col0" class="data row0 col0" >731</td>
#     </tr>
#     <tr>
#       <th id="T_19abd_level0_row1" class="row_heading level0 row1" >DIAGNOSTIC_XRE_ERROR</th>
#       <td id="T_19abd_row1_col0" class="data row1 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_19abd_level0_row2" class="row_heading level0 row2" >DIAGNOSTIC-ERICSSON-LTE-SERVICE-DEGRADED-SECTOR</th>
#       <td id="T_19abd_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_19abd_level0_row3" class="row_heading level0 row3" >DIAGNOSTIC-IPRAN-MPLSLDP-Session-Down</th>
#       <td id="T_19abd_row3_col0" class="data row3 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_19abd_level0_row4" class="row_heading level0 row4" >DIAGNOSTIC-RCBIN-LINK-DOWN</th>
#       <td id="T_19abd_row4_col0" class="data row4 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('no. of Cause Identified')
df[df['RootCause']=='Cause Identified'][['Bot', 'RuleName']].groupby(['Bot']).agg('count').sort_values('RuleName', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Cause Identified
# <style type="text/css">
# #T_03edd_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_03edd_row1_col0 {
#   background-color: #f5f03c;
#   color: #000000;
# }
# #T_03edd_row2_col0 {
#   background-color: #f1f44d;
#   color: #000000;
# }
# #T_03edd_row3_col0 {
#   background-color: #ecf95f;
#   color: #000000;
# }
# #T_03edd_row4_col0, #T_03edd_row5_col0 {
#   background-color: #e7fc6e;
#   color: #000000;
# }
# #T_03edd_row6_col0, #T_03edd_row7_col0, #T_03edd_row8_col0, #T_03edd_row9_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_03edd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03edd_level0_col0" class="col_heading level0 col0" >RuleName</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bot</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03edd_level0_row0" class="row_heading level0 row0" >Unknown</th>
#       <td id="T_03edd_row0_col0" class="data row0 col0" >6377</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row1" class="row_heading level0 row1" >DIAGNOSTIC-RCBIN-LINK-DOWN</th>
#       <td id="T_03edd_row1_col0" class="data row1 col0" >1140</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row2" class="row_heading level0 row2" >DIAGNOSTIC_GENERIC_WITH_CELL_STATUS</th>
#       <td id="T_03edd_row2_col0" class="data row2 col0" >865</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row3" class="row_heading level0 row3" >DIAGNOSTIC-ERICSSON-LTE-SERVICE-DEGRADED-SECTOR</th>
#       <td id="T_03edd_row3_col0" class="data row3 col0" >572</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row4" class="row_heading level0 row4" >DIAGNOSTIC-TLAN-INTEGRATED</th>
#       <td id="T_03edd_row4_col0" class="data row4 col0" >335</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row5" class="row_heading level0 row5" >DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-ALARMS</th>
#       <td id="T_03edd_row5_col0" class="data row5 col0" >322</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row6" class="row_heading level0 row6" >RESOLUTION-NODEB-SERVICE-DEGRADED</th>
#       <td id="T_03edd_row6_col0" class="data row6 col0" >126</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row7" class="row_heading level0 row7" >DIAGNOSTIC LTE PLMN SERVICE UNAVAILABLE</th>
#       <td id="T_03edd_row7_col0" class="data row7 col0" >119</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row8" class="row_heading level0 row8" >DIAGNOSTIC-TLAN-NNMI-RTU-HEARTBEAT</th>
#       <td id="T_03edd_row8_col0" class="data row8 col0" >115</td>
#     </tr>
#     <tr>
#       <th id="T_03edd_level0_row9" class="row_heading level0 row9" >DIAGNOSTIC IPRAN LINK DOWN MAJOR ALARMS</th>
#       <td id="T_03edd_row9_col0" class="data row9 col0" >115</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('no. of Cause Not Identified')
df[df['RootCause']=='Cause Not Identified'][['Bot', 'RuleName']].groupby(['Bot']).agg('count').sort_values('RuleName', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Cause Not Identified
# <style type="text/css">
# #T_4baac_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_4baac_row1_col0, #T_4baac_row2_col0 {
#   background-color: #eafa63;
#   color: #000000;
# }
# #T_4baac_row3_col0 {
#   background-color: #eafa65;
#   color: #000000;
# }
# #T_4baac_row4_col0 {
#   background-color: #e8fb6b;
#   color: #000000;
# }
# #T_4baac_row5_col0 {
#   background-color: #e7fd71;
#   color: #000000;
# }
# #T_4baac_row6_col0 {
#   background-color: #e6fe74;
#   color: #000000;
# }
# #T_4baac_row7_col0 {
#   background-color: #e5fe75;
#   color: #000000;
# }
# #T_4baac_row8_col0 {
#   background-color: #e4ff78;
#   color: #000000;
# }
# #T_4baac_row9_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_4baac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4baac_level0_col0" class="col_heading level0 col0" >RuleName</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bot</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4baac_level0_row0" class="row_heading level0 row0" >Unknown</th>
#       <td id="T_4baac_row0_col0" class="data row0 col0" >3568</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row1" class="row_heading level0 row1" >DIAGNOSTIC-TLAN-INTEGRATED</th>
#       <td id="T_4baac_row1_col0" class="data row1 col0" >276</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row2" class="row_heading level0 row2" >DIAGNOSTIC-RCBIN-LINK-DOWN</th>
#       <td id="T_4baac_row2_col0" class="data row2 col0" >274</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row3" class="row_heading level0 row3" >DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-ALARMS</th>
#       <td id="T_4baac_row3_col0" class="data row3 col0" >268</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row4" class="row_heading level0 row4" >DIAGNOSTIC_GENERIC_WITH_CELL_STATUS</th>
#       <td id="T_4baac_row4_col0" class="data row4 col0" >204</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row5" class="row_heading level0 row5" >DIAGNOSTIC-TLAN-RECTIFIER</th>
#       <td id="T_4baac_row5_col0" class="data row5 col0" >156</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row6" class="row_heading level0 row6" >DIAGNOSTIC-REN-CORE-LINK-DOWN-MAJOR</th>
#       <td id="T_4baac_row6_col0" class="data row6 col0" >130</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row7" class="row_heading level0 row7" >RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED</th>
#       <td id="T_4baac_row7_col0" class="data row7 col0" >120</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row8" class="row_heading level0 row8" >DIAGNOSTIC-NNMI-BLACK-NODE-DOWN</th>
#       <td id="T_4baac_row8_col0" class="data row8 col0" >84</td>
#     </tr>
#     <tr>
#       <th id="T_4baac_level0_row9" class="row_heading level0 row9" >DIAGNOSTIC IPRAN LINK DOWN MAJOR ALARMS</th>
#       <td id="T_4baac_row9_col0" class="data row9 col0" >66</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('no. of Change Management Activity')
df[df['RootCause']=='Change Management Activity'][['Bot', 'RuleName']].groupby(['Bot']).agg('count').sort_values('RuleName', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Change Management Activity
# <style type="text/css">
# #T_d06f8_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_d06f8_row1_col0 {
#   background-color: #fde920;
#   color: #000000;
# }
# #T_d06f8_row2_col0 {
#   background-color: #f0f54e;
#   color: #000000;
# }
# #T_d06f8_row3_col0 {
#   background-color: #eafa66;
#   color: #000000;
# }
# #T_d06f8_row4_col0 {
#   background-color: #e7fc6f;
#   color: #000000;
# }
# #T_d06f8_row5_col0 {
#   background-color: #e7fd71;
#   color: #000000;
# }
# #T_d06f8_row6_col0 {
#   background-color: #e5fe75;
#   color: #000000;
# }
# #T_d06f8_row7_col0 {
#   background-color: #e4ff78;
#   color: #000000;
# }
# #T_d06f8_row8_col0, #T_d06f8_row9_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_d06f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d06f8_level0_col0" class="col_heading level0 col0" >RuleName</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bot</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d06f8_level0_row0" class="row_heading level0 row0" >Unknown</th>
#       <td id="T_d06f8_row0_col0" class="data row0 col0" >5193</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row1" class="row_heading level0 row1" >DIAGNOSTIC-RCBIN-LINK-DOWN</th>
#       <td id="T_d06f8_row1_col0" class="data row1 col0" >1323</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row2" class="row_heading level0 row2" >DIAGNOSTIC_GENERIC_WITH_CELL_STATUS</th>
#       <td id="T_d06f8_row2_col0" class="data row2 col0" >710</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row3" class="row_heading level0 row3" >DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-ALARMS</th>
#       <td id="T_d06f8_row3_col0" class="data row3 col0" >396</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row4" class="row_heading level0 row4" >DIAGNOSTIC-TLAN-INTEGRATED</th>
#       <td id="T_d06f8_row4_col0" class="data row4 col0" >277</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row5" class="row_heading level0 row5" >DIAGNOSTIC-CASA-GENERIC-LINK-STATUS</th>
#       <td id="T_d06f8_row5_col0" class="data row5 col0" >250</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row6" class="row_heading level0 row6" >DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS</th>
#       <td id="T_d06f8_row6_col0" class="data row6 col0" >201</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row7" class="row_heading level0 row7" >DIAGNOSTIC-SBC-REDUNDANCY-ALARMS</th>
#       <td id="T_d06f8_row7_col0" class="data row7 col0" >148</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row8" class="row_heading level0 row8" >DIAGNOSTIC-ERICSSON-LTE-SERVICE-DEGRADED-SECTOR</th>
#       <td id="T_d06f8_row8_col0" class="data row8 col0" >136</td>
#     </tr>
#     <tr>
#       <th id="T_d06f8_level0_row9" class="row_heading level0 row9" >DIAGNOSTIC-EON-LINK-DOWN-ALARMS</th>
#       <td id="T_d06f8_row9_col0" class="data row9 col0" >126</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('no. of Commercial Power Failure')
df[df['RootCause']=='Commercial Power Failure'][['Bot', 'RuleName']].groupby(['Bot']).agg('count').sort_values('RuleName', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Commercial Power Failure
# <style type="text/css">
# #T_314fc_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_314fc_row1_col0 {
#   background-color: #ffbc00;
#   color: #000000;
# }
# #T_314fc_row2_col0 {
#   background-color: #edf759;
#   color: #000000;
# }
# #T_314fc_row3_col0 {
#   background-color: #ecf95f;
#   color: #000000;
# }
# #T_314fc_row4_col0 {
#   background-color: #e7fc6f;
#   color: #000000;
# }
# #T_314fc_row5_col0 {
#   background-color: #e7fd71;
#   color: #000000;
# }
# #T_314fc_row6_col0 {
#   background-color: #e5fe77;
#   color: #000000;
# }
# #T_314fc_row7_col0, #T_314fc_row8_col0 {
#   background-color: #e4ff78;
#   color: #000000;
# }
# #T_314fc_row9_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_314fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_314fc_level0_col0" class="col_heading level0 col0" >RuleName</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bot</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_314fc_level0_row0" class="row_heading level0 row0" >DIAGNOSTIC-TLAN-SITE-COMMERCIAL-POWER-FAILURE</th>
#       <td id="T_314fc_row0_col0" class="data row0 col0" >1743</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row1" class="row_heading level0 row1" >Unknown</th>
#       <td id="T_314fc_row1_col0" class="data row1 col0" >887</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row2" class="row_heading level0 row2" >DIAGNOSTIC-TLAN-INTEGRATED</th>
#       <td id="T_314fc_row2_col0" class="data row2 col0" >164</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row3" class="row_heading level0 row3" >DIAGNOSTIC-TLAN-GENERATOR-RUN</th>
#       <td id="T_314fc_row3_col0" class="data row3 col0" >140</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row4" class="row_heading level0 row4" >DIAGNOSTIC-TLAN-RECTIFIER</th>
#       <td id="T_314fc_row4_col0" class="data row4 col0" >62</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row5" class="row_heading level0 row5" >DIAGNOSTIC-EON-7360-PON-OLT-LOS</th>
#       <td id="T_314fc_row5_col0" class="data row5 col0" >58</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row6" class="row_heading level0 row6" >DIAGNOSTIC-GENERIC-MICROWAVE-MINILINK</th>
#       <td id="T_314fc_row6_col0" class="data row6 col0" >33</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row7" class="row_heading level0 row7" >DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS</th>
#       <td id="T_314fc_row7_col0" class="data row7 col0" >24</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row8" class="row_heading level0 row8" >DIAGNOSTIC_LTE_CELLKPI_DOWNTIME_MANUAL</th>
#       <td id="T_314fc_row8_col0" class="data row8 col0" >22</td>
#     </tr>
#     <tr>
#       <th id="T_314fc_level0_row9" class="row_heading level0 row9" >DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-ALARMS</th>
#       <td id="T_314fc_row9_col0" class="data row9 col0" >14</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Let's check the supplier code for the unknown suppliers
df[df['Bot']=='Unknown']['Bot'].value_counts()
# Out:
# Unknown    41204
# Name: Bot, dtype: int64

# %%
plt.rcParams['figure.figsize']=10,5
sns.countplot(df[df['RootCause']=='Change Management Activity']['WorkflowState'],
             order=df[df['RootCause']=='Change Management Activity']['WorkflowState'].value_counts().head(10).index,
             palette='viridis')
plt.xticks(rotation=90)
plt.title('RootCause with most successful WorkflowState')
plt.show()

# %%
plt.rcParams['figure.figsize']=10,5
sns.countplot(df[df['RootCause']=='Change Management Activity']['RecoveryPrime'],
             order=df[df['RootCause']=='Change Management Activity']['RecoveryPrime'].value_counts().head(10).index,
             palette='viridis')
plt.xticks(rotation=90)
plt.title('RootCause with most successful RecoveryPrime')
plt.show()

# %%
plt.rcParams['figure.figsize']=10,5
sns.countplot(df[df['RootCause']=='Change Management Activity']['RuleName'],
             order=df[df['RootCause']=='Change Management Activity']['RuleName'].value_counts().head(10).index,
             palette='viridis')
plt.xticks(rotation=90)
plt.title('RootCause with most successful RuleName')
plt.show()

# %%
plt.rcParams['figure.figsize']=10,5
sns.countplot(df[df['RootCause']=='Change Management Activity']['Bot'],
             order=df[df['RootCause']=='Change Management Activity']['Bot'].value_counts().head(10).index,
             palette='viridis')
plt.xticks(rotation=90)
plt.title('RootCause with most successful Bot')
plt.show()

# %% [raw]
# plt.rcParams['figure.figsize']=10,5
# sns.countplot(df['Bot'],
#              order=df['Bot'].value_counts().head(10).index,
#               hue=df['RootCause'],
#              palette='magma')
# plt.xticks(rotation=90)
# plt.title('which RecoveryPrime having most successfull Change Management Activity')
# #plt.legend(['Change Management Activity', 'Others'])
# plt.show()

# %% [raw]
# plt.rcParams['figure.figsize']=10,5
# sns.countplot(df['RuleName'],
#              order=df['RuleName'].value_counts().head(10).index,
#               hue=df['RootCause'],
#              palette='magma')
# plt.xticks(rotation=90)
# plt.title('which RecoveryPrime having most successfull Change Management Activity')
# plt.legend(['Change Management Activity', 'Others'])
# plt.show()

# %% [raw]
# plt.rcParams['figure.figsize']=10,5
# sns.countplot(df['RecoveryPrime'],
#              order=df['RecoveryPrime'].value_counts().head(10).index,
#               hue=df['RootCause'],
#              palette='magma')
# plt.xticks(rotation=90)
# plt.title('which RecoveryPrime having most successfull Change Management Activity')
# plt.legend(['Change Management Activity', 'Others'])
# plt.show()

# %% [raw]
# plt.rcParams['figure.figsize']=15,5
#
# plt.subplot(121)
# sns.countplot(df['Bot'],
#              order=df['Bot'].value_counts().head(10).index,
#              palette='dark')
# plt.xticks(rotation=90)
# plt.title('Most of the Flow')
#
# plt.subplot(122)
# sns.countplot(df['RecoveryPrime'],
#              order=df['RecoveryPrime'].value_counts().head(10).index,
#              palette='plasma')
# plt.xticks(rotation=90)
# plt.title('Most of the Recovery Prime')
#
# plt.show()

# %% [raw]
# #let's filter usefull data alone
# df=df[['ImtId',
#        'CreateDate',
#        'RuleName',
#        'RootCause',
#        'Resolution',
#        'RecoveryPrime',
#        'WorkflowState',
#        'EventSource',
#        'Responsibility',
#        'ResponsibilityDepartment',
#        'State',
#        'Status',
#        'Submitter',
#        'SubmitterDepartment',
#        'Bot',
#        'AutomationSuiteName',
#        'AutomationType',
#        'AutomationStatus',
#        'AutomationFramework']]

# %%
#let's filter usefull data alone
df=df[['ImtId',
       'CreateDate',
       'RuleName',
       'RootCause',
       'Resolution', 
       'RecoveryPrime',
       'WorkflowState',
       'Responsibility',
       'ResponsibilityDepartment', 
       'State',
       'Status', 
       'Submitter', 
       'SubmitterDepartment',
       'Bot',
       'AutomationSuiteName',
       'AutomationStatus',
       'AutomationFramework']]

# %%
#let's make a copy of filtered data
df_copy=df.copy()

# %% [raw]
# plt.legend(['Automation','Broadcast Source','Cause Identified','Cause Not Identified','Change Management Activity'
#            ,'Commercial Power Failure','Customer Equipment Fault','Damage Network','Employee Error','Facilities - Environment',
#            'Fiber','AutomationFiber Cut','Hardware Failure','Hosted Services','AutomationMother Nature','AutomationMother Nature',
#             'N/A','No Fault Found','Opened In Error','OSS','Preventive Maintenance Error','Provisioning','Provisioning System Error',
#             'Security Issue','Software Failure','Third Party'
#            ],loc=6,borderaxespad=60)

# %% [raw]
# df.RootCause_NUM = df.RootCause.map(
#                     {
#                         'Automation': 0,
#                         'Broadcast Source': 1,
#                         'Cause Identified': 2,
#                         'Cause Not Identified':3,
#                         'Change Management Activity' :4,
#                         'Commercial Power Failure' : 5,
#                         'Others' : 6
#                     }
#                     )

# %%
# Defining all the conditions inside a function
def condition(x):
    if x == 'Automation':
        return 0
    elif x == 'Broadcast Source':
        return 1
    elif x == 'Cause Identified':
        return 2
    elif x == 'Cause Not Identified':
        return 3
    elif x == 'Change Management Activity':
        return 4
    else:
        return 5
 
# Applying the conditions
df['RootCause_NUM'] = df['RootCause'].apply(condition)
 
print(df['RootCause_NUM'])
# Out:
# 0        3
# 1        5
# 2        5
# 3        1
# 4        5
#         ..
# 96996    5
# 96997    5
# 96998    5
# 96999    5
# 97000    5
# Name: RootCause_NUM, Length: 97100, dtype: int64

# %% [raw]
# df['RootCause'] = df['RootCause'].map(lambda x: 1 if x == 'Automation'
#                                                  elif x == 'Broadcast Source' 2
#                                                  elif x == 'Cause Identified' 3
#                                                  elif x == 'Cause Not Identified' 4
#                                                  elif x == 'Change Management Activity' 5
#                                                  else 0)
# df['RootCause'] = df['RootCause'].astype(int)

# %%
df.RootCause_NUM
# Out:
# 0        3
# 1        5
# 2        5
# 3        1
# 4        5
#         ..
# 96996    5
# 96997    5
# 96998    5
# 96999    5
# 97000    5
# Name: RootCause_NUM, Length: 97100, dtype: int64

# %%
df['ImtId_NUM']=df['ImtId'].astype("category").cat.codes
df['CreateDate_NUM']=df['CreateDate'].astype("category").cat.codes
df['RuleName_NUM']=df['RuleName'].astype("category").cat.codes
#df['RootCause_NUM']=df['RootCause'].astype("category").cat.codes
df['Resolution_NUM']=df['Resolution'].astype("category").cat.codes
df['RecoveryPrime_NUM']=df['RecoveryPrime'].astype("category").cat.codes
df['WorkflowState_NUM']=df['WorkflowState'].astype("category").cat.codes
#df['EventSource_NUM']=df['EventSource'].astype("category").cat.codes
df['Responsibility_NUM']=df['Responsibility'].astype("category").cat.codes
df['ResponsibilityDepartment_NUM']=df['ResponsibilityDepartment'].astype("category").cat.codes
df['State_NUM']=df['State'].astype("category").cat.codes
df['Status_NUM']=df['Status'].astype("category").cat.codes   
df['Submitter_NUM']=df['Submitter'].astype("category").cat.codes 
df['SubmitterDepartment_NUM']=df['SubmitterDepartment'].astype("category").cat.codes 
df['Bot_NUM']=df['Bot'].astype("category").cat.codes 
df['AutomationSuiteName_NUM']=df['AutomationSuiteName'].astype("category").cat.codes 
#df['TeamName_NUM']=df['TeamName'].astype("category").cat.codes 
#df['AutomationType_NUM']=df['AutomationType'].astype("category").cat.codes
df['AutomationStatus_NUM']=df['AutomationStatus'].astype("category").cat.codes 
df['AutomationFramework_NUM']=df['AutomationFramework'].astype("category").cat.codes

# %% [raw]
# corr_matrix=df.corr()

# %%
corr = df.corr()
corr
# Out:
#                               RootCause_NUM  ImtId_NUM  CreateDate_NUM  \
# RootCause_NUM                      1.000000   0.145059        0.153457
# ImtId_NUM                          0.145059   1.000000        0.991515
# CreateDate_NUM                     0.153457   0.991515        1.000000
# RuleName_NUM                       0.267481   0.087740        0.094568
# Resolution_NUM                     0.055952   0.185341        0.188272
# RecoveryPrime_NUM                  0.403556   0.220965        0.227098
# WorkflowState_NUM                  0.707450   0.163208        0.171892
# Responsibility_NUM                -0.137575   0.012717        0.011254
# ResponsibilityDepartment_NUM       0.179831   0.052157        0.053214
# State_NUM                          0.146732   0.203671        0.204114
# Status_NUM                         0.179551   0.245216        0.245807
# Submitter_NUM                      0.129506   0.041158        0.042247
# SubmitterDepartment_NUM            0.125702   0.024598        0.026102
# Bot_NUM                            0.364930   0.130407        0.136629
# AutomationSuiteName_NUM            0.350530   0.132113        0.137924
# AutomationStatus_NUM              -0.279904  -0.108773       -0.110252
# AutomationFramework_NUM            0.250695   0.103379        0.104870
#
#                               RuleName_NUM  Resolution_NUM  RecoveryPrime_NUM  \
# RootCause_NUM                     0.267481        0.055952           0.403556
# ImtId_NUM                         0.087740        0.185341           0.220965
# CreateDate_NUM                    0.094568        0.188272           0.227098
# RuleName_NUM                      1.000000        0.013625           0.161184
# Resolution_NUM                    0.013625        1.000000           0.522960
# RecoveryPrime_NUM                 0.161184        0.522960           1.000000
# WorkflowState_NUM                 0.263138        0.238332           0.644183
# Responsibility_NUM               -0.025933       -0.037734           0.067809
# ResponsibilityDepartment_NUM     -0.008142        0.143875           0.011887
# State_NUM                         0.004242        0.389780           0.243709
# Status_NUM                        0.007064        0.483252           0.302204
# Submitter_NUM                    -0.025975        0.064897          -0.072655
# SubmitterDepartment_NUM          -0.004539        0.054678          -0.069529
# Bot_NUM                           0.239083        0.122193           0.363333
# AutomationSuiteName_NUM           0.442443        0.075789           0.358685
# AutomationStatus_NUM             -0.096747       -0.090377          -0.378213
# AutomationFramework_NUM           0.110070        0.090038           0.363527
#
#                               WorkflowState_NUM  Responsibility_NUM  \
# RootCause_NUM                          0.707450           -0.137575
# ImtId_NUM                              0.163208            0.012717
# CreateDate_NUM                         0.171892            0.011254
# RuleName_NUM                           0.263138           -0.025933
# Resolution_NUM                         0.238332           -0.037734
# RecoveryPrime_NUM                      0.644183            0.067809
# WorkflowState_NUM                      1.000000           -0.066287
# Responsibility_NUM                    -0.066287            1.000000
# ResponsibilityDepartment_NUM           0.115699           -0.033372
# State_NUM                              0.074044            0.020892
# Status_NUM                             0.092239            0.014623
# Submitter_NUM                          0.056269           -0.299068
# SubmitterDepartment_NUM                0.050775           -0.188218
# Bot_NUM                                0.555533            0.109456
# AutomationSuiteName_NUM                0.550833            0.098477
# AutomationStatus_NUM                  -0.579633           -0.070859
# AutomationFramework_NUM                0.558807            0.062591
#
#                               ResponsibilityDepartment_NUM  State_NUM  \
# RootCause_NUM                                     0.179831   0.146732
# ImtId_NUM                                         0.052157   0.203671
# CreateDate_NUM                                    0.053214   0.204114
# RuleName_NUM                                     -0.008142   0.004242
# Resolution_NUM                                    0.143875   0.389780
# RecoveryPrime_NUM                                 0.011887   0.243709
# WorkflowState_NUM                                 0.115699   0.074044
# Responsibility_NUM                               -0.033372   0.020892
# ResponsibilityDepartment_NUM                      1.000000   0.202189
# State_NUM                                         0.202189   1.000000
# Status_NUM                                        0.229883   0.905703
# Submitter_NUM                                     0.196552   0.092205
# SubmitterDepartment_NUM                           0.283132   0.074859
# Bot_NUM                                           0.105948   0.074607
# AutomationSuiteName_NUM                           0.003096   0.043400
# AutomationStatus_NUM                             -0.014485  -0.054227
# AutomationFramework_NUM                          -0.004430   0.045379
#
#                               Status_NUM  Submitter_NUM  \
# RootCause_NUM                   0.179551       0.129506
# ImtId_NUM                       0.245216       0.041158
# CreateDate_NUM                  0.245807       0.042247
# RuleName_NUM                    0.007064      -0.025975
# Resolution_NUM                  0.483252       0.064897
# RecoveryPrime_NUM               0.302204      -0.072655
# WorkflowState_NUM               0.092239       0.056269
# Responsibility_NUM              0.014623      -0.299068
# ResponsibilityDepartment_NUM    0.229883       0.196552
# State_NUM                       0.905703       0.092205
# Status_NUM                      1.000000       0.109549
# Submitter_NUM                   0.109549       1.000000
# SubmitterDepartment_NUM         0.093140       0.774255
# Bot_NUM                         0.088603       0.048992
# AutomationSuiteName_NUM         0.050586      -0.001531
# AutomationStatus_NUM           -0.063664       0.023861
# AutomationFramework_NUM         0.052626      -0.030423
#
#                               SubmitterDepartment_NUM   Bot_NUM  \
# RootCause_NUM                                0.125702  0.364930
# ImtId_NUM                                    0.024598  0.130407
# CreateDate_NUM                               0.026102  0.136629
# RuleName_NUM                                -0.004539  0.239083
# Resolution_NUM                               0.054678  0.122193
# RecoveryPrime_NUM                           -0.069529  0.363333
# WorkflowState_NUM                            0.050775  0.555533
# Responsibility_NUM                          -0.188218  0.109456
# ResponsibilityDepartment_NUM                 0.283132  0.105948
# State_NUM                                    0.074859  0.074607
# Status_NUM                                   0.093140  0.088603
# Submitter_NUM                                0.774255  0.048992
# SubmitterDepartment_NUM                      1.000000  0.043807
# Bot_NUM                                      0.043807  1.000000
# AutomationSuiteName_NUM                     -0.014849  0.780654
# AutomationStatus_NUM                         0.040765 -0.742592
# AutomationFramework_NUM                     -0.045574  0.718025
#
#                               AutomationSuiteName_NUM  AutomationStatus_NUM  \
# RootCause_NUM                                0.350530             -0.279904
# ImtId_NUM                                    0.132113             -0.108773
# CreateDate_NUM                               0.137924             -0.110252
# RuleName_NUM                                 0.442443             -0.096747
# Resolution_NUM                               0.075789             -0.090377
# RecoveryPrime_NUM                            0.358685             -0.378213
# WorkflowState_NUM                            0.550833             -0.579633
# Responsibility_NUM                           0.098477             -0.070859
# ResponsibilityDepartment_NUM                 0.003096             -0.014485
# State_NUM                                    0.043400             -0.054227
# Status_NUM                                   0.050586             -0.063664
# Submitter_NUM                               -0.001531              0.023861
# SubmitterDepartment_NUM                     -0.014849              0.040765
# Bot_NUM                                      0.780654             -0.742592
# AutomationSuiteName_NUM                      1.000000             -0.758595
# AutomationStatus_NUM                        -0.758595              1.000000
# AutomationFramework_NUM                      0.733498             -0.966917
#
#                               AutomationFramework_NUM
# RootCause_NUM                                0.250695
# ImtId_NUM                                    0.103379
# CreateDate_NUM                               0.104870
# RuleName_NUM                                 0.110070
# Resolution_NUM                               0.090038
# RecoveryPrime_NUM                            0.363527
# WorkflowState_NUM                            0.558807
# Responsibility_NUM                           0.062591
# ResponsibilityDepartment_NUM                -0.004430
# State_NUM                                    0.045379
# Status_NUM                                   0.052626
# Submitter_NUM                               -0.030423
# SubmitterDepartment_NUM                     -0.045574
# Bot_NUM                                      0.718025
# AutomationSuiteName_NUM                      0.733498
# AutomationStatus_NUM                        -0.966917
# AutomationFramework_NUM                      1.000000

# %%
plt.figure(figsize=(20,16))
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
                 linewidths=0.2, cmap="YlGnBu",annot=True)
plt.title("Correlation between variables")
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %%
corr["RootCause_NUM"].sort_values(ascending=False)
# Out:
# RootCause_NUM                   1.000000
# WorkflowState_NUM               0.707450
# RecoveryPrime_NUM               0.403556
# Bot_NUM                         0.364930
# AutomationSuiteName_NUM         0.350530
# RuleName_NUM                    0.267481
# AutomationFramework_NUM         0.250695
# ResponsibilityDepartment_NUM    0.179831
# Status_NUM                      0.179551
# CreateDate_NUM                  0.153457
# State_NUM                       0.146732
# ImtId_NUM                       0.145059
# Submitter_NUM                   0.129506
# SubmitterDepartment_NUM         0.125702
# Resolution_NUM                  0.055952
# Responsibility_NUM             -0.137575
# AutomationStatus_NUM           -0.279904
# Name: RootCause_NUM, dtype: float64

# %% [raw]
# df['ImtId_NUM']=df['ImtId'].astype("category").cat.codes
# df['CreateDate_NUM']=df['CreateDate'].astype("category").cat.codes
# df['RuleName_NUM']=df['RuleName'].astype("category").cat.codes
# df['RootCause_NUM']=df['RootCause'].astype("category").cat.codes
# df['Resolution_NUM']=df['Resolution'].astype("category").cat.codes
# df['RecoveryPrime_NUM']=df['RecoveryPrime'].astype("category").cat.codes
# df['WorkflowState_NUM']=df['WorkflowState'].astype("category").cat.codes
# #df['EventSource_NUM']=df['EventSource'].astype("category").cat.codes
# df['Responsibility_NUM']=df['Responsibility'].astype("category").cat.codes
# df['ResponsibilityDepartment_NUM']=df['ResponsibilityDepartment'].astype("category").cat.codes
# df['State_NUM']=df['State'].astype("category").cat.codes
# df['Status_NUM']=df['Status'].astype("category").cat.codes
# df['Submitter_NUM']=df['Submitter'].astype("category").cat.codes
# df['SubmitterDepartment_NUM']=df['SubmitterDepartment'].astype("category").cat.codes
# df['Bot_NUM']=df['Bot'].astype("category").cat.codes
# df['AutomationSuiteName_NUM']=df['AutomationSuiteName'].astype("category").cat.codes
# #df['TeamName_NUM']=df['TeamName'].astype("category").cat.codes
# #df['AutomationType_NUM']=df['AutomationType'].astype("category").cat.codes
# df['AutomationStatus_NUM']=df['AutomationStatus'].astype("category").cat.codes
# df['AutomationFramework_NUM']=df['AutomationFramework'].astype("category").cat.codes

# %%
# Let's check whether having AutomationType's number making any impact on RootCause
df['Resolution_NUM'].values[df['Resolution_NUM'].values>0]=1
df['Resolution_NUM'].fillna(0, inplace=True)
df[df['Resolution_NUM']==0]['RootCause_NUM'].value_counts()
# Out:
# 5    41
# Name: RootCause_NUM, dtype: int64

# %%
# Let's check whether having Bot_NUM's number making any impact on RootCause
df['Bot_NUM'].values[df['Bot_NUM'].values>0]=1
df['Bot_NUM'].fillna(0, inplace=True)
df[df['Bot_NUM']==0]['RootCause_NUM'].value_counts()
# Out:
# 0    677
# 5    393
# 2    115
# 4     85
# 3     66
# Name: RootCause_NUM, dtype: int64

# %%
# Let's check whether having Bot_NUM's number making any impact on RootCause
df['RuleName_NUM'].values[df['RuleName_NUM'].values>0]=1
df['RuleName_NUM'].fillna(0, inplace=True)
df[df['RuleName_NUM']==0]['RootCause_NUM'].value_counts()
# Out:
# 4    182
# 5     94
# 3     18
# 2      6
# Name: RootCause_NUM, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['ImtId', 'CreateDate', 'RuleName', 'RootCause', 'Resolution',
#        'RecoveryPrime', 'WorkflowState', 'Responsibility',
#        'ResponsibilityDepartment', 'State', 'Status', 'Submitter',
#        'SubmitterDepartment', 'Bot', 'AutomationSuiteName', 'AutomationStatus',
#        'AutomationFramework', 'RootCause_NUM', 'ImtId_NUM', 'CreateDate_NUM',
#        'RuleName_NUM', 'Resolution_NUM', 'RecoveryPrime_NUM',
#        'WorkflowState_NUM', 'Responsibility_NUM',
#        'ResponsibilityDepartment_NUM', 'State_NUM', 'Status_NUM',
#        'Submitter_NUM', 'SubmitterDepartment_NUM', 'Bot_NUM',
#        'AutomationSuiteName_NUM', 'AutomationStatus_NUM',
#        'AutomationFramework_NUM'],
#       dtype='object')

# %% [raw]
# #x = df.drop(cols, axis=1, inplace=True)
# #x=df.drop(['RootCause','ImtId','CreateDate','RuleName','Resolution','RecoveryPrime','WorkflowState',
# #           'Responsibility','ResponsibilityDepartment','State','Status','Submitter','SubmitterDepartment'
# #          'Bot','AutomationSuiteName','AutomationStatus','AutomationFramework'], axis = 1, inplace=True)
# #y=df['RootCause_NUM'].values

# %%
cols = ['RootCause','ImtId','CreateDate','RuleName','Resolution','RecoveryPrime','WorkflowState',
        'Responsibility','ResponsibilityDepartment','State','Status','Submitter','SubmitterDepartment',
        'Bot','AutomationSuiteName','AutomationStatus','AutomationFramework']


#Splitting dataset into labels and features
X = df.drop(columns = cols)
y = df.RootCause_NUM

# %%
#Splitting dataset into labels and features
X = df.drop(columns = ['RootCause_NUM','RootCause','ImtId','CreateDate','RuleName','Resolution','RecoveryPrime','WorkflowState',
        'Responsibility','ResponsibilityDepartment','State','Status','Submitter','SubmitterDepartment',
        'Bot','AutomationSuiteName','AutomationStatus','AutomationFramework','ImtId_NUM'])
y = df.RootCause_NUM

# %%
X.head()
# Out:
#    CreateDate_NUM  RuleName_NUM  Resolution_NUM  RecoveryPrime_NUM  \
# 0               0             1               1                  2
# 1               1             1               1                  3
# 2               2             1               1                  2
# 3               3             1               1                  3
# 4               4             1               1                  3
#
#    WorkflowState_NUM  Responsibility_NUM  ResponsibilityDepartment_NUM  \
# 0                  6                  22                             9
# 1                  6                  15                            17
# 2                  6                  21                            44
# 3                  6                  15                            18
# 4                  5                  15                            19
#
#    State_NUM  Status_NUM  Submitter_NUM  SubmitterDepartment_NUM  Bot_NUM  \
# 0          1           0              5                        3        1
# 1          1           0              0                        0        1
# 2          1           0              0                        0        1
# 3          1           0              0                        0        1
# 4          1           0              0                        0        1
#
#    AutomationSuiteName_NUM  AutomationStatus_NUM  AutomationFramework_NUM
# 0                       98                     0                        1
# 1                       98                     0                        1
# 2                       98                     0                        1
# 3                       98                     0                        1
# 4                       12                     1                        0

# %%
y.head()
# Out:
# 0    3
# 1    5
# 2    5
# 3    1
# 4    5
# Name: RootCause_NUM, dtype: int64

# %%
### It will zero variance features
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(X)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
X.columns[var_thres.get_support()]
# Out:
# Index(['CreateDate_NUM', 'RuleName_NUM', 'Resolution_NUM', 'RecoveryPrime_NUM',
#        'WorkflowState_NUM', 'Responsibility_NUM',
#        'ResponsibilityDepartment_NUM', 'State_NUM', 'Status_NUM',
#        'Submitter_NUM', 'SubmitterDepartment_NUM', 'Bot_NUM',
#        'AutomationSuiteName_NUM', 'AutomationStatus_NUM',
#        'AutomationFramework_NUM'],
#       dtype='object')

# %%
constant_columns = [column for column in X.columns
                    if column not in X.columns[var_thres.get_support()]]

print(len(constant_columns))
# Out:
# 0

# %%
for feature in constant_columns:
     print(feature)

# %%
X=X.drop(constant_columns,axis=1)

# %%
X.corr()
# Out:
#                               CreateDate_NUM  RuleName_NUM  Resolution_NUM  \
# CreateDate_NUM                      1.000000     -0.013508        0.009782
# RuleName_NUM                       -0.013508      1.000000       -0.001144
# Resolution_NUM                      0.009782     -0.001144        1.000000
# RecoveryPrime_NUM                   0.227098     -0.020173        0.014086
# WorkflowState_NUM                   0.171892     -0.040436       -0.007961
# Responsibility_NUM                  0.011254      0.007594       -0.003098
# ResponsibilityDepartment_NUM        0.053214      0.001165       -0.019646
# State_NUM                           0.204114      0.009066        0.004003
# Status_NUM                          0.245807      0.011333        0.004871
# Submitter_NUM                       0.042247      0.012770       -0.016104
# SubmitterDepartment_NUM             0.026102      0.012045       -0.029922
# Bot_NUM                             0.010042     -0.006575       -0.002428
# AutomationSuiteName_NUM             0.137924     -0.049187       -0.005348
# AutomationStatus_NUM               -0.110252      0.064840        0.002639
# AutomationFramework_NUM             0.104870     -0.057911       -0.001690
#
#                               RecoveryPrime_NUM  WorkflowState_NUM  \
# CreateDate_NUM                         0.227098           0.171892
# RuleName_NUM                          -0.020173          -0.040436
# Resolution_NUM                         0.014086          -0.007961
# RecoveryPrime_NUM                      1.000000           0.644183
# WorkflowState_NUM                      0.644183           1.000000
# Responsibility_NUM                     0.067809          -0.066287
# ResponsibilityDepartment_NUM           0.011887           0.115699
# State_NUM                              0.243709           0.074044
# Status_NUM                             0.302204           0.092239
# Submitter_NUM                         -0.072655           0.056269
# SubmitterDepartment_NUM               -0.069529           0.050775
# Bot_NUM                                0.081333           0.116637
# AutomationSuiteName_NUM                0.358685           0.550833
# AutomationStatus_NUM                  -0.378213          -0.579633
# AutomationFramework_NUM                0.363527           0.558807
#
#                               Responsibility_NUM  \
# CreateDate_NUM                          0.011254
# RuleName_NUM                            0.007594
# Resolution_NUM                         -0.003098
# RecoveryPrime_NUM                       0.067809
# WorkflowState_NUM                      -0.066287
# Responsibility_NUM                      1.000000
# ResponsibilityDepartment_NUM           -0.033372
# State_NUM                               0.020892
# Status_NUM                              0.014623
# Submitter_NUM                          -0.299068
# SubmitterDepartment_NUM                -0.188218
# Bot_NUM                                 0.005650
# AutomationSuiteName_NUM                 0.098477
# AutomationStatus_NUM                   -0.070859
# AutomationFramework_NUM                 0.062591
#
#                               ResponsibilityDepartment_NUM  State_NUM  \
# CreateDate_NUM                                    0.053214   0.204114
# RuleName_NUM                                      0.001165   0.009066
# Resolution_NUM                                   -0.019646   0.004003
# RecoveryPrime_NUM                                 0.011887   0.243709
# WorkflowState_NUM                                 0.115699   0.074044
# Responsibility_NUM                               -0.033372   0.020892
# ResponsibilityDepartment_NUM                      1.000000   0.202189
# State_NUM                                         0.202189   1.000000
# Status_NUM                                        0.229883   0.905703
# Submitter_NUM                                     0.196552   0.092205
# SubmitterDepartment_NUM                           0.283132   0.074859
# Bot_NUM                                           0.017334   0.019407
# AutomationSuiteName_NUM                           0.003096   0.043400
# AutomationStatus_NUM                             -0.014485  -0.054227
# AutomationFramework_NUM                          -0.004430   0.045379
#
#                               Status_NUM  Submitter_NUM  \
# CreateDate_NUM                  0.245807       0.042247
# RuleName_NUM                    0.011333       0.012770
# Resolution_NUM                  0.004871      -0.016104
# RecoveryPrime_NUM               0.302204      -0.072655
# WorkflowState_NUM               0.092239       0.056269
# Responsibility_NUM              0.014623      -0.299068
# ResponsibilityDepartment_NUM    0.229883       0.196552
# State_NUM                       0.905703       0.092205
# Status_NUM                      1.000000       0.109549
# Submitter_NUM                   0.109549       1.000000
# SubmitterDepartment_NUM         0.093140       0.774255
# Bot_NUM                         0.024226       0.027095
# AutomationSuiteName_NUM         0.050586      -0.001531
# AutomationStatus_NUM           -0.063664       0.023861
# AutomationFramework_NUM         0.052626      -0.030423
#
#                               SubmitterDepartment_NUM   Bot_NUM  \
# CreateDate_NUM                               0.026102  0.010042
# RuleName_NUM                                 0.012045 -0.006575
# Resolution_NUM                              -0.029922 -0.002428
# RecoveryPrime_NUM                           -0.069529  0.081333
# WorkflowState_NUM                            0.050775  0.116637
# Responsibility_NUM                          -0.188218  0.005650
# ResponsibilityDepartment_NUM                 0.283132  0.017334
# State_NUM                                    0.074859  0.019407
# Status_NUM                                   0.093140  0.024226
# Submitter_NUM                                0.774255  0.027095
# SubmitterDepartment_NUM                      1.000000  0.025555
# Bot_NUM                                      0.025555  1.000000
# AutomationSuiteName_NUM                     -0.014849  0.130469
# AutomationStatus_NUM                         0.040765 -0.101410
# AutomationFramework_NUM                     -0.045574  0.098055
#
#                               AutomationSuiteName_NUM  AutomationStatus_NUM  \
# CreateDate_NUM                               0.137924             -0.110252
# RuleName_NUM                                -0.049187              0.064840
# Resolution_NUM                              -0.005348              0.002639
# RecoveryPrime_NUM                            0.358685             -0.378213
# WorkflowState_NUM                            0.550833             -0.579633
# Responsibility_NUM                           0.098477             -0.070859
# ResponsibilityDepartment_NUM                 0.003096             -0.014485
# State_NUM                                    0.043400             -0.054227
# Status_NUM                                   0.050586             -0.063664
# Submitter_NUM                               -0.001531              0.023861
# SubmitterDepartment_NUM                     -0.014849              0.040765
# Bot_NUM                                      0.130469             -0.101410
# AutomationSuiteName_NUM                      1.000000             -0.758595
# AutomationStatus_NUM                        -0.758595              1.000000
# AutomationFramework_NUM                      0.733498             -0.966917
#
#                               AutomationFramework_NUM
# CreateDate_NUM                               0.104870
# RuleName_NUM                                -0.057911
# Resolution_NUM                              -0.001690
# RecoveryPrime_NUM                            0.363527
# WorkflowState_NUM                            0.558807
# Responsibility_NUM                           0.062591
# ResponsibilityDepartment_NUM                -0.004430
# State_NUM                                    0.045379
# Status_NUM                                   0.052626
# Submitter_NUM                               -0.030423
# SubmitterDepartment_NUM                     -0.045574
# Bot_NUM                                      0.098055
# AutomationSuiteName_NUM                      0.733498
# AutomationStatus_NUM                        -0.966917
# AutomationFramework_NUM                      1.000000

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(20,15))
cor = X.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X, 0.7)
len(set(corr_features))
# Out:
# 4

# %%
corr_features
# Out:
# {'AutomationFramework_NUM',
#  'AutomationStatus_NUM',
#  'Status_NUM',
#  'SubmitterDepartment_NUM'}

# %%
#X_train.drop(corr_features,axis=1)
#X_test.drop(corr_features,axis=1)
X.drop(corr_features,axis=1)
# Out:
#        CreateDate_NUM  RuleName_NUM  Resolution_NUM  RecoveryPrime_NUM  \
# 0                   0             1               1                  2
# 1                   1             1               1                  3
# 2                   2             1               1                  2
# 3                   3             1               1                  3
# 4                   4             1               1                  3
# ...               ...           ...             ...                ...
# 96996           96946             1               1                  6
# 96997           96947             1               1                  3
# 96998           96948             1               1                  3
# 96999           96949             1               1                  3
# 97000           96950             1               1                  3
#
#        WorkflowState_NUM  Responsibility_NUM  ResponsibilityDepartment_NUM  \
# 0                      6                  22                             9
# 1                      6                  15                            17
# 2                      6                  21                            44
# 3                      6                  15                            18
# 4                      5                  15                            19
# ...                  ...                 ...                           ...
# 96996                  6                  22                             7
# 96997                  5                  15                            20
# 96998                  5                  15                            20
# 96999                  5                  15                            19
# 97000                  5                  15                            19
#
#        State_NUM  Submitter_NUM  Bot_NUM  AutomationSuiteName_NUM
# 0              1              5        1                       98
# 1              1              0        1                       98
# 2              1              0        1                       98
# 3              1              0        1                       98
# 4              1              0        1                       12
# ...          ...            ...      ...                      ...
# 96996          3              3        1                       98
# 96997          1              0        1                       33
# 96998          1              0        1                       33
# 96999          1              0        1                        1
# 97000          1              0        1                       60
#
# [97100 rows x 11 columns]

# %%
# DATA PREPROCESSING - Scaling Data

#standardizing all the columns
sc=StandardScaler()
scaled=sc.fit_transform(X)

#converted to dataframe to work easily on columns
X_scaled=pd.DataFrame(scaled, columns=X.columns)
#print(data)

# %%
from sklearn.preprocessing import StandardScaler

#to_scale=df_cln.select_dtypes(include='number').columns.tolist()[1:-1]
sc=StandardScaler()
scaled=sc.fit_transform(X)
x_scl=pd.DataFrame(scaled, columns=X.columns)

# %%
#check weathear data is standardized or not
plt.subplot(121)
plt.ylim(-1,1)

means=[]
for i in range(x_scl.shape[1]):
    means.append(np.mean(x_scl.iloc[:,i]))
plt.plot(means, scaley=False)
plt.title('Means of scaled features')

plt.subplot(122)
plt.ylim(0,2)
vars=[]
for i in range(x_scl.shape[1]):
    vars.append(np.var(x_scl.iloc[:,i]))
plt.plot(vars, scaley=False)
plt.title('Varience of scaled features')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaled_data=scaler.transform(X)

# %%
scaled_data
# Out:
# array([[-1.73011125,  0.05567022,  0.02055294, ...,  0.88354848,
#         -1.1647177 ,  1.0402542 ],
#        [-1.73007553,  0.05567022,  0.02055294, ...,  0.88354848,
#         -1.1647177 ,  1.0402542 ],
#        [-1.73003981,  0.05567022,  0.02055294, ...,  0.88354848,
#         -1.1647177 ,  1.0402542 ],
#        ...,
#        [ 1.73306796,  0.05567022,  0.02055294, ..., -0.98934634,
#          0.85857715, -0.83017305],
#        [ 1.73310368,  0.05567022,  0.02055294, ..., -1.91138687,
#          0.85857715, -0.83017305],
#        [ 1.7331394 ,  0.05567022,  0.02055294, ..., -0.21137465,
#          0.85857715, -0.83017305]])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (97100, 15)

# %%
x_pca.shape
# Out:
# (97100, 2)

# %%
scaled_data
# Out:
# array([[-1.73011125,  0.05567022,  0.02055294, ...,  0.88354848,
#         -1.1647177 ,  1.0402542 ],
#        [-1.73007553,  0.05567022,  0.02055294, ...,  0.88354848,
#         -1.1647177 ,  1.0402542 ],
#        [-1.73003981,  0.05567022,  0.02055294, ...,  0.88354848,
#         -1.1647177 ,  1.0402542 ],
#        ...,
#        [ 1.73306796,  0.05567022,  0.02055294, ..., -0.98934634,
#          0.85857715, -0.83017305],
#        [ 1.73310368,  0.05567022,  0.02055294, ..., -1.91138687,
#          0.85857715, -0.83017305],
#        [ 1.7331394 ,  0.05567022,  0.02055294, ..., -0.21137465,
#          0.85857715, -0.83017305]])

# %%
x_pca
# Out:
# array([[ 1.17702228,  0.35059176],
#        [ 1.33741752, -1.26266214],
#        [ 1.36691434, -0.53984781],
#        ...,
#        [-1.03005454,  0.20769289],
#        [-1.43437851,  0.2853017 ],
#        [-0.69917515,  0.07792965]])

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df['RootCause_NUM'])
plt.xlabel('First principle component')
plt.ylabel('Second principle component')
# Out:
# Text(0, 0.5, 'Second principle component')

# %% [markdown]
# ## '''''''''''''''''''''''''''''''''''''''''''''''' Data Exploration Analyasis Step TWO"'''''''''''''''''''''''''''''''''''''''''''''''''

# %%
# DATA PREPROCESSING - Scaling Data

#standardizing all the columns
sc=StandardScaler()
scaled=sc.fit_transform(X)

#converted to dataframe to work easily on columns
X_scaled=pd.DataFrame(scaled, columns=X.columns)
#print(data)

# %%
#check weathear data is standardized or not
plt.subplot(121)
plt.ylim(-1,1)

means=[]
for i in range(X_scaled.shape[1]):
    means.append(np.mean(X_scaled.iloc[:,i]))
plt.plot(means, scaley=False)
plt.title('Means of scaled features')

plt.subplot(122)
plt.ylim(0,2)
vars=[]
for i in range(X_scaled.shape[1]):
    vars.append(np.var(X_scaled.iloc[:,i]))
plt.plot(vars, scaley=False)
plt.title('Varience of scaled features')
plt.show()

# %% [markdown]
# ========================================================================================================================
#
# # --------------------------------   PART TWO MODEL BUILDING   -------------------------------
#
# ========================================================================================================================

# %% [markdown]
# *******************************************************************************************************************************
# ###############################################################################################################################
#
# # ''''''''''''''''''''''...Data Handling - Predictive / Supervised Learning...''''''''''''''''''''
#
# ###############################################################################################################################
# *******************************************************************************************************************************
#
# ## 1. Root Cause Analysis by Implementing Mechine Learning Algorithms
#
# ###############################################################################################################################

# %%
#scaling data is necessary for making gradient descent faster 
sc = StandardScaler()
X = pd.DataFrame(sc.fit_transform(x_pca))
y = pd.Series(y)

# %%
#For cross-validation using train-test split ( TEST-SIZE = 30% )
X_train, X_test, y_train, y_test = train_test_split(x_pca,y,random_state=0)

# %%
print("X_train shape {}, len {}.".format(X_train.shape,len(X_train)))
print("X_test shape {}, len {}.".format(X_test.shape,len(X_test)))
print("y_train shape {}, len {}.".format(y_train.shape,len(y_train)))
print("y_test shape {}, len {}.".format(y_test.shape,len(y_test)))
# Out:
# X_train shape (72825, 2), len 72825.
# X_test shape (24275, 2), len 24275.
# y_train shape (72825,), len 72825.
# y_test shape (24275,), len 24275.

# %% [markdown]
# ### 2.1. MACRO FOR CALCULATING FOR CALCULATING  Precision, Recall and F1

# %% [raw]
# ********************************** .....MACRO FOR CALCULATING  Precision, Recall and F1.....***********************************

# %%
#CREATE MACRO
results_df = pd.DataFrame()
columns = ["Model", "Cross Val Score", "pre_macro", "recall_macro", "f1_macro", "f1_macro_manual"]

def evaluate(true, predicted):
    pre_macro = metrics.precision_score(true, predicted, average="macro")
    recall_macro = metrics.recall_score(true, predicted, average="macro")
    f1_macro = metrics.f1_score(true, predicted, average="macro")
    f1_score_raw = metrics.f1_score(true, predicted, average=None)
    f1_macro_manual = f1_score_raw.mean()
    return pre_macro, recall_macro, f1_macro, f1_macro_manual

def append_results(model_name, model, results_df, y_test, pred):
    results_append_df = pd.DataFrame(data=[[model_name, *evaluate(y_test, pred), cross_val_score(model, X, y,cv=5).mean()]], columns=columns)
    results_df = results_df.append(results_append_df, ignore_index = True)
    return results_df

# %% [markdown]
# ### 2.2.1. KNN Model

# %% [raw]
# ***************************************************.....KNN Model.....*********************************************************

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
pred_knn = knn.predict(X_test)
score_knn = accuracy_score(y_test,pred_knn)

# %%
print('confusion_matrix KNN      :\n', metrics.confusion_matrix(y_test, pred_knn))
print('---------------------------------------------------------------------------------------------------------------------\n')
print('classification_report KNN :\n',metrics.classification_report(y_test, pred_knn))
# Out:
# confusion_matrix KNN      :
#  [[ 3994     0     0     0     0    26]
#  [    0    84     0     6     0    95]
#  [    0     0  2476    17   204   230]
#  [    4     6    30   612   105   847]
#  [    4     2   258   105  1564   665]
#  [   67    63   313   486   498 11514]]
# ---------------------------------------------------------------------------------------------------------------------
#
# classification_report KNN :
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4020
#            1       0.54      0.45      0.49       185
#            2       0.80      0.85      0.82      2927
#            3       0.50      0.38      0.43      1604
#            4       0.66      0.60      0.63      2598
#            5       0.86      0.89      0.87     12941
#
#     accuracy                           0.83     24275
#    macro avg       0.72      0.69      0.71     24275
# weighted avg       0.83      0.83      0.83     24275

# %% [markdown]
# ### 2.2.2. Logestic Regression Model

# %% [raw]
# **********************************************.....Logestic Regression Model.....*********************************************

# %%
# Train model
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
pred_log = log_reg.predict(X_test)
score_log = accuracy_score(y_test,pred_log)

# %%
print('confusion_matrix LogisticRegression      :\n', metrics.confusion_matrix(y_test, pred_log))
print('------------------------------------------------------------------------------------------------------------------\n')
print('classification_report LogisticRegression :\n',metrics.classification_report(y_test, pred_log))
# Out:
# confusion_matrix LogisticRegression      :
#  [[ 3791     0     0     0     0   229]
#  [    0     0     0     0     0   185]
#  [    4     0     0     0     0  2923]
#  [   17     0     0     0     0  1587]
#  [   15     0     0     0     0  2583]
#  [  224     0     0     0     0 12717]]
# ------------------------------------------------------------------------------------------------------------------
#
# classification_report LogisticRegression :
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4020
#            1       0.00      0.00      0.00       185
#            2       0.00      0.00      0.00      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.63      0.98      0.77     12941
#
#     accuracy                           0.68     24275
#    macro avg       0.26      0.32      0.28     24275
# weighted avg       0.49      0.68      0.56     24275

# %%
log_reg2 = LogisticRegression(solver='saga', # you can  add max_iter=500,tol=0.001,
                           class_weight={False:1, True:9})
log_reg2.fit(X_train, y_train)
pred_log2 = log_reg.predict(X_test)
score_log2 = accuracy_score(y_test,pred_log2)

# %%
print('confusion_matrix LogisticRegression      :\n', metrics.confusion_matrix(y_test, pred_log2))
print('------------------------------------------------------------------------------------------------------------------\n')
print('classification_report LogisticRegression :\n',metrics.classification_report(y_test, pred_log2))
# Out:
# confusion_matrix LogisticRegression      :
#  [[ 3791     0     0     0     0   229]
#  [    0     0     0     0     0   185]
#  [    4     0     0     0     0  2923]
#  [   17     0     0     0     0  1587]
#  [   15     0     0     0     0  2583]
#  [  224     0     0     0     0 12717]]
# ------------------------------------------------------------------------------------------------------------------
#
# classification_report LogisticRegression :
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      4020
#            1       0.00      0.00      0.00       185
#            2       0.00      0.00      0.00      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.63      0.98      0.77     12941
#
#     accuracy                           0.68     24275
#    macro avg       0.26      0.32      0.28     24275
# weighted avg       0.49      0.68      0.56     24275

# %% [markdown]
# ### 2.2.3. SVC Model

# %% [raw]
# ****************************************************.....SVC Model.....******************************************************

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,y_train)
pred_svc = svc.predict(X_test)
score_svc = accuracy_score(y_test,pred_svc)

# %%
print('confusion_matrix SVC      :\n', metrics.confusion_matrix(y_test, pred_svc))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report SVC :\n',metrics.classification_report(y_test, pred_svc))
# Out:
# confusion_matrix SVC      :
#  [[ 3751     0     0     0     0   269]
#  [    0     0    53     0     0   132]
#  [    3     0   121     0     0  2803]
#  [   10     0     5     0     0  1589]
#  [    7     0     8     0     0  2583]
#  [  168     0   178     0     0 12595]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report SVC :
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      4020
#            1       0.00      0.00      0.00       185
#            2       0.33      0.04      0.07      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.63      0.97      0.77     12941
#
#     accuracy                           0.68     24275
#    macro avg       0.32      0.32      0.30     24275
# weighted avg       0.53      0.68      0.57     24275

# %% [markdown]
# ### 2.2.4. Random Forest Model

# %% [raw]
# ************************************************.....Random Forest Model......*************************************************

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
pred_rfc = rfc.predict(X_test)
score_rfc = accuracy_score(y_test,pred_rfc)

# %%
print('confusion_matrix RandomForest      :\n', metrics.confusion_matrix(y_test, pred_rfc))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report RandomForest :\n',metrics.classification_report(y_test, pred_rfc))
# Out:
# confusion_matrix RandomForest      :
#  [[ 3994     0     0     0     0    26]
#  [    0   111     2     6     1    65]
#  [    0     0  2563    14   130   220]
#  [    3     4    24   747    86   740]
#  [    4     1   157    74  1782   580]
#  [   53    54   234   504   398 11698]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report RandomForest :
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4020
#            1       0.65      0.60      0.63       185
#            2       0.86      0.88      0.87      2927
#            3       0.56      0.47      0.51      1604
#            4       0.74      0.69      0.71      2598
#            5       0.88      0.90      0.89     12941
#
#     accuracy                           0.86     24275
#    macro avg       0.78      0.75      0.77     24275
# weighted avg       0.86      0.86      0.86     24275

# %% [markdown]
# ### 2.2.5. Ada Boost Model

# %% [raw]
# **************************************************.....Ada Boost Model......***************************************************

# %%
from sklearn.ensemble import AdaBoostClassifier
adab = AdaBoostClassifier()
adab.fit(X_train,y_train)
pred_adab = adab.predict(X_test)
score_adab = accuracy_score(y_test,pred_adab)

# %%
print('confusion_matrix AdaBoost      :\n', metrics.confusion_matrix(y_test, pred_adab))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report AdaBoost :\n',metrics.classification_report(y_test, pred_adab))
# Out:
# confusion_matrix AdaBoost      :
#  [[3926    0    0    0    0   94]
#  [   0  182    3    0    0    0]
#  [   7 1626 1233    0    0   61]
#  [  48  810  603    0    0  143]
#  [  54 1128 1248    0    0  168]
#  [ 484 4836 6191    0    0 1430]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report AdaBoost :
#                precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      4020
#            1       0.02      0.98      0.04       185
#            2       0.13      0.42      0.20      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.75      0.11      0.19     12941
#
#     accuracy                           0.28     24275
#    macro avg       0.30      0.42      0.23     24275
# weighted avg       0.56      0.28      0.28     24275

# %% [markdown]
# ### 2.2.6. Ridge Classification Model

# %% [raw]
# **********************************************.....Ridge Classification Model......********************************************

# %%
from sklearn.linear_model import RidgeClassifier

# %%
ridge_reg = RidgeClassifier()
ridge_reg.fit(X_train, y_train)
pred_ridge = ridge_reg.predict(X_test)

# %%
print('confusion_matrix Ridge Classification      :\n', metrics.confusion_matrix(y_test, pred_ridge))
print('---------------------------------------------------------------------------------------------------------------------\n')
print('classification_report Ridge Classification :\n',metrics.classification_report(y_test, pred_ridge))
# Out:
# confusion_matrix Ridge Classification      :
#  [[ 3836     0     0     0     0   184]
#  [    0     0     0     0     0   185]
#  [    6     0     0     0     0  2921]
#  [   22     0     0     0     0  1582]
#  [   18     0     0     0     0  2580]
#  [  265     0     0     0     0 12676]]
# ---------------------------------------------------------------------------------------------------------------------
#
# classification_report Ridge Classification :
#                precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      4020
#            1       0.00      0.00      0.00       185
#            2       0.00      0.00      0.00      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.63      0.98      0.77     12941
#
#     accuracy                           0.68     24275
#    macro avg       0.26      0.32      0.28     24275
# weighted avg       0.49      0.68      0.56     24275

# %% [markdown]
# ### 2.2.7. Decision Tree Regressor Model

# %% [raw]
# ****************************************.....Decision Tree Classifier Model......*********************************************

# %%
dtree = tree.DecisionTreeClassifier()
dtree.fit(X_train, y_train)
pred_dtree = dtree.predict(X_test)

# %%
print('confusion_matrix Decision Tree Classifier      :\n', metrics.confusion_matrix(y_test, pred_dtree))
print('---------------------------------------------------------------------------------------------------------------------\n')
print('classification_report Decision Tree Classifier :\n',metrics.classification_report(y_test, pred_dtree))
# Out:
# confusion_matrix Decision Tree Classifier      :
#  [[ 3969     0     0     6     2    43]
#  [    0   112     1     6     1    65]
#  [    0     0  2555    30   144   198]
#  [    3     6    32   779   105   679]
#  [    5     4   161    97  1818   513]
#  [   50    66   263   715   662 11185]]
# ---------------------------------------------------------------------------------------------------------------------
#
# classification_report Decision Tree Classifier :
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4020
#            1       0.60      0.61      0.60       185
#            2       0.85      0.87      0.86      2927
#            3       0.48      0.49      0.48      1604
#            4       0.67      0.70      0.68      2598
#            5       0.88      0.86      0.87     12941
#
#     accuracy                           0.84     24275
#    macro avg       0.74      0.75      0.75     24275
# weighted avg       0.84      0.84      0.84     24275

# %% [markdown]
# ### 2.2.8. Gradient Boosting Classifier Model (GBM)

# %% [raw]
# ************************************.....Gradient Boosting Classifier Model (GBM)......****************************************

# %%
gbm = GradientBoostingClassifier()
gbm.fit(X_train, y_train)
pred_gbm = gbm.predict(X_test)

# %%
print('confusion_matrix Gradient Boosting Classifier      :\n', metrics.confusion_matrix(y_test, pred_gbm))
print('---------------------------------------------------------------------------------------------------------------------\n')
print('classification_report Gradient Boosting Classifier :\n',metrics.classification_report(y_test, pred_gbm))
# Out:
# confusion_matrix Gradient Boosting Classifier      :
#  [[ 3953     0     0     0     0    67]
#  [    0    63     3     0     0   119]
#  [    2     1  1803     0    26  1095]
#  [   11     1    51    11     1  1529]
#  [    6     2   611     2   129  1848]
#  [  135    47   444     6    50 12259]]
# ---------------------------------------------------------------------------------------------------------------------
#
# classification_report Gradient Boosting Classifier :
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      4020
#            1       0.55      0.34      0.42       185
#            2       0.62      0.62      0.62      2927
#            3       0.58      0.01      0.01      1604
#            4       0.63      0.05      0.09      2598
#            5       0.72      0.95      0.82     12941
#
#     accuracy                           0.75     24275
#    macro avg       0.68      0.49      0.49     24275
# weighted avg       0.73      0.75      0.69     24275

# %% [markdown]
# ### 2.2.9. XGBoost Classifier Model

# %% [raw]
# ******************************************.....XGBoost Classifier Model ......*********************************************

# %%
xg_reg = xgb.XGBClassifier()

# %% [raw]
# xg_reg.fit(X_train, y_train)
# pred_xg_reg = xg_reg.predict(X_test)

# %% [markdown]
# ### 2.2.10. LassoCV Classifier Model

# %% [raw]
# ******************************************..... LassoCV Classifier Model ......*********************************************

# %% [raw]
# lasso = LassoCV()

# %% [markdown]
# lasso.fit(X_train, y_train)
# pred_lasso = lasso.predict(X_test)

# %% [markdown]
# ## 2.3. Regularization and Optimization all Models
#
# ###############################################################################################################################

# %% [markdown]
# ### 2.3.1. KNN Opt

# %% [raw]
# *******************************************************.....KNN Opt.....******************************************************

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
list_knn=[]
for i in range(1,11):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train,y_train)
    pred_s = knn.predict(X_test)
    scores = accuracy_score(y_test,pred_s)
    list_knn.append(scores)

# %%
print(max(list_knn))
# Out:
# 0.8487744593202884

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,11),list_knn)
plt.xlabel('k values')
plt.ylabel('accuracy scores')
plt.show()

# %%
#KNN TUNING:

#Initiating Random Forest regressor
knn_model = KNeighborsClassifier(n_neighbors=5, weights='uniform')

#Define the grid of hyperparameters
params_grid = {'n_neighbors': [2,3,5,10],
               'weights': ['uniform']
              }

#Initiate Grid search
grid_model = GridSearchCV(estimator = knn_model, param_grid = params_grid , cv = 5)
                       
#Fitting the grid search
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [2, 3, 5, 10], 'weights': ['uniform']})

# %%
print('Best parameter settings out of the ones we provided in the param_grid:')
print('Best Parameters :',grid_model.best_params_)
print('---------------------------------------------------------------------------------------------------------------------\n')
print('Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:')
print('Best Score      :',grid_model.best_score_)
print('---------------------------------------------------------------------------------------------------------------------\n')
print('---------------------------------------------------------------------------------------------------------------------\n')
pred_knn_g = grid_model.best_estimator_.predict(X_test)
print(pred_knn_g[:10])
print(y_test[:10])
# Out:
# Best parameter settings out of the ones we provided in the param_grid:
# Best Parameters : {'n_neighbors': 3, 'weights': 'uniform'}
# ---------------------------------------------------------------------------------------------------------------------
#
# Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:
# Best Score      : 0.8330381050463439
# ---------------------------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------------------
#
# [4 5 2 0 4 5 5 5 2 5]
# 57468    5
# 85248    5
# 23590    2
# 32375    0
# 48302    4
# 57131    5
# 74090    5
# 66611    5
# 51501    2
# 52349    5
# Name: RootCause_NUM, dtype: int64

# %%
print('confusion_matrix KNN_opt     :\n', metrics.confusion_matrix(y_test, pred_knn_g))
print('------------------------------------------------------------------------------------------------------------------\n')
print('classification_report KNN_opt :\n',metrics.classification_report(y_test, pred_knn_g))
# Out:
# confusion_matrix KNN_opt     :
#  [[ 3997     0     0     0     0    23]
#  [    0    99     0     3     0    83]
#  [    0     0  2550    17   176   184]
#  [    3     9    33   707    89   763]
#  [    3     2   237   139  1626   591]
#  [   60    73   318   641   400 11449]]
# ------------------------------------------------------------------------------------------------------------------
#
# classification_report KNN_opt :
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4020
#            1       0.54      0.54      0.54       185
#            2       0.81      0.87      0.84      2927
#            3       0.47      0.44      0.45      1604
#            4       0.71      0.63      0.67      2598
#            5       0.87      0.88      0.88     12941
#
#     accuracy                           0.84     24275
#    macro avg       0.73      0.73      0.73     24275
# weighted avg       0.84      0.84      0.84     24275

# %% [markdown]
# ### 2.3.2. Logistic Regression Optimization

# %% [raw]
# *********************************************.....Logistic Regression Optimization.....***************************************

# %%
from sklearn.linear_model import SGDClassifier
lclassifier = SGDClassifier(loss='log_loss',learning_rate='optimal', eta0=0.01, penalty='elasticnet')

# %%
#compare that k-fold scores
print("linear regression's 10-fold score:",cross_val_score(lclassifier, X, y, cv=5).mean())
# Out:
# linear regression's 10-fold score: nan

# %%
from sklearn.metrics import log_loss

# %%
#Gradient descent can used in different models that have a loss function
'''We are defining a param_grid here to try out different configuration 
(non-exhaustive) which gives us an idea of what values/range of values 
will give a better model to test/deploy 
'''
params = {
            'loss': ['log'],#'hinge'
            'penalty':['elasticnet'],
            'alpha': [0.1],
            'l1_ratio':[1],
            'learning_rate':['optimal'],
            'eta0':[0.001],
            'power_t':[0.01]
         }
grid_model2 = GridSearchCV(SGDClassifier(random_state=0), params, cv=5)
grid_model2.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SGDClassifier(random_state=0),
#              param_grid={'alpha': [0.1], 'eta0': [0.001], 'l1_ratio': [1],
#                          'learning_rate': ['optimal'], 'loss': ['log'],
#                          'penalty': ['elasticnet'], 'power_t': [0.01]})

# %%
print('Best parameter settings out of the ones we provided in the param_grid:')
print('Best Parameters :',grid_model2.best_params_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:')
print('Best Score      :',grid_model2.best_score_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('-----------------------------------------------------------------------------------------------------------------\n')
pred_log_g = grid_model2.best_estimator_.predict(X_test)
print(pred_log_g[:10])
print(y_test[:10])
# Out:
# Best parameter settings out of the ones we provided in the param_grid:
# Best Parameters : {'alpha': 0.1, 'eta0': 0.001, 'l1_ratio': 1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'elasticnet', 'power_t': 0.01}
# -----------------------------------------------------------------------------------------------------------------
#
# Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:
# Best Score      : 0.6535805012015106
# -----------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------------
#
# [5 5 5 0 5 5 5 5 5 5]
# 57468    5
# 85248    5
# 23590    2
# 32375    0
# 48302    4
# 57131    5
# 74090    5
# 66611    5
# 51501    2
# 52349    5
# Name: RootCause_NUM, dtype: int64

# %%
print('confusion_matrix LogesticRegression_opt      :\n', metrics.confusion_matrix(y_test, pred_log_g))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report LogesticRegression_opt :\n',metrics.classification_report(y_test, pred_log_g))
# Out:
# confusion_matrix LogesticRegression_opt      :
#  [[ 2972     0     0     0     0  1048]
#  [    0     0     0     0     0   185]
#  [    0     0     0     0     0  2927]
#  [    5     0     0     0     0  1599]
#  [    3     0     0     0     0  2595]
#  [   73     0     0     0     0 12868]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report LogesticRegression_opt :
#                precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84      4020
#            1       0.00      0.00      0.00       185
#            2       0.00      0.00      0.00      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.61      0.99      0.75     12941
#
#     accuracy                           0.65     24275
#    macro avg       0.26      0.29      0.27     24275
# weighted avg       0.48      0.65      0.54     24275

# %% [markdown]
# ### 2.3.3. SVC opt

# %% [raw]
# *******************************************************.....SVC opt.....*******************************************************

# %%
svc = SGDClassifier(loss='hinge', learning_rate='constant',eta0=0.5)

# %%
print("svc's 5-fold score:",cross_val_score(svc,X,y,cv=5).mean())
# Out:
# svc's 5-fold score: 0.5475386199794027

# %%
'''We are defining a param_grid here to try out different configuration 
(non-exhaustive) which gives us an idea of what values/range of values 
will give a better model to test/deploy 
'''
params = {
            'loss': ['hinge'],
            'alpha': [0.001,0.01,0.1,1],
            'l1_ratio':[0,0.5,1],
            'learning_rate':['constant'],
            'eta0':[0.001,0.01,0.1,1],
            'power_t':[0.5,1,2]
         }
grid_model3 = GridSearchCV(SGDClassifier(penalty='elasticnet',random_state=0),
                          params,cv=5)
grid_model3.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=SGDClassifier(penalty='elasticnet', random_state=0),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1],
#                          'eta0': [0.001, 0.01, 0.1, 1], 'l1_ratio': [0, 0.5, 1],
#                          'learning_rate': ['constant'], 'loss': ['hinge'],
#                          'power_t': [0.5, 1, 2]})

# %%
print('Best parameter settings out of the ones we provided in the param_grid:')
print('Best Parameters :',grid_model3.best_params_)
print('------------------------------------------------------------------------------------------------------------------\n')
print('Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:')
print('Best Score      :',grid_model3.best_score_)
print('------------------------------------------------------------------------------------------------------------------\n')
print('------------------------------------------------------------------------------------------------------------------\n')
pred_svc_g = grid_model3.best_estimator_.predict(X_test)
print(pred_svc_g[:10])
print(y_test[:10])
# Out:
# Best parameter settings out of the ones we provided in the param_grid:
# Best Parameters : {'alpha': 0.1, 'eta0': 0.001, 'l1_ratio': 0.5, 'learning_rate': 'constant', 'loss': 'hinge', 'power_t': 0.5}
# ------------------------------------------------------------------------------------------------------------------
#
# Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:
# Best Score      : 0.6796292481977343
# ------------------------------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------------------------------
#
# [5 5 5 0 5 5 5 5 5 5]
# 57468    5
# 85248    5
# 23590    2
# 32375    0
# 48302    4
# 57131    5
# 74090    5
# 66611    5
# 51501    2
# 52349    5
# Name: RootCause_NUM, dtype: int64

# %%
print('confusion_matrix SVC_opt      :\n', metrics.confusion_matrix(y_test, pred_svc_g))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report SVC_opt :\n',metrics.classification_report(y_test, pred_svc_g))
# Out:
# confusion_matrix SVC_opt      :
#  [[ 3922     0     0     0     0    98]
#  [    0     0     0     0     0   185]
#  [   12     0     0     0     0  2915]
#  [   35     0     0     0     0  1569]
#  [   38     0     0     0     0  2560]
#  [  381     0     0     0     0 12560]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report SVC_opt :
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      4020
#            1       0.00      0.00      0.00       185
#            2       0.00      0.00      0.00      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.63      0.97      0.77     12941
#
#     accuracy                           0.68     24275
#    macro avg       0.25      0.32      0.28     24275
# weighted avg       0.48      0.68      0.56     24275

# %% [markdown]
# ### 2.3.4. RandomForest Model

# %% [raw]
# **********************************************...... RandomForest Opt .......**************************************************

# %%
#Graph k-fold score vs no. of estimators in Random Forest
scores = []
for i in range(10,201,10):
    scores.append(cross_val_score(RandomForestClassifier(n_estimators=i,random_state=42),
                                 X,y,cv=5).mean())

# %%
plt.plot(range(10,201,10),scores)
plt.xlabel('No. of DTs in Random Forest')
plt.ylabel('K-fold scores')
plt.show()

# %%
#including other params like max_depth, we will apply gridsearch to fine the best settings for the RF
params = {
            'n_estimators': [100,115,120],
            'max_depth': [5,12,13,14]
        }
grid_model4 = GridSearchCV(RandomForestClassifier(random_state=0), params,cv=5)
grid_model4.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0),
#              param_grid={'max_depth': [5, 12, 13, 14],
#                          'n_estimators': [100, 115, 120]})

# %%
print('Best parameter settings out of the ones we provided in the param_grid:')
print('Best Parameters :',grid_model4.best_params_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:')
print('Best Score      :',grid_model4.best_score_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('-----------------------------------------------------------------------------------------------------------------\n')
pred_rfo = grid_model4.best_estimator_.predict(X_test)
print(pred_rfo[:10])
print(y_test[:10])
# Out:
# Best parameter settings out of the ones we provided in the param_grid:
# Best Parameters : {'max_depth': 5, 'n_estimators': 120}
# -----------------------------------------------------------------------------------------------------------------
#
# Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:
# Best Score      : 0.6692070030895982
# -----------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------------
#
# [5 5 5 0 5 5 5 5 5 5]
# 57468    5
# 85248    5
# 23590    2
# 32375    0
# 48302    4
# 57131    5
# 74090    5
# 66611    5
# 51501    2
# 52349    5
# Name: RootCause_NUM, dtype: int64

# %%
print('confusion_matrix RandomForest_opt      :\n', metrics.confusion_matrix(y_test, pred_rfo))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report RandomForest_opt :\n',metrics.classification_report(y_test, pred_rfo))
# Out:
# confusion_matrix RandomForest_opt      :
#  [[ 2398     0     0     0     0  1622]
#  [    1     0     9     0     0   175]
#  [  155     0   433     0     0  2339]
#  [  204     0   125     0     0  1275]
#  [  235     0   355     0     0  2008]
#  [ 1595     0   688     0     0 10658]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report RandomForest_opt :
#                precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56      4020
#            1       0.00      0.00      0.00       185
#            2       0.27      0.15      0.19      2927
#            3       0.00      0.00      0.00      1604
#            4       0.00      0.00      0.00      2598
#            5       0.59      0.82      0.69     12941
#
#     accuracy                           0.56     24275
#    macro avg       0.23      0.26      0.24     24275
# weighted avg       0.43      0.56      0.48     24275

# %% [markdown]
# ### 2.3.5. Adaboost Model

# %% [raw]
# ************************************************......Adaboost Opt......******************************************************

# %%
#Graph k-fold score vs no. of estimators in Adaboost which uses DT as base estimators
scores = []
for i in range(1,201,10):
    scores.append(cross_val_score(AdaBoostClassifier(n_estimators=i,random_state=0),
                                  X,y,cv=5).mean())

# %%
plt.plot(range(10,201,10),scores)
plt.xlabel('No. of DTs in Adaboost')
plt.ylabel('K-fold scores')
plt.show()

# %%
#including other params like max_depth, we will apply gridsearch to fine the best settings 
from sklearn.tree import DecisionTreeClassifier
params = {
            'n_estimators': [0.1,1,5,10],
            'base_estimator': [DecisionTreeClassifier(max_depth=13,random_state=0),
                               DecisionTreeClassifier(max_depth=14,random_state=0),
                               DecisionTreeClassifier(max_depth=16,random_state=0)]
        }
grid_model5 = GridSearchCV(AdaBoostClassifier(random_state=0), params,cv=5)
grid_model5.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=0),
#              param_grid={'base_estimator': [DecisionTreeClassifier(max_depth=13,
#                                                                    random_state=0),
#                                             DecisionTreeClassifier(max_depth=14,
#                                                                    random_state=0),
#                                             DecisionTreeClassifier(max_depth=16,
#                                                                    random_state=0)],
#                          'n_estimators': [0.1, 1, 5, 10]})

# %%
from sklearn import *

# %%
print('Best parameter settings out of the ones we provided in the param_grid:')
print('Best Parameters :',grid_model5.best_params_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:')
print('Best Score      :',grid_model5.best_score_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('-----------------------------------------------------------------------------------------------------------------\n')
pred_adab_o = grid_model5.best_estimator_.predict(X_test)
print(pred_adab_o[:10])
print(y_test[:10])
# Out:
# Best parameter settings out of the ones we provided in the param_grid:
# Best Parameters : {'base_estimator': DecisionTreeClassifier(max_depth=13, random_state=0), 'n_estimators': 1}
# -----------------------------------------------------------------------------------------------------------------
#
# Fitting model into the training set, Test score , and also this score is available from the gridsearch result as well:
# Best Score      : 0.531967044284243
# -----------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------------
#
# [4 5 5 5 5 5 5 4 4 5]
# 57468    5
# 85248    5
# 23590    2
# 32375    0
# 48302    4
# 57131    5
# 74090    5
# 66611    5
# 51501    2
# 52349    5
# Name: RootCause_NUM, dtype: int64

# %%
print('confusion_matrix  AdaBoost_opt      :\n', metrics.confusion_matrix(y_test, pred_adab_o))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report AdaBoost_opt :\n',metrics.classification_report(y_test, pred_adab_o))
# Out:
# confusion_matrix  AdaBoost_opt      :
#  [[ 386    0    0    7   29 3598]
#  [   0    0    2    3   11  169]
#  [  81    0  338   28  210 2270]
#  [ 162    1   26   92  158 1165]
#  [ 202    1  211   60  217 1907]
#  [1425   59  242  565 1361 9289]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report AdaBoost_opt :
#                precision    recall  f1-score   support
#
#            0       0.17      0.10      0.12      4020
#            1       0.00      0.00      0.00       185
#            2       0.41      0.12      0.18      2927
#            3       0.12      0.06      0.08      1604
#            4       0.11      0.08      0.09      2598
#            5       0.50      0.72      0.59     12941
#
#     accuracy                           0.43     24275
#    macro avg       0.22      0.18      0.18     24275
# weighted avg       0.37      0.43      0.37     24275

# %% [markdown]
# ### 2.3.6. Decision Tree Classifier Model Opt

# %% [raw]
# **************************************......Decision Tree Classifier Model Opt......*******************************************

# %%
#Graph k-fold score vs no. of estimators in Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
scores = []
for i in range(1,201,10):
    dtree = DecisionTreeClassifier(max_depth=i,random_state=0)
    scores.append(cross_val_score(dtree, X,y,cv=5).mean())

# %%
plt.figure(figsize=(5,5))
plt.plot(range(10,201,10),scores)
plt.xlabel('No. of DTs in DecisionTree')
plt.ylabel('K-fold scores')
plt.show()

# %%
#Decision Tree TUNING:

#Initiating Random Forest regressor
dtree_model = DecisionTreeClassifier(random_state=0)

#Define the grid of hyperparameters
params_grid = {
              'max_depth': [None],
              'min_samples_split': [2],
              'min_samples_leaf': [1,2],
              'max_features': [None]
              
              }

#Initiate Grid search
grid_model6 = GridSearchCV( estimator =dtree_model,
                       param_grid = params_grid ,
                       cv = 5,
                       scoring = 'neg_mean_squared_error',
                       verbose = 1,
                       n_jobs = -1)

#Fitting the grid search
grid_model6.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': [None], 'max_features': [None],
#                          'min_samples_leaf': [1, 2], 'min_samples_split': [2]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
print('Best parameter settings out of the ones we provided in the param_grid:')
print('Best Parameters :',grid_model6.best_params_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('Fitting model into the training set, Test score, and also this score is available from the gridsearch result as well:')
print('Best Score      :',grid_model6.best_score_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('-----------------------------------------------------------------------------------------------------------------\n')
pred_clfm = grid_model6.best_estimator_.predict(X_test)
print(pred_rfo[:10])
print(y_test[:10])
# Out:
# Best parameter settings out of the ones we provided in the param_grid:
# Best Parameters : {'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# -----------------------------------------------------------------------------------------------------------------
#
# Fitting model into the training set, Test score, and also this score is available from the gridsearch result as well:
# Best Score      : -0.7644078269824923
# -----------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------------
#
# [5 5 5 0 5 5 5 5 5 5]
# 57468    5
# 85248    5
# 23590    2
# 32375    0
# 48302    4
# 57131    5
# 74090    5
# 66611    5
# 51501    2
# 52349    5
# Name: RootCause_NUM, dtype: int64

# %%
print('confusion_matrix RandomForest_opt      :\n', metrics.confusion_matrix(y_test, pred_clfm))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report RandomForest_opt :\n',metrics.classification_report(y_test, pred_clfm))
# Out:
# confusion_matrix RandomForest_opt      :
#  [[ 3971     0     0     5     2    42]
#  [    0   112     0     6     1    66]
#  [    0     0  2564    25   140   198]
#  [    2     6    35   774   105   682]
#  [    5     3   165    94  1815   516]
#  [   51    65   276   728   660 11161]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report RandomForest_opt :
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4020
#            1       0.60      0.61      0.60       185
#            2       0.84      0.88      0.86      2927
#            3       0.47      0.48      0.48      1604
#            4       0.67      0.70      0.68      2598
#            5       0.88      0.86      0.87     12941
#
#     accuracy                           0.84     24275
#    macro avg       0.74      0.75      0.75     24275
# weighted avg       0.84      0.84      0.84     24275

# %% [raw]
# **************************************......Random Forest Classifier Model Opt......****************************************

# %%
#Graph k-fold score vs no. of estimators in Decision Tree Classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
scores = []
for i in range(1,201,10):
    clfm = RandomForestClassifier(max_depth=i,random_state=0)
    scores.append(cross_val_score(clfm, X,y,cv=5).mean())

# %%
plt.figure(figsize=(5,5))
plt.plot(range(10,201,10),scores)
plt.xlabel('No. of RFs in Random Forest')
plt.ylabel('K-fold scores')
plt.show()

# %%
#Random Forest Multiclass TUNING:

#Initiating Random Forest regressor
clfm_model = RandomForestClassifier(random_state=0)

#Define the grid of hyperparameters
params_grid = {
              'max_depth':[None], #[3,5,10],
              'min_samples_split': [0.01,0.1,1,2,5],
              'min_samples_leaf': [0.05,1,2,5],
              'max_features': [None]
              
              }

#Initiate Grid search
grid_model10 = GridSearchCV( estimator =clfm_model,
                       param_grid = params_grid ,
                       cv = 5,
                       scoring = 'neg_mean_squared_error',
                       verbose = 1,
                       n_jobs = -1)

#Fitting the grid search
grid_model10.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': [None], 'max_features': [None],
#                          'min_samples_leaf': [0.05, 1, 2, 5],
#                          'min_samples_split': [0.01, 0.1, 1, 2, 5]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
print('Best parameter settings out of the ones we provided in the param_grid:')
print('Best Parameters :',grid_model10.best_params_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('Fitting model into the training set, Test score, and also this score is available from the gridsearch result as well:')
print('Best Score      :',grid_model10.best_score_)
print('-----------------------------------------------------------------------------------------------------------------\n')
print('-----------------------------------------------------------------------------------------------------------------\n')
pred_clfm = grid_model10.best_estimator_.predict(X_test)
print(pred_rfo[:10])
print(y_test[:10])
# Out:
# Best parameter settings out of the ones we provided in the param_grid:
# Best Parameters : {'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5}
# -----------------------------------------------------------------------------------------------------------------
#
# Fitting model into the training set, Test score, and also this score is available from the gridsearch result as well:
# Best Score      : -0.6826089941640919
# -----------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------------
#
# [5 5 5 0 5 5 5 5 5 5]
# 57468    5
# 85248    5
# 23590    2
# 32375    0
# 48302    4
# 57131    5
# 74090    5
# 66611    5
# 51501    2
# 52349    5
# Name: RootCause_NUM, dtype: int64

# %%
print('confusion_matrix RandomForest_opt      :\n', metrics.confusion_matrix(y_test, pred_clfm))
print('-----------------------------------------------------------------------------------------------------------------\n')
print('classification_report RandomForest_opt :\n',metrics.classification_report(y_test, pred_clfm))
# Out:
# confusion_matrix RandomForest_opt      :
#  [[ 3992     0     0     0     1    27]
#  [    0    94     0     4     1    86]
#  [    0     0  2534    13   147   233]
#  [    3     3    22   683    89   804]
#  [    5     1   172    72  1706   642]
#  [   52    46   235   406   368 11834]]
# -----------------------------------------------------------------------------------------------------------------
#
# classification_report RandomForest_opt :
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4020
#            1       0.65      0.51      0.57       185
#            2       0.86      0.87      0.86      2927
#            3       0.58      0.43      0.49      1604
#            4       0.74      0.66      0.69      2598
#            5       0.87      0.91      0.89     12941
#
#     accuracy                           0.86     24275
#    macro avg       0.78      0.73      0.75     24275
# weighted avg       0.85      0.86      0.85     24275

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=1000, n_features=4,
                           n_informative=2, n_redundant=0,
                           random_state=0, shuffle=False)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
print(clf.predict([[0, 0, 0, 0]]))
# Out:
# [1]

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
clf.score(X_test, y_test)
# Out:
# 0.6778166838311019

# %%
y_pred_clf=clf.predict(X_test)
y_pred_clf
# Out:
# array([5, 5, 5, ..., 5, 5, 0], dtype=int64)

# %% [markdown]
# ## -----------------------------------------------------  CONLUSION  -------------------------------------------------------

# %% [markdown]
# ## A. Visualization the Result
#
# ###############################################################################################################################

# %%
#Density-Plot and Box-Plot
sns.set_theme(style="ticks", palette="pastel")
fig, ax = plt.subplots(nrows =3, ncols = 5, figsize = (25, 10))

sns.distplot((y_test,pred_knn), ax = ax[0,0])
ax[0,0].set_xlabel("KNN DENSITY", color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_log), ax = ax[0,1])
ax[0,1].set_xlabel('Logestic Regressier DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_svc), ax = ax[0,2])
ax[0,2].set_xlabel('SVC DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_rfc), ax = ax[0,3])
ax[0,3].set_xlabel('Random Forest Classifier DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_dtree), ax = ax[0,4])
ax[1,3].set_xlabel('Decision Tree Classifier DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_ridge), ax = ax[1,0])
ax[1,4].set_xlabel('Ridge Classifier DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_adab), ax = ax[1,1])
ax[0,4].set_xlabel('AdaBoost Classifier DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_knn_g), ax = ax[1,2])
ax[1,0].set_xlabel('KNN OPT DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_log_g), ax = ax[1,3])
ax[1,1].set_xlabel('Linear Classifier OPT DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_svc_g), ax = ax[1,4])
ax[1,2].set_xlabel('SVR OPT DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_rfo), ax = ax[2,0])
ax[1,3].set_xlabel('Random Forest Classifier OPT DENSITY', color = "darkblue", fontsize = 14)

sns.distplot((y_test,pred_adab_o), ax = ax[2,1])
ax[1,4].set_xlabel('AdaBoost Classifier OPT DENSITY', color = "darkblue", fontsize = 14)

#sns.distplot((y_test,pred_dtree_sgd), ax = ax[2,2])
#ax[1,3].set_xlabel('Decision Tree Classifier OPT DENSITY', color = "darkblue", fontsize = 14)

#sns.distplot((y_test,pred_ridge_sgd), ax = ax[2,3])
#ax[1,4].set_xlabel('Ridge Classifier OPT DENSITY', color = "darkblue", fontsize = 14)

fig.suptitle('DISTRIBUTION OF THE VARIOUS MODELS IN SKLEARN', color = "darkblue", fontsize = 22)
fig.tight_layout()
fig.subplots_adjust(top=0.88)

plt.show()

# %%
# PLOTTING THE PREDICTIONS
plt.rcParams['figure.figsize']= 20,15


plt.subplot(3,5,1)
plt.scatter(y_test,pred_knn)
plt.plot(y_test, y_test, 'r')
fig.suptitle('KNN', fontsize=20)
plt.xlabel('Real value', fontsize = 10)  
plt.ylabel('Prediccion', fontsize = 10) 

plt.subplot(3,5,2)
plt.scatter(y_test,pred_log)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Real value', fontsize = 10)  
plt.ylabel('Prediccion', fontsize = 10) 

plt.subplot(3,5,3)
plt.scatter(y_test,pred_svc)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Actual Value', fontsize = 10)  
plt.ylabel('Predicted Value', fontsize = 10) 

plt.subplot(3,5,4)
plt.scatter(y_test,pred_rfc)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Actual Value', fontsize = 10)  
plt.ylabel('Predicted Value', fontsize = 10)  

plt.subplot(3,5,5)
plt.scatter(y_test,pred_adab)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Actual Value', fontsize = 10)  
plt.ylabel('Predicted Value', fontsize = 10) 

#plt.subplot(3,5,6)
#plt.scatter(y_test,pred_dtree)
#plt.plot(y_test, y_test, 'r')
#plt.xlabel('Actual Value')  
#plt.ylabel('Predicted Value')  

#plt.subplot(3,5,7)
#plt.scatter(y_test,pred_ridge)
#plt.plot(y_test, y_test, 'r')
#plt.xlabel('Actual Value')  
#plt.ylabel('Predicted Value') 

plt.subplot(3,5,6)
plt.scatter(y_test,pred_knn_g)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Actual Value', fontsize = 10)  
plt.ylabel('Predicted Value', fontsize = 10) 

plt.subplot(3,5,7)
plt.scatter(y_test,pred_log_g)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Real value', fontsize = 10)  
plt.ylabel('Prediccion', fontsize = 10) 

#plt.subplot(3,5,10)
#plt.scatter(y_test,pred_svc_g)
#plt.plot(y_test, y_test, 'r')
#plt.xlabel('Real value', fontsize = 10)  
#plt.ylabel('Prediccion', fontsize = 10) 

plt.subplot(3,5,8)
plt.scatter(y_test,pred_rfo)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Real value', fontsize = 10)  
plt.ylabel('Prediccion', fontsize = 10) 

plt.subplot(3,5,9)
plt.scatter(y_test,pred_adab_o)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Real value', fontsize = 10)  
plt.ylabel('Prediccion', fontsize = 10) 

#plt.subplot(3,5,13)
#plt.scatter(y_test,pred_dtree_sgd)
#plt.plot(y_test, y_test, 'r')
#plt.xlabel('Real value', fontsize = 10)  
#plt.ylabel('Prediccion', fontsize = 10) 

#plt.subplot(3,5,14)
#plt.scatter(y_test,pred_ridge_sgd)
#plt.plot(y_test, y_test, 'r')
#plt.xlabel('Real value', fontsize = 10)  
#plt.ylabel('Prediccion', fontsize = 10) 

fig.suptitle('PREDICTIONS OF THE VARIOUS MODELS IN SKLEARN', color = "darkblue", fontsize = 8)
fig.tight_layout()
fig.subplots_adjust(top=0.88)

plt.show()

# %% [markdown]
# ## B. COMPARE ALL MODELS

# %%
print('Display Accuracy, Recall and Precision For Classification Models')
print('-----------------------------------------------------------------------------------------------------------------\n')
print('-------------------------------------------------------------------------------------------------------------------')
print('********************************...........INFERENCE AND CONCLUSION.............***********************************')
print('-------------------------------------------------------------------------------------------------------------------')
results_df = append_results("KNN", knn, results_df, y_test, pred_knn)
results_df = append_results("Logestic Regression", log_reg, results_df, y_test, pred_log)
#results_df = append_results("SVC", svc, results_df, y_test, pred_svc)
results_df = append_results("Random Forest", rfc, results_df, y_test, pred_rfc)
results_df = append_results("Ada Boost", adab, results_df, y_test, pred_adab)
results_df = append_results("KNN_opt", grid_model, results_df, y_test, pred_knn_g)
results_df = append_results("LogesticRegression_opt", grid_model2, results_df, y_test, pred_log_g)
#results_df = append_results("SVC_opt", grid_model3, results_df, y_test, pred_svc_g)
results_df = append_results("Random Forest_opt", grid_model4, results_df, y_test, pred_rfo)
results_df = append_results("Ada Boost_opt", grid_model5, results_df, y_test, pred_adab_o)
results_df
# Out:
# Display Accuracy, Recall and Precision For Classification Models
# -----------------------------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------------------------------
# ********************************...........INFERENCE AND CONCLUSION.............***********************************
# -------------------------------------------------------------------------------------------------------------------
#                     Model  Cross Val Score  pre_macro  recall_macro  f1_macro  \
# 0                     KNN         0.724623   0.694464      0.707236  0.707236
# 1     Logestic Regression         0.260771   0.320954      0.284384  0.284384
# 2           Random Forest         0.779110   0.754124      0.765535  0.765535
# 3               Ada Boost         0.296183   0.415359      0.225979  0.225979
# 4                 KNN_opt         0.731779   0.725327      0.727858  0.727858
# 5  LogesticRegression_opt         0.263303   0.288944      0.265618  0.265618
# 6       Random Forest_opt         0.230200   0.261339      0.239208  0.239208
# 7           Ada Boost_opt         0.219968   0.178363      0.178159  0.178159
#
#    f1_macro_manual
# 0            0.939
# 1            0.942
# 2            0.947
# 3            0.938
# 4            0.940
# 5            0.937
# 6            0.945
# 7            0.933

# %%
plt.rcParams['figure.figsize'] = 20,5
g = sns.barplot("Model","f1_macro", data = results_df, color = 'b')
g.set_title("Classification Model Results", color = "darkblue")
plt.show()

# %% [raw]
# Most of the Classification Model hoover around 70% - accuaracy level except Ada Boost and Logestic Regression.

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
# !pip install catboost
from catboost import CatBoostClassifier

Classifiers=[["Random Forest",RandomForestClassifier()],
             ["Support Vector Machine",SVC()],
             ["LogisticRegression",LogisticRegression()],
             ["KNN",KNeighborsClassifier(n_neighbors=5)],
             ["Naive Bayes",GaussianNB()],
             ["Decision Tree",DecisionTreeClassifier()],
             ["AdaBoostClassifier", AdaBoostClassifier()],
             ["GradientBoostingClassifier", GradientBoostingClassifier()],
             ["XGB", XGBClassifier()],
             ["CatBoost", CatBoostClassifier(logging_level='Silent')]  
]
# Out:
# Requirement already satisfied: catboost in c:\users\sara.khosravi\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: six in c:\users\sara.khosravi\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\sara.khosravi\anaconda3\lib\site-packages (from catboost) (3.5.1)
# Requirement already satisfied: scipy in c:\users\sara.khosravi\anaconda3\lib\site-packages (from catboost) (1.7.3)
# Requirement already satisfied: plotly in c:\users\sara.khosravi\anaconda3\lib\site-packages (from catboost) (5.4.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from catboost) (1.21.5)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from catboost) (1.4.2)
# Requirement already satisfied: graphviz in c:\users\sara.khosravi\anaconda3\lib\site-packages (from catboost) (0.20)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2021.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from matplotlib->catboost) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sara.khosravi\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)

# %% [markdown]
# pred_X = df.tail(100)

# %% [raw]
# df.columns
# #df.columns.values.tolist()

# %%
df_id = df['ImtId']
#df_id.shape

# %%
pred_X = X
#pred_X.shape

# %% [raw]
# Consider a binary classification for labels 0 and 1.
#
# Predict will give either 0 or 1 as output
# Predict_proba will give the only probability of 1.

# %%
df_ImtId_M = df['ImtId']
df_CreateDate_M = df['CreateDate']
df_RuleName_M = df['RuleName'] 
df_RootCause_M = df['RootCause'] 
df_Resolution_M =df['Resolution'] 
df_RecoveryPrime_M = df['RecoveryPrime']
df_WorkflowState_M = df['WorkflowState'] 
df_Responsibility_M = df['Responsibility'] 
df_ResponsibilityDepartment_M = df['ResponsibilityDepartment'] 
df_State_M = df['State'] 
df_Status_M =df['Status'] 
df_Submitter_M = df['Submitter']
df_SubmitterDepartment_M = df['SubmitterDepartment']
df_Bot_M = df['Bot']
df_AutomationSuiteName_M = df['AutomationSuiteName']
df_AutomationStatus_M = df['AutomationStatus'] 
df_AutomationFramework_M = df['AutomationFramework']

# %% [raw]
# predDf = pd.DataFrame({'RootCause_NUM':pred_adab_o,
#                        'ImtId_NUM':df_ImtId_M,
#                        'CreateDate_NUM':df_CreateDate_M,
#                        'RuleName_NUM':df_RuleName_M,
#                        'Resolution_NUM':df_Resolution_M,
#                        'RecoveryPrime_NUM':df_RecoveryPrime_M,
#                        'WorkflowState_NUM':df_WorkflowState_M,
#                        'Responsibility_NUM':df_Responsibility_M,
#                        'ResponsibilityDepartment_NUM':df_ResponsibilityDepartment_M,
#                        'State_NUM':df_State_M,
#                        'Status_NUM':df_Status_M,
#                        'Submitter_NUM':df_Submitter_M,
#                        'SubmitterDepartment_NUM':df_SubmitterDepartment_M,
#                        'Bot_NUM':df_Bot_M,
#                        'AutomationSuiteName_NUM':df_AutomationSuiteName_M,
#                        'AutomationStatus_NUM':df_AutomationStatus_M,
#                        'AutomationFramework_NUM':df_AutomationFramework_M
#                       })
# predDf

# %% [markdown]
# df_id = df["ImtId"].tail(100)
# df_id.shape

# %% [raw]
# model = GaussianNB()
# model.fit(X_train,y_train)
# pred_y = model.predict(pred_X)
# pred_y_pro = model.predict_proba(pred_X)[:,1]

# %%
df_ImtId_M = df['ImtId']

# %%
pred_adab_o = pd.Series(pred_adab_o)

# %%
predDf = pd.DataFrame({'df_ImtId_M':df_id, 'df_RootCause_M':pred_adab_o})
predDf
# Out:
#             df_ImtId_M  df_RootCause_M
# 0      IMT.2112.043195             4.0
# 1      IMT.2112.043196             5.0
# 2      IMT.2112.043197             5.0
# 3      IMT.2112.043198             5.0
# 4      IMT.2112.043199             5.0
# ...                ...             ...
# 96996  IMT.2204.002571             NaN
# 96997  IMT.2204.002572             NaN
# 96998  IMT.2204.002574             NaN
# 96999  IMT.2204.002575             NaN
# 97000  IMT.2204.002576             NaN
#
# [97100 rows x 2 columns]

# %%
predDf = pd.DataFrame({'RuleName_NUM':df_RuleName_M, 'RootCause_NUM':pred_adab_o})
predDf
# Out:
#                                             RuleName_NUM  RootCause_NUM
# 0                                    UMTS UL RSSI -85dBm            4.0
# 1      BMC - IUM Evolution - Parameter Count changed ...            5.0
# 2                                      TLAN_HVAC_Failure            5.0
# 3                      SB_SYNTH_IPTV - Medius - Critical            5.0
# 4          CCAP - CASA System Monitoring UPS Switch over            5.0
# ...                                                  ...            ...
# 96996                  MiniLinkTN_SNMP_Reserved Position            NaN
# 96997                           SB_SYNTH_IPRAN Link Down            NaN
# 96998                           SB_SYNTH_IPRAN Link Down            NaN
# 96999           Core Security - peakflowSPTraps CRITICAL            NaN
# 97000                 RCBIN Core - Link Down Proprietary            NaN
#
# [97100 rows x 2 columns]

# %%
predDf = pd.DataFrame({'Resolution_NUM':df_Resolution_M, 'RootCause_NUM':pred_adab_o})
predDf
# Out:
#                     Resolution_NUM  RootCause_NUM
# 0      Network / Service Validated            4.0
# 1      Network / Service Validated            5.0
# 2      Network / Service Validated            5.0
# 3                  Source Restored            5.0
# 4                           Re-Set            5.0
# ...                            ...            ...
# 96996                      Unknown            NaN
# 96997  Network / Service Validated            NaN
# 96998  Network / Service Validated            NaN
# 96999  Network / Service Validated            NaN
# 97000  Network / Service Validated            NaN
#
# [97100 rows x 2 columns]

# %%
predDf = pd.DataFrame({'RecoveryPrime_NUM':df_RecoveryPrime_M, 'RootCause_NUM':pred_adab_o})
predDf
# Out:
#       RecoveryPrime_NUM  RootCause_NUM
# 0        Field Resolved            4.0
# 1          NOC Resolved            5.0
# 2        Field Resolved            5.0
# 3          NOC Resolved            5.0
# 4          NOC Resolved            5.0
# ...                 ...            ...
# 96996           Unknown            NaN
# 96997      NOC Resolved            NaN
# 96998      NOC Resolved            NaN
# 96999      NOC Resolved            NaN
# 97000      NOC Resolved            NaN
#
# [97100 rows x 2 columns]

# %%
predDf = pd.DataFrame({'WorkflowState_NUM':df_WorkflowState_M, 'RootCause_NUM':pred_adab_o})
predDf
# Out:
#          WorkflowState_NUM  RootCause_NUM
# 0                  Unknown            4.0
# 1                  Unknown            5.0
# 2                  Unknown            5.0
# 3                  Unknown            5.0
# 4      Requires Specialist            5.0
# ...                    ...            ...
# 96996              Unknown            NaN
# 96997  Requires Specialist            NaN
# 96998  Requires Specialist            NaN
# 96999  Requires Specialist            NaN
# 97000  Requires Specialist            NaN
#
# [97100 rows x 2 columns]

# %%
predDf = pd.DataFrame({'Responsibility_NUM':df_Responsibility_M, 'RootCause_NUM':pred_adab_o})
predDf
# Out:
#                    Responsibility_NUM  RootCause_NUM
# 0      Ops Cable and Wireless Ontario            4.0
# 1                                 NOC            5.0
# 2          Ops Cable and Wireless GTA            5.0
# 3                                 NOC            5.0
# 4                                 NOC            5.0
# ...                               ...            ...
# 96996  Ops Cable and Wireless Ontario            NaN
# 96997                             NOC            NaN
# 96998                             NOC            NaN
# 96999                             NOC            NaN
# 97000                             NOC            NaN
#
# [97100 rows x 2 columns]

# %%
predDf = pd.DataFrame({'Bot_NUM':df_Bot_M, 'RootCause_NUM':pred_adab_o})
predDf
# Out:
#                                                  Bot_NUM  RootCause_NUM
# 0                                                Unknown            4.0
# 1                                                Unknown            5.0
# 2                                                Unknown            5.0
# 3                                                Unknown            5.0
# 4                        DIAGNOSTIC-CASA-UPS-SWITCH-OVER            5.0
# ...                                                  ...            ...
# 96996                                            Unknown            NaN
# 96997  DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-AL...            NaN
# 96998  DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-AL...            NaN
# 96999                             DIAGNOSTIC-ARBOR-ALARM            NaN
# 97000                         DIAGNOSTIC-RCBIN-LINK-DOWN            NaN
#
# [97100 rows x 2 columns]

# %%
predDf.value_counts()
# Out:
# Bot_NUM                                         RootCause_NUM
# Unknown                                         5.0              6702
# DIAGNOSTIC-CASA-UPS-SWITCH-OVER                 5.0              2847
# DIAGNOSTIC-TLAN-INTEGRATED                      5.0              1085
# DIAGNOSTIC-RCBIN-LINK-DOWN                      5.0               913
# Unknown                                         0.0               852
#                                                                  ...
# DIAGNOSTIC-NodeB-Service-Degraded               3.0                 1
# DIAGNOSTIC-AD-FOR-EON-PCHIP-ERROR               3.0                 1
# DIAGNOSTIC_LTE_LINK_DEGRADED                    2.0                 1
# DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE  4.0                 1
# DIAGNOSTIC-RCBIN-Neighbor-Loss                  3.0                 1
# Length: 377, dtype: int64

# %%
predDf["RootCause_NUM"].value_counts(normalize=True)
# Out:
# 5.0    0.757734
# 0.0    0.093050
# 4.0    0.081850
# 2.0    0.033765
# 3.0    0.031099
# 1.0    0.002503
# Name: RootCause_NUM, dtype: float64

# %% [raw]
# pred_y_pro = np.array(pd.DataFrame(pred_y_pro)[1])
# y = predDf["RootCause"].tail(100).values
# fpr, tpr, thresholds = sklearn.metrics.roc_curve(y, pred_y_pro, pos_label = 1)

# %% [raw]
# import numpy as np
# import pandas as pd
# import os
# import matplotlib.pyplot as plt
# import seaborn as sns
# from pylab import rcParams
# import matplotlib.cm as cm
# import pandas_profiling as pp
#
# import sklearn
# from sklearn import preprocessing
#
#
# auc = sklearn.metrics.auc(fpr, tpr)

# %% [raw]
# plt.figure()
# lw = 2
# plt.plot(fpr, tpr, color='darkorange',
#          lw=lw, label='ROC curve (area = %0.2f)' % auc)
# plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
predDf.sort_values(by="RootCause_NUM", ascending=False).head()
# Out:
#                           Bot_NUM  RootCause_NUM
# 24274                     Unknown            5.0
# 20693                     Unknown            5.0
# 12461                     Unknown            5.0
# 20696  DIAGNOSTIC-TLAN-INTEGRATED            5.0
# 20697                     Unknown            5.0

# %% [raw]
# predDf[predDf["RootCause"].apply(lambda RootCause: RootCause[0] == "Change Management Activity")].head()

# %% [raw]
# So, here we can compare the performance of all the models using the metrics calculated. Let’s see all the models used to predict the root cause Prediction together along with the metrics for the ease of comparison.
#
# From the table above, it is clear that for the present problem, the best performing model is OPTIMIZED RANDOM FOREST with the highest WITH f1_macro AT 91%. But we have to keep in mind that the deep learning is also not far behind with respect to the metrics. And the beauty of deep learning is that with the increase in the training sample size, the accuracy of the model also increases.
#
# If the data set is small and we need a good prediction for the response variable as the case here; it is a good idea to go for models like Random Forest. As they are capable of generating good prediction with lesser training data or labelled data.
#
# THIS DATASET SHOULD BE TACKLED BY TRAIN/TEST.
#
#
# NUMBER OF EXAMPLES
# 	training set     ---
# 	test set         ---
#
# NUMBER OF ATTRIBUTES
# 	18
#
# The best Model here is to obtain an accuracy of 91% WITH f1_macro, that related OPTIMIZED RANDOM FOREST.

# %% [markdown]
# ############################################################################################################################
#
# ![image.png](attachment:image.png)
#
# ############################################################################################################################

# %%
import pandas as pd
from scipy import stats

# %% [raw]
# Pandas has a very simple contingency table feature. Below, I specify the two variables of interest (RootCause and Bot) and set margins=True so I get marginal totals (“All”).

# %% [markdown]
# ###### Creating a contingency table

# %% [raw]
# contab_freq = pd.crosstab(
#     predDf['RootCause_NUM'],
#     predDf['ImtId_NUM'],
#     margins = True
#    )
# contab_freq

# %% [raw]
# Typically, showing frequencies is less useful than relative frequencies. Here, I am interested in the row percentages: what is the probability that a female is a manager versus the probability a male is a manager.
#
# We can get relative frequencies using the normalize argument. If normalize  = True, then we get the relative frequency in each cell relative to the total number of employees. This is not very useful. What we want instead is to normalize by row. The parameter for this is: normalize = 'index'. Why “index” instead of “row”? Because each row has a row number (or index).

# %% [markdown]
# ###### Showing row percentages

# %% [raw]
# conttab_relfreq = pd.crosstab(
#     predDf['RootCause_NUM'],
#     predDf['ImtId_NUM'],
#     margins = True,
#     normalize='index'
#    )
# conttab_relfreq

# %%
df_Responsibility = df['Responsibility']

df.shape
# Out:
# (97100, 34)

# %%
predDf = pd.DataFrame({'Responsibility_NUM':df_Responsibility, 'RootCause_NUM':pred_adab_o})
predDf
# Out:
#                    Responsibility_NUM  RootCause_NUM
# 0      Ops Cable and Wireless Ontario            4.0
# 1                                 NOC            5.0
# 2          Ops Cable and Wireless GTA            5.0
# 3                                 NOC            5.0
# 4                                 NOC            5.0
# ...                               ...            ...
# 96996  Ops Cable and Wireless Ontario            NaN
# 96997                             NOC            NaN
# 96998                             NOC            NaN
# 96999                             NOC            NaN
# 97000                             NOC            NaN
#
# [97100 rows x 2 columns]

# %%
contab_freq = pd.crosstab(
    predDf['RootCause_NUM'],
    predDf['Responsibility_NUM'],
    margins = True
   )
contab_freq
# Out:
# Responsibility_NUM  AB MW Region  Access Network Engineering  \
# RootCause_NUM
# 0.0                           27                          17
# 1.0                            1                           0
# 2.0                            7                           9
# 3.0                            7                           2
# 4.0                           21                          15
# 5.0                          176                         106
# All                          239                         149
#
# Responsibility_NUM  Access Networks AB MW Region  Access Networks Atlantic  \
# RootCause_NUM
# 0.0                                           45                        25
# 1.0                                            0                         0
# 2.0                                           16                        15
# 3.0                                           13                         8
# 4.0                                           45                        17
# 5.0                                          382                       134
# All                                          501                       199
#
# Responsibility_NUM  Access Networks BC Region  Access Networks National  \
# RootCause_NUM
# 0.0                                        28                         8
# 1.0                                         1                         0
# 2.0                                        10                         3
# 3.0                                        15                         1
# 4.0                                        31                         7
# 5.0                                       287                        79
# All                                       372                        98
#
# Responsibility_NUM  Access Networks Quebec  Atlantic  BC Region  \
# RootCause_NUM
# 0.0                                     29        20         19
# 1.0                                      0         0          1
# 2.0                                     12         4          4
# 3.0                                      5         5          6
# 4.0                                     20        15         15
# 5.0                                    209       140        163
# All                                    275       184        208
#
# Responsibility_NUM  Cable and Wireless GTA  ...  OSS  \
# RootCause_NUM                               ...
# 0.0                                     53  ...    0
# 1.0                                      1  ...    0
# 2.0                                     19  ...    1
# 3.0                                     14  ...    1
# 4.0                                     48  ...    0
# 5.0                                    373  ...    2
# All                                    508  ...    4
#
# Responsibility_NUM  OSS Infrastructure and Systems  Operation Core Video  \
# RootCause_NUM
# 0.0                                              8                     0
# 1.0                                              0                     0
# 2.0                                              0                     0
# 3.0                                              4                     0
# 4.0                                              5                     0
# 5.0                                             51                     3
# All                                             68                     3
#
# Responsibility_NUM  Ops Cable and Wireless GTA  \
# RootCause_NUM
# 0.0                                         49
# 1.0                                          2
# 2.0                                         23
# 3.0                                         16
# 4.0                                         48
# 5.0                                        427
# All                                        565
#
# Responsibility_NUM  Ops Cable and Wireless Ontario  Quebec  TAC  \
# RootCause_NUM
# 0.0                                             52      36   15
# 1.0                                              4       0    0
# 2.0                                             16       9    7
# 3.0                                             19       5    9
# 4.0                                             55      19    6
# 5.0                                            472     203  109
# All                                            618     272  146
#
# Responsibility_NUM  Wireless Access Planning  \
# RootCause_NUM
# 0.0                                       14
# 1.0                                        0
# 2.0                                        3
# 3.0                                        3
# 4.0                                       13
# 5.0                                       99
# All                                      132
#
# Responsibility_NUM  Wireline Access Network and Transport Ops    All
# RootCause_NUM
# 0.0                                                       119   2268
# 1.0                                                         3     61
# 2.0                                                        47    823
# 3.0                                                        48    758
# 4.0                                                       119   1995
# 5.0                                                      1074  18469
# All                                                      1410  24374
#
# [7 rows x 25 columns]

# %%
conttab_relfreq = pd.crosstab(
    predDf['RootCause_NUM'],
    predDf['Responsibility_NUM'],
    margins = True,
    normalize='index'
   )
conttab_relfreq
# Out:
# Responsibility_NUM  AB MW Region  Access Network Engineering  \
# RootCause_NUM
# 0.0                     0.011905                    0.007496
# 1.0                     0.016393                    0.000000
# 2.0                     0.008505                    0.010936
# 3.0                     0.009235                    0.002639
# 4.0                     0.010526                    0.007519
# 5.0                     0.009529                    0.005739
# All                     0.009806                    0.006113
#
# Responsibility_NUM  Access Networks AB MW Region  Access Networks Atlantic  \
# RootCause_NUM
# 0.0                                     0.019841                  0.011023
# 1.0                                     0.000000                  0.000000
# 2.0                                     0.019441                  0.018226
# 3.0                                     0.017150                  0.010554
# 4.0                                     0.022556                  0.008521
# 5.0                                     0.020683                  0.007255
# All                                     0.020555                  0.008164
#
# Responsibility_NUM  Access Networks BC Region  Access Networks National  \
# RootCause_NUM
# 0.0                                  0.012346                  0.003527
# 1.0                                  0.016393                  0.000000
# 2.0                                  0.012151                  0.003645
# 3.0                                  0.019789                  0.001319
# 4.0                                  0.015539                  0.003509
# 5.0                                  0.015540                  0.004277
# All                                  0.015262                  0.004021
#
# Responsibility_NUM  Access Networks Quebec  Atlantic  BC Region  \
# RootCause_NUM
# 0.0                               0.012787  0.008818   0.008377
# 1.0                               0.000000  0.000000   0.016393
# 2.0                               0.014581  0.004860   0.004860
# 3.0                               0.006596  0.006596   0.007916
# 4.0                               0.010025  0.007519   0.007519
# 5.0                               0.011316  0.007580   0.008826
# All                               0.011283  0.007549   0.008534
#
# Responsibility_NUM  Cable and Wireless GTA  ...  \
# RootCause_NUM                               ...
# 0.0                               0.023369  ...
# 1.0                               0.016393  ...
# 2.0                               0.023086  ...
# 3.0                               0.018470  ...
# 4.0                               0.024060  ...
# 5.0                               0.020196  ...
# All                               0.020842  ...
#
# Responsibility_NUM  Network Transportation and Operations       OSS  \
# RootCause_NUM
# 0.0                                              0.008377  0.000000
# 1.0                                              0.000000  0.000000
# 2.0                                              0.008505  0.001215
# 3.0                                              0.006596  0.001319
# 4.0                                              0.010025  0.000000
# 5.0                                              0.010937  0.000108
# All                                              0.010380  0.000164
#
# Responsibility_NUM  OSS Infrastructure and Systems  Operation Core Video  \
# RootCause_NUM
# 0.0                                       0.003527              0.000000
# 1.0                                       0.000000              0.000000
# 2.0                                       0.000000              0.000000
# 3.0                                       0.005277              0.000000
# 4.0                                       0.002506              0.000000
# 5.0                                       0.002761              0.000162
# All                                       0.002790              0.000123
#
# Responsibility_NUM  Ops Cable and Wireless GTA  \
# RootCause_NUM
# 0.0                                   0.021605
# 1.0                                   0.032787
# 2.0                                   0.027947
# 3.0                                   0.021108
# 4.0                                   0.024060
# 5.0                                   0.023120
# All                                   0.023180
#
# Responsibility_NUM  Ops Cable and Wireless Ontario    Quebec       TAC  \
# RootCause_NUM
# 0.0                                       0.022928  0.015873  0.006614
# 1.0                                       0.065574  0.000000  0.000000
# 2.0                                       0.019441  0.010936  0.008505
# 3.0                                       0.025066  0.006596  0.011873
# 4.0                                       0.027569  0.009524  0.003008
# 5.0                                       0.025556  0.010991  0.005902
# All                                       0.025355  0.011159  0.005990
#
# Responsibility_NUM  Wireless Access Planning  \
# RootCause_NUM
# 0.0                                 0.006173
# 1.0                                 0.000000
# 2.0                                 0.003645
# 3.0                                 0.003958
# 4.0                                 0.006516
# 5.0                                 0.005360
# All                                 0.005416
#
# Responsibility_NUM  Wireline Access Network and Transport Ops
# RootCause_NUM
# 0.0                                                  0.052469
# 1.0                                                  0.049180
# 2.0                                                  0.057108
# 3.0                                                  0.063325
# 4.0                                                  0.059649
# 5.0                                                  0.058151
# All                                                  0.057849
#
# [7 rows x 24 columns]

# %% [raw]
# Root Cause
# Change Management Activity	29442
# Other                   	67658
# All                     	97100
# Here, each row sums to 100%. Thus, for the total set of Root Cause, 30% are Change Management Activity and 70% are Others. The advantage of this presentation is that these percentages are directly comparable even though the majority (67658/97100) Root Cause of the data set are not Change Management Activity.

# %% [markdown]
# ###### Chi-squared test of independence

# %% [raw]
# The row percentages leave us with the impression that managerial status depends on gender. We can test this more formally using the  (X^2/ˈkaɪ skweə(r)) test of independence.
#
# Scipy has a method called chi2_contingency() that takes a contingency table of observed frequencies as input. Note that this table cannot include marginal totals or marginal frequencies. Instead, it must consist of m x n observations:

# %% [raw]
# contab_obs = pd.crosstab(
#     predDf['RootCause_NUM'],
#     predDf['ImtId_NUM'],
#     margins = False)
# chi = stats.chi2_contingency(contab_obs)
# chi

# %% [raw]
# (26.617776266575998,
#  2.479518719230249e-07,
#  1,
#  array([[ 23.55769231, 116.44230769],
#         [ 11.44230769,  56.55769231]]))
#
# The output of the chi2_contingency() method is not particularly attractive but it contains what we need:
#
# The first line is the X^2 statistic, which we can safely ignore
#
# The second line is the probability of getting a X^2 statistic that large if the two variables are independent. This p-value is very small (10^-7) so we conclude there is almost zero chance that gender and managerial status are independent at this bank.
#
# The third line is the degrees of freedom, which we can safely ignore.
#
# The remainder of the output is a matrix showing the expected frequencies under the assumption in independence. These expected values are quite different from the observed values above.
#
# You may notice that the X^2 statistic and p-value are different from those provided by R. This is because scipy defaults to the “Pearson’s Chi-squared test with Yates’ continuity correction” version of the test.

# %%
predDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97100 entries, 0 to 97000
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Responsibility_NUM  97100 non-null  object
#  1   RootCause_NUM       24374 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.2+ MB

# %% [raw]
# #df['ImtId_NUM']=df.ImtId.cat.codes #get list of map of x to numeric values
# map_dict=dict(enumerate(df.ImtId.cat.categories)) #{0:'bad',1:'good',2:'great'} .astype('category').values categories
# #col x_map maps the numeric to origin value of x
# df['ImtId_Map']=df['ImtId_NUM'].map(map_dict) #i=imtid
# df['ImtId_Map']

# %% [raw]
# pd.crosstab([df['RootCause'], df['Bot']], df['RuleName'], normalize = True)

# %%
pd.crosstab([df['RootCause'], df['Bot']], df['Responsibility'])
# Out:
# Responsibility                                                    AB MW Region  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE             0
#                   DIAGNOSTIC-MW-Ceragon                                      0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                    0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                 0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                 0
# ...                                                                        ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                        0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                     0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                   0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                          0
#                   Unknown                                                    0
#
# Responsibility                                                    Access Network Engineering  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                           0
#                   DIAGNOSTIC-MW-Ceragon                                                    0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                  0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                               0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                               0
# ...                                                                                      ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                      0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                   0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                                 0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                        0
#                   Unknown                                                                  0
#
# Responsibility                                                    Access Networks AB MW Region  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                             0
#                   DIAGNOSTIC-MW-Ceragon                                                      0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                    1
#                   DIAGNOSTIC-TLAN-INTEGRATED                                                 0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                                 0
# ...                                                                                        ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                        0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                     0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                                   0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                          0
#                   Unknown                                                                    0
#
# Responsibility                                                    Access Networks Atlantic  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                         0
#                   DIAGNOSTIC-MW-Ceragon                                                  0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                1
#                   DIAGNOSTIC-TLAN-INTEGRATED                                             1
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                             0
# ...                                                                                    ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                    0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                 0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                               0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                      0
#                   Unknown                                                                0
#
# Responsibility                                                    Access Networks BC Region  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                          0
#                   DIAGNOSTIC-MW-Ceragon                                                   0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                 0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                              0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                              0
# ...                                                                                     ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                     1
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                  1
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                                0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                       0
#                   Unknown                                                                 0
#
# Responsibility                                                    Access Networks National  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                         0
#                   DIAGNOSTIC-MW-Ceragon                                                  0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                             0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                             0
# ...                                                                                    ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                    0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                 0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                               0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                      0
#                   Unknown                                                                0
#
# Responsibility                                                    Access Networks Quebec  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                       0
#                   DIAGNOSTIC-MW-Ceragon                                                0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                              0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                           0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                           0
# ...                                                                                  ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                  0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                               0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                             0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                    0
#                   Unknown                                                              0
#
# Responsibility                                                    Atlantic  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE         0
#                   DIAGNOSTIC-MW-Ceragon                                  0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                0
#                   DIAGNOSTIC-TLAN-INTEGRATED                             0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                             0
# ...                                                                    ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                    0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                 0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED               0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                      0
#                   Unknown                                                0
#
# Responsibility                                                    BC Region  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE          0
#                   DIAGNOSTIC-MW-Ceragon                                   0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                 0
#                   DIAGNOSTIC-TLAN-INTEGRATED                              0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                              0
# ...                                                                     ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                     1
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                  0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                2
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                       1
#                   Unknown                                                 2
#
# Responsibility                                                    Cable and Wireless GTA  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                       0
#                   DIAGNOSTIC-MW-Ceragon                                                0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                              0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                           1
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                           0
# ...                                                                                  ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                  0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                               0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                             0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                    0
#                   Unknown                                                              0
#
# Responsibility                                                    ...  OSS  \
# RootCause         Bot                                             ...
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE  ...    0
#                   DIAGNOSTIC-MW-Ceragon                           ...    0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded         ...    0
#                   DIAGNOSTIC-TLAN-INTEGRATED                      ...    0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                      ...    0
# ...                                                               ...  ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS             ...    0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS          ...    0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED        ...    0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED               ...    0
#                   Unknown                                         ...    0
#
# Responsibility                                                    OSS Infrastructure and Systems  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                               0
#                   DIAGNOSTIC-MW-Ceragon                                                        0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                      0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                                   0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                                   0
# ...                                                                                          ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                          0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                       0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                                     0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                            0
#                   Unknown                                                                      0
#
# Responsibility                                                    Operation Core Video  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                     0
#                   DIAGNOSTIC-MW-Ceragon                                              0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                            0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                         0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                         0
# ...                                                                                ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                             0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                           0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                  0
#                   Unknown                                                            0
#
# Responsibility                                                    Ops Cable and Wireless GTA  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                           1
#                   DIAGNOSTIC-MW-Ceragon                                                    0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                  0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                               0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                               0
# ...                                                                                      ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                      0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                   0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                                 0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                        0
#                   Unknown                                                                  0
#
# Responsibility                                                    Ops Cable and Wireless Ontario  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                               0
#                   DIAGNOSTIC-MW-Ceragon                                                        1
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                      0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                                   0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                                   0
# ...                                                                                          ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                          0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                       0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                                     0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                            0
#                   Unknown                                                                      0
#
# Responsibility                                                    Quebec  TAC  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE       0    0
#                   DIAGNOSTIC-MW-Ceragon                                0    0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded              0    0
#                   DIAGNOSTIC-TLAN-INTEGRATED                           0    0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                           0    0
# ...                                                                  ...  ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                  0    0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS               0    0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED             0    0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                    0    0
#                   Unknown                                              0    0
#
# Responsibility                                                    Unknown  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE        0
#                   DIAGNOSTIC-MW-Ceragon                                 0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded               0
#                   DIAGNOSTIC-TLAN-INTEGRATED                            0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                            0
# ...                                                                   ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                   0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED              0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                     0
#                   Unknown                                               0
#
# Responsibility                                                    Wireless Access Planning  \
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                         0
#                   DIAGNOSTIC-MW-Ceragon                                                  0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                             0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                             0
# ...                                                                                    ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                    0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                 0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                               0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                      0
#                   Unknown                                                                0
#
# Responsibility                                                    Wireline Access Network and Transport Ops
# RootCause         Bot
# Application Fault DIAGNOSTIC-ERICSSON-UMTS-DIGITAL-CABLE-FAILURE                                          0
#                   DIAGNOSTIC-MW-Ceragon                                                                   0
#                   DIAGNOSTIC-MW-MiniLink-Service-Degraded                                                 0
#                   DIAGNOSTIC-TLAN-INTEGRATED                                                              0
#                   DIAGNOSTIC-UMTS-MGW-ALARMS                                                              0
# ...                                                                                                     ...
# Vandalism         DIAGNOSTIC_GENERIC_WITH_CELL_STATUS                                                     0
#                   DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS                                                  0
#                   RESOLUTION-ERICSSON-LTE-SERVICE-DEGRADED                                                0
#                   RESOLUTION-NODEB-SERVICE-DEGRADED                                                       0
#                   Unknown                                                                                 0
#
# [1054 rows x 28 columns]

# %%
predDf
# Out:
#                    Responsibility_NUM  RootCause_NUM
# 0      Ops Cable and Wireless Ontario            4.0
# 1                                 NOC            5.0
# 2          Ops Cable and Wireless GTA            5.0
# 3                                 NOC            5.0
# 4                                 NOC            5.0
# ...                               ...            ...
# 96996  Ops Cable and Wireless Ontario            NaN
# 96997                             NOC            NaN
# 96998                             NOC            NaN
# 96999                             NOC            NaN
# 97000                             NOC            NaN
#
# [97100 rows x 2 columns]

# %%
print('no. of Change Management Activity')
df[df['RootCause']=='Change Management Activity'][['Bot', 'RuleName']].groupby(['Bot']).agg('count').sort_values('RuleName', 
                         ascending=False).head(10).style.background_gradient(cmap='Wistia')
# Out:
# no. of Change Management Activity
# <style type="text/css">
# #T_1633b_row0_col0 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_1633b_row1_col0 {
#   background-color: #fde920;
#   color: #000000;
# }
# #T_1633b_row2_col0 {
#   background-color: #f0f54e;
#   color: #000000;
# }
# #T_1633b_row3_col0 {
#   background-color: #eafa66;
#   color: #000000;
# }
# #T_1633b_row4_col0 {
#   background-color: #e7fc6f;
#   color: #000000;
# }
# #T_1633b_row5_col0 {
#   background-color: #e7fd71;
#   color: #000000;
# }
# #T_1633b_row6_col0 {
#   background-color: #e5fe75;
#   color: #000000;
# }
# #T_1633b_row7_col0 {
#   background-color: #e4ff78;
#   color: #000000;
# }
# #T_1633b_row8_col0, #T_1633b_row9_col0 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_1633b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1633b_level0_col0" class="col_heading level0 col0" >RuleName</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bot</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1633b_level0_row0" class="row_heading level0 row0" >Unknown</th>
#       <td id="T_1633b_row0_col0" class="data row0 col0" >5193</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row1" class="row_heading level0 row1" >DIAGNOSTIC-RCBIN-LINK-DOWN</th>
#       <td id="T_1633b_row1_col0" class="data row1 col0" >1323</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row2" class="row_heading level0 row2" >DIAGNOSTIC_GENERIC_WITH_CELL_STATUS</th>
#       <td id="T_1633b_row2_col0" class="data row2 col0" >710</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row3" class="row_heading level0 row3" >DIAGNOSTIC-IPRAN-SYNTH-LINK-DOWN-CORRELATED-ALARMS</th>
#       <td id="T_1633b_row3_col0" class="data row3 col0" >396</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row4" class="row_heading level0 row4" >DIAGNOSTIC-TLAN-INTEGRATED</th>
#       <td id="T_1633b_row4_col0" class="data row4 col0" >277</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row5" class="row_heading level0 row5" >DIAGNOSTIC-CASA-GENERIC-LINK-STATUS</th>
#       <td id="T_1633b_row5_col0" class="data row5 col0" >250</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row6" class="row_heading level0 row6" >DIAGNOSTIC_GENERIC_WITH_NO_CELL_STATUS</th>
#       <td id="T_1633b_row6_col0" class="data row6 col0" >201</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row7" class="row_heading level0 row7" >DIAGNOSTIC-SBC-REDUNDANCY-ALARMS</th>
#       <td id="T_1633b_row7_col0" class="data row7 col0" >148</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row8" class="row_heading level0 row8" >DIAGNOSTIC-ERICSSON-LTE-SERVICE-DEGRADED-SECTOR</th>
#       <td id="T_1633b_row8_col0" class="data row8 col0" >136</td>
#     </tr>
#     <tr>
#       <th id="T_1633b_level0_row9" class="row_heading level0 row9" >DIAGNOSTIC-EON-LINK-DOWN-ALARMS</th>
#       <td id="T_1633b_row9_col0" class="data row9 col0" >126</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# X.value_counts(dropna=False)

# %%
X.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [196], in <cell line: 1>()
# ----> 1 X.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
plt.rcParams['figure.figsize']=25,25

plt.style.use('ggplot')
weights=pd.Series(log_reg.coef_[0], index=['ImtId_NUM', 'RuleName_NUM', 
       'Resolution_NUM', 'RecoveryPrime_NUM', 'WorkflowState_NUM',
       'Responsibility_NUM', 'ResponsibilityDepartment_NUM', 'State_NUM',
       'Status_NUM', 'Submitter_NUM', 'SubmitterDepartment_NUM', 'Bot_NUM',
       'AutomationSuiteName_NUM', 'AutomationStatus_NUM',
       'AutomationFramework_NUM'])

params_weight =weights.plot(kind='bar', title='feature going to help us for successfull Change Management Activity ')
fig=params_weight.get_figure()
plt.show()

# %%
predDf = pd.DataFrame({'Responsibility_NUM':df_Responsibility_M,
                       'RootCause_NUM':df_RootCause_M ,
                       'RootCause_NUM':pred_adab_o
                       
                      })
predDf

# %%
#********************************************************************************************************************

# %% [raw]
# from sklearn.preprocessing import StandardScaler
#
# #to_scale=df_cln.select_dtypes(include='number').columns.tolist()[1:-1]
# sc=StandardScaler()
# scaled=sc.fit_transform(X)
# x_scl=pd.DataFrame(scaled, columns=X.columns)

# %% [raw]
# # check weathear data is standardized or not
# plt.subplot(121)
# plt.ylim(-1,1)
#
# means=[]
# for i in range(x_scl.shape[1]):
#     means.append(np.mean(x_scl.iloc[:,i]))
# plt.plot(means, scaley=False)
# plt.title('Means of scaled features')
#
# plt.subplot(122)
# plt.ylim(0,2)
# vars=[]
# for i in range(x_scl.shape[1]):
#     vars.append(np.var(x_scl.iloc[:,i]))
# plt.plot(vars, scaley=False)
# plt.title('Varience of scaled features')
# plt.show()

# %% [raw]
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(x_scl, y, test_size=0.25)

# %% [raw]
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, roc_auc_score

# %% [raw]
# LR=LogisticRegression()
# LR.fit(X_train, y_train)

# %% [raw]
# LR.score(X_test, y_test)

# %% [raw]
# y_pred_LR=LR.predict(X_test)

# %% [raw]
# plt.rcParams['figure.figsize']=25,5
# ax= plt.subplot()
# cm = confusion_matrix(y_test, y_pred_LR)
# sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
#
# # labels, title and ticks
# ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
# ax.set_title('Confusion Matrix');
# #ax.xaxis.set_ticklabels(['Change Management Activity', 'Others']); ax.yaxis.set_ticklabels(['Change Management Activity', 'Others']);

# %% [raw]
# fpr, tpr, thres = roc_curve(y_test, LR.predict_proba(X_test)[:,1])
# roc_auc = auc(fpr, tpr)

# %% [raw]
# plt.rcParams['figure.figsize']=10,7
# plt.plot(fpr, tpr, label = 'ROC Curve' %roc_auc)
# plt.plot([0, 1], [0, 1], '--')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.legend()
# plt.title('ROC-AUC graph')
# plt.show()

# %% [raw]
# from sklearn.ensemble import RandomForestClassifier
# #from sklearn.feature_selection import SelectFromModel

# %% [raw]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [raw]
# RF =RandomForestClassifier()
# RF.fit(X_train, y_train)

# %% [raw]
# RF.score(X_test, y_test)

# %% [raw]
# y_pred_RF=RF.predict(X_test)

# %% [raw]
# plt.rcParams['figure.figsize']=5,5
# ax= plt.subplot()
# cm = confusion_matrix(y_test, y_pred_RF)
# sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells
#
# # labels, title and ticks
# ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
# ax.set_title('Confusion Matrix');
# ax.xaxis.set_ticklabels(['Change Management Activity', 'Others']); ax.yaxis.set_ticklabels(['Change Management Activity', 'Others']);

# %% [raw]
# fpr, tpr, thres = roc_curve(y_test, RF.predict_proba(X_test)[:,1])
# roc_auc = auc(fpr, tpr)

# %% [raw]
# plt.rcParams['figure.figsize']=5,5
# plt.plot(fpr, tpr, label = 'ROC Curve' %roc_auc)
# plt.plot([0, 1], [0, 1], '--')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.legend()
# plt.title('ROC-AUC graph')
# plt.show()

# %% [markdown]
# ###### Selecting most helping Parametes

# %% [raw]
# X.columns

# %% [raw]
# plt.rcParams['figure.figsize']=15,7
# plt.style.use('ggplot')
# weights=pd.Series(LR.coef_[0], index=['ImtId_NUM', 'RuleName_NUM', 'RootCause_NUM',
#        'Resolution_NUM', 'RecoveryPrime_NUM', 'WorkflowState_NUM',
#        'Responsibility_NUM', 'ResponsibilityDepartment_NUM', 'State_NUM',
#        'Status_NUM', 'Submitter_NUM', 'SubmitterDepartment_NUM', 'Bot_NUM',
#        'AutomationSuiteName_NUM', 'AutomationStatus_NUM',
#        'AutomationFramework_NUM'])
#
# params_weight =weights.plot(kind='bar', title='feature going to help us for successfull Change Management Activity ')
# fig=params_weight.get_figure()
# plt.show()

# %% [markdown]
# ###### Parameters that impact on Change Managment Activity:
#
# -State
#
# -WorkflowState
#
# -Resolution
#
# -Create Date
#
# -Submitter
#
# -Recovery Prime
#
# -Responsibility Department
#
# -Automation Suite Name
#
# -Bot
#
# -Responsibility

# %%
#*********************************************************************

# %%
log_reg.fit(X_train, y_train)
pred_log = log_reg.predict(X_test)
score_log = accuracy_score(y_test,pred_log)

# %%
'''
PCA uses Singular Value Decomposition to calculate 
new features that help discrimate based on their differences
'''
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
pca.fit(X_train_scaled)

# %%
#Explained variance shows discriminating power of each new feature 
#the first five are chosen as the values are significant
pca.explained_variance_ratio_

# %%
pca.explained_variance_ratio_.sum()

# %%
#the new features (principal components) do not have much 
#physical interpretation as the original features 
#but are calculated/derived using the original features 
X_train_pca = pd.DataFrame(pca.transform(X_train_scaled))
X_train_pca.head()

# %%
#remodelling in the new feature space
model_pca = LogisticRegression(solver='saga',class_weight={False:1, True:9})
model_pca.fit(X_train_pca,y_train)

# %%
#the test set needs to be transformed as well
X_test_pca = pd.DataFrame(pca.transform(X_test_scaled))
model_pca.score(X_test_pca,y_test)

# %%
#scoring the model on the new featureset
y_pred_pca = model_pca.predict(X_test_pca)
print(classification_report(y_test,y_pred_pca))
confusion_matrix(y_test,y_pred_pca)

# %%
#*********************************************************************

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_scaled = StandardScaler().fit_transform(X)

# %%
from sklearn.decomposition import PCA

# %%
X.shape

# %%
pca = PCA(n_components=2)#n_components : int, float, None or str 

   #int Number of components to keep
   #float  select the number of components such that the amount of variance that needs to be explained is greater than the percentage specified by n_components


principalComponents = pca.fit_transform(X_scaled)

# %%
pca.explained_variance_ratio_

# %%
pca.explained_variance_ratio_[:4]

# %%
pca.explained_variance_ratio_[:4].sum()

# %%
pca.explained_variance_ratio_.sum()

# %%
pca.explained_variance_ratio_[:10].sum()

# %%
cum_exp_var = []
s=0
for i in pca.explained_variance_ratio_:
    s+=i
    cum_exp_var.append(s)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(2),cum_exp_var)

# %%
pca.explained_variance_ratio_[:235].sum()

# %%
pca = PCA(0.9)
principalComponents = pca.fit_transform(X_scaled)

# %%
principalComponents.shape# you can see that 236 new featurs can cover 90% of varaince

# %%
len(pca.explained_variance_ratio_)

# %%
(pca.explained_variance_ratio_).sum()

# %%
# if you use float number in pca it is beteer to check the values to see how much the last components are significant
pca.explained_variance_ratio_

# %%
pca = PCA(n_components=4)
principalComponents = pca.fit_transform(X_scaled)

# %%
pca.explained_variance_ratio_

# %%
pca.explained_variance_ratio_.sum()

# %%
#df.reset_index(inplace=True, drop=True)
X.reset_index( drop=True)

# %%
principalDF=pd.DataFrame(data=principalComponents,columns=["PC1","PC2","PC3","PC4"])

# %%
new_df=pd.concat([principalDF,y], axis=1, join_axes=[principalDF.index])

# %%
new_df.head()

# %%
from sklearn.ensemble import RandomForestClassifier          # 
from sklearn.svm import SVC, LinearSVC                       # 
from sklearn.linear_model import LogisticRegression          #
from sklearn.neighbors import KNeighborsClassifier           # KNN
from sklearn.naive_bayes import GaussianNB                   # 
from sklearn.tree import DecisionTreeClassifier              # 
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier     

from sklearn.metrics import classification_report, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.ensemble import VotingClassifier

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings('ignore')

get_ipython().magic('matplotlib inline')

# %%
Classify_result=[]
names=[]
prediction=[]
for name,classifier in Classifiers:
    classifier=classifier
    classifier.fit(X_train,y_train)
    y_pred=classifier.predict(X_test)
    recall=recall_score(y_test,y_pred,average=None)
    precision=precision_score(y_test,y_pred,average=None)
    f1 =f1_score(y_test,y_pred,average=None)
    class_eva=pd.DataFrame([recall,precision,f1])
    Classify_result.append(class_eva)
    name=pd.Series(name)
    names.append(name)
    y_pred=pd.Series(y_pred)
    prediction.append(y_pred)

# %% [raw]
# names=pd.DataFrame(names)
# names=names[0].tolist()
# names

# %% [raw]
# names=pd.DataFrame(names)
# names=names[0].tolist()
# result=pd.concat(Classify_result,axis=1)
# result.columns=names
# result.index=["recall","precision","F1"]
# result
