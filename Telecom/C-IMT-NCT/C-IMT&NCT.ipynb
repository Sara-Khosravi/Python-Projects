# %% [markdown]
# ###############################################################################################################################
#
# ## Predicting NCT by Implementing Supervised Mechine Learning Regressor Algorithms

# %% [markdown]
#  ---------------------------
#
#
# ------------------------------------
#
# ###############################################################################################################################

# %% [markdown]
# #### ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Introduction
# ###############################################################################################################################

# %% [markdown]
# ### 1.1. Problem Statement

# %% [raw]
# The data contains Network Automation attributes from November 2021 to YTD.
#
# The aim is to build a predictive model and find out the element of the network. And also is there any correlation between NCT and IMT tickets in each Element.
#
# Using this model will try to understand the network, and predict the element.
#
# Data Set Information:
#
# The Network Operation Automation dataset contains 18 attributes all of which are Categorical.
# The first one being IMT Number.  The most important columns is the class which has been
# coded as follows :
#         1 Flow (Bot Name)
#         2
#
#
#
# Validation set:

# %% [raw]
# in this project, the root cause is predicted and the best classification is found in the network data. The models build in the project are as follows:
#
# 1. LinearClassifier
# 2. KNeighbors
# 3. RandomForestClassifier
# 4. AdaBoostClassifier
# 5. SVR

# %% [raw]
# Recall that we are interested in knowing if there is a relationship between 'Root Cause' and ('Status','State','Recovery Prime', 'Automation Name (Bot)','Automation Type','Automation Framework','Rule Name','Create Date','Imt Id','Responsibility Department','Submitter','Resolution','Workflow State','Responsibility','Automation Status','Team Name'). In order to do so, we would have to use the Chi-squared test. But first, let's state our null hypothesis and the alternative hypothesis.
#
# H0:There is no statistically significant relationship between Root Cause and Automation Name (Bot).
#
# Ha:There is a statistically significant relationship between Root Cause and Automation Name (Bot).
#
# and so on...
#
#
# ('Status','State','Recovery Prime', 'Automation Name (Bot)','Automation Type','Automation Framework','Rule Name','Create Date','Imt Id','Responsibility Department','Submitter','Resolution','Workflow State','Responsibility','Automation Status','Team Name')

# %% [raw]
# Metrics	Definition
# Precision	Precision is defined as the ratio of true positives to the sum of true and false positives.
# Recall	Recall is defined as the ratio of true positives to the sum of true positives and false negatives.
# F1 Score	The F1 is the weighted harmonic mean of precision and recall. The closer the value of the F1 score is to 1.0, the better the expected performance of the model is.
# Support	Support is the number of actual occurrences of the class in the dataset. It doesn’t vary between models, it just diagnoses the performance evaluation process.

# %% [raw]
# Popular algorithms that can be used for multi-class classification include:
#
# k-Nearest Neighbors.
# Decision Trees.
# Naive Bayes.
# Random Forest.
# Gradient Boosting.
#
# Binary classification algorithms that can use these strategies for multi-class classification include:
#
# Logistic Regression.
# Support Vector Machine.

# %% [markdown]
# ## 2. DATA COLLECTION
#
# ###############################################################################################################################

# %% [markdown]
# ### 2.1. Connect to dataset

# %%
# SETTING UP WORKING DIRECTORY
import os
os.getcwd()
os.chdir(r'C:\Users\sara.khosravi\Documents\Sara\Data Analysis\ML')
os.getcwd()
# Out:
# 'C:\\Users\\sara.khosravi\\Documents\\Sara\\Data Analysis\\ML'

# %% [markdown]
# ### 2.2. combine the datasets

# %%
# IMPORTING PACKAGES AND LIBRARIES
import warnings
warnings.filterwarnings('ignore')

#import libraries for the data-structures
# Importing the numpy and pandas package
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra

import sys
#!pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#import pandas_profiling


# EDA Package
#!pip install sweetviz
#import sweetviz as sv

#import libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# !pip3 install plotly
import plotly
import plotly.figure_factory as ff

from datetime import datetime
from matplotlib import dates
from datetime import datetime
import time

import statsmodels.api as sm
from scipy.stats import norm


#import libraries for modeling
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error
import math
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.tree import plot_tree
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn import tree
from sklearn.linear_model import Ridge
from sklearn.linear_model import LassoCV 
from sklearn.linear_model import RidgeCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import VotingRegressor
# !pip install xgboost
from xgboost import XGBRegressor
import xgboost as xgb

from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor

print('Libraries imported and installed.')
# Out:
# ...
# Libraries imported and installed.

# %%
# a list with all missing value formats
missing_value_formats = ["n.a.","?","NA","n/a", "na", "--"]

# %%
#Read files:

# READING THE DATA

#IMT
dfimt = pd.read_excel(r'C:\Users\sara.khosravi\Documents\Sara\Data Analysis\ML\Data\UC-1-NCT&IMT\IMT.xlsx',na_values=missing_value_formats)
print(dfimt.shape)

#NCT
dfnct = pd.read_excel(r'C:\Users\sara.khosravi\Documents\Sara\Data Analysis\ML\Data\UC-1-NCT&IMT\NCT.xlsx',na_values=missing_value_formats)
print(dfnct.shape)
# Out:
# (23607, 16)
# (172358, 11)

# %%
# UNDERSTANDING THE DATASET
dfimt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23607 entries, 0 to 23606
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Start Date                                 23515 non-null  datetime64[ns]
#  1   Com Network Element Id                     23607 non-null  object
#  2   Service Impact                             23607 non-null  int64
#  3   Network Impact                             15361 non-null  float64
#  4   Duration                                   0 non-null      float64
#  5   Severity                                   23508 non-null  object
#  6   Site                                       18310 non-null  object
#  7   Site Id                                    23597 non-null  object
#  8   Element                                    23579 non-null  object
#  9   Element Type                               23481 non-null  object
# ...

# %%
# UNDERSTANDING THE DATASET
dfnct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172358 entries, 0 to 172357
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Com Network Element Id  172358 non-null  object
#  1   Duration                13067 non-null   float64
#  2   Element                 172328 non-null  object
#  3   Element Type            171328 non-null  object
#  4   Network Impact          172358 non-null  int64
#  5   Region                  159771 non-null  object
#  6   Service Impact          169962 non-null  float64
#  7   Service Impacted        129038 non-null  object
#  8   Severity                171371 non-null  object
#  9   Site                    168510 non-null  object
#  10  Site Id                 171666 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 14.5+ MB

# %%
# UNDERSTANDING THE DATASET
dfimt
# Out:
#                Start Date Com Network Element Id  Service Impact  \
# 0     2022-02-05 19:13:51        CNE000030330632               0
# 1     2022-02-06 11:04:11        CNE000030330876               0
# 2     2022-03-17 03:17:27        CNE000030289562               0
# 3     2022-03-17 03:17:27        CNE000030382953               0
# 4     2022-03-22 08:40:56        CNE000030272112               0
# ...                   ...                    ...             ...
# 23602                 NaT        CNE000030586045               0
# 23603                 NaT        CNE000030586662               0
# 23604                 NaT        CNE000030595668               0
# 23605                 NaT        CNE000030607594               0
# 23606                 NaT        CNE000030609692               0
#
#        Network Impact  Duration Severity                        Site  \
# 0                 2.0       NaN    Minor           LOWER SOUTH RIVER
# ...

# %%
# UNDERSTANDING THE DATASET
dfnct
# Out:
#        Com Network Element Id  Duration                  Element  \
# 0             CNE000030216175       NaN                  Comcast
# 1             CNE000030216176       NaN                  Comcast
# 2             CNE000030216180       NaN                  Comcast
# 3             CNE000030216218       NaN                    V14DX
# 4             CNE000030216219       NaN                    V92DX
# ...                       ...       ...                      ...
# 172353        CNE000030637705       NaN  RCBIN DISASTER RECOVERY
# 172354        CNE000030638427       NaN    DWDM:7500:QUEBEC DWDM
# 172355        CNE000030638450       NaN            TLAN-W4483-01
# 172356        CNE000030638773       NaN                 10476575
# 172357        CNE000030638775       NaN                 10476576
#
#         Element Type  Network Impact        Region  Service Impact  \
# 0        Application               0  NATIONAL USA             0.0
# ...

# %%
#Dropping the columns I had justified dropping
dfimt = dfimt.drop(["Duration"], axis = 1)
dfimt.head(1)
# Out:
#            Start Date Com Network Element Id  Service Impact  Network Impact  \
# 0 2022-02-05 19:13:51        CNE000030330632               0             2.0
#
#   Severity               Site Site Id Element Element Type Element Sub Type  \
# 0    Minor  LOWER SOUTH RIVER   A0254    ASFV          850              NaN
#
#   Region Service Impacted            End Date  \
# 0    ATL         GSM\GPRS 2022-02-11 15:34:51
#
#    Days Between Networkelement Start and End  Duration of Networkelement
# 0                                   5.847917  5 days, 20 Hrs, 21 Minutes

# %%
# MAPPING 

df= dfimt.join(dfnct.set_index('Element'), on='Element', how='left', lsuffix='_left', rsuffix='_right')
df
train=df

# %% [raw]
# # EDA USING SWEETVIZ PACKAGE
# #analyzing the dataset
# eda_report = sv.analyze(train)
# #display the report
# eda_report.show_html('eda.html')

# %% [raw]
# # EDA USING PANDAS PROFILING
# pandas_profiling.ProfileReport(df)

# %%
data= df

# %% [markdown]
# ### 2.3. Find the top 10 records

# %%
#getting number of rows(obs)
data.shape[0]
# Out:
# 66124

# %%
#getting number of collumns
data.shape[1]
# Out:
# 25

# %%
#df2=df #copy by refrences
# getting copy of data ( copy by value)
#method1:
data_orginal=data.copy()
#method2:
data_orginal2=data[:]

# %%
data=data_orginal.copy()

# %%
data.head(2)
# Out:
#            Start Date Com Network Element Id_left  Service Impact_left  \
# 0 2022-02-05 19:13:51             CNE000030330632                    0
# 1 2022-02-06 11:04:11             CNE000030330876                    0
#
#    Network Impact_left Severity_left          Site_left Site Id_left Element  \
# 0                  2.0         Minor  LOWER SOUTH RIVER        A0254    ASFV
# 1                  2.0         Minor   CHRISTMAS ISLAND        A0170    ASDE
#
#   Element Type_left Element Sub Type  ... Com Network Element Id_right  \
# 0               850              NaN  ...                          NaN
# 1               850              NaN  ...                          NaN
#
#   Duration Element Type_right  Network Impact_right Region_right  \
# 0      NaN                NaN                   NaN          NaN
# 1      NaN                NaN                   NaN          NaN
#
#   Service Impact_right  Service Impacted_right Severity_right  Site_right  \
# ...

# %%
data.tail(2)
# Out:
#       Start Date Com Network Element Id_left  Service Impact_left  \
# 23605        NaT             CNE000030607594                    0
# 23606        NaT             CNE000030609692                    0
#
#        Network Impact_left Severity_left Site_left Site Id_left Element  \
# 23605                  0.0           NaN       NaN          ---  T42KU2
# 23606                  0.0           NaN  NATIONAL     NATIONAL     NRM
#
#       Element Type_left Element Sub Type  ... Com Network Element Id_right  \
# 23605               ---              NaN  ...                          NaN
# 23606   OSS Application              NaN  ...              CNE000030485852
#
#       Duration Element Type_right  Network Impact_right Region_right  \
# 23605      NaN                NaN                   NaN          NaN
# 23606      NaN    OSS Application                   0.0     NATIONAL
#
#       Service Impact_right  Service Impacted_right Severity_right  Site_right  \
# ...

# %% [markdown]
# ### 2.4. Describe Dataset

# %%
data.describe()
# Out:
#        Service Impact_left  Network Impact_left  \
# count              66124.0         36462.000000
# mean                   0.0             1.512424
# std                    0.0             1.104206
# min                    0.0             0.000000
# 25%                    0.0             0.000000
# 50%                    0.0             2.000000
# 75%                    0.0             2.000000
# max                    0.0             3.000000
#
#        Days Between Networkelement Start and End     Duration  \
# count                               65921.000000  3459.000000
# mean                                    1.337217   122.025730
# std                                     2.434285    81.274145
# min                                     0.000000     6.000000
# 25%                                     0.048773    60.000000
# 50%                                     0.253993   120.000000
# 75%                                     1.309734   180.000000
# ...

# %% [raw]
# from pandas_profiling import ProfileReport

# %% [markdown]
# pandas_profiling.ProfileReport(data)

# %% [markdown]
# =======================================================================================================================
#
# # ---------------------------------------------  PART ONE   ----------------------------------------------
#
# ========================================================================================================================

# %% [markdown]
# # 3. Data Preprocessing
#
# ###############################################################################################################################

# %% [markdown]
# ## ''''''''''''''''''''''''''''''''''''''''''''''''' Data Exploration Analyasis Step One '''''''''''''''''''''''''''''''''''''''''''''''''''

# %% [raw]
# 1. Find Missing Values
# 2. Find Outliers
# 3. Transform Variables
# 4. Create Variables

# %% [markdown]
# ## ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''

# %% [markdown]
# ## 4. Data Exploration Analyasis Step " ONE"
#
# ###############################################################################################################################

# %% [markdown]
# ### 4.1. Handling Duplicate Data

# %% [markdown]
# #### 4.1.1. Handling Duplicate Observation

# %%
data.shape
# Out:
# (66124, 25)

# %%
data=data.iloc[:66124, :]
data.shape
# Out:
# (66124, 25)

# %% [raw]
# pd.set_option('max_columns', 50)
# data.head(5)

# %%
data=data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66124 entries, 0 to 23606
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Start Date                                 65921 non-null  datetime64[ns]
#  1   Com Network Element Id_left                66124 non-null  object
#  2   Service Impact_left                        66124 non-null  int64
#  3   Network Impact_left                        36462 non-null  float64
#  4   Severity_left                              65914 non-null  object
#  5   Site_left                                  59688 non-null  object
#  6   Site Id_left                               66114 non-null  object
#  7   Element                                    65284 non-null  object
#  8   Element Type_left                          65211 non-null  object
#  9   Element Sub Type                           55386 non-null  object
# ...

# %%
#making a copy of data before preprocessing
data_raw=data.copy()

# %% [raw]
# # EDA USING SWEETVIZ PACKAGE
# #analyzing the dataset
# eda_report = sv.analyze(data)
# #display the report
# eda_report.show_html('eda.html')

# %% [raw]
# pandas_profiling.ProfileReport(data)

# %% [markdown]
# ### 4.2. Handling Missing Values

# %% [markdown]
# #### 4.2.1. Sorting Data by Date

# %% [markdown]
# ###### --Sort by date help us to filling missing value reasnable

# %%
df.sort_values(by="Start Date" , ascending=True)
# Out:
#                Start Date Com Network Element Id_left  Service Impact_left  \
# 0     2022-02-05 19:13:51             CNE000030330632                    0
# 1     2022-02-06 11:04:11             CNE000030330876                    0
# 2     2022-03-17 03:17:27             CNE000030289562                    0
# 3     2022-03-17 03:17:27             CNE000030382953                    0
# 4     2022-03-22 08:40:56             CNE000030272112                    0
# ...                   ...                         ...                  ...
# 23602                 NaT             CNE000030586045                    0
# 23603                 NaT             CNE000030586662                    0
# 23604                 NaT             CNE000030595668                    0
# 23605                 NaT             CNE000030607594                    0
# 23606                 NaT             CNE000030609692                    0
#
# ...

# %% [markdown]
# #### 4.2.2.  Finding the Missing values

# %%
#calculatin no. of missing values for each column and it's percentage
def percentage_of_miss():
  data1=data[data.columns[data.isnull().sum()>=1]] # I did slicing by condition( I get s subset of dataframe that contains columns that have atleast one missing values) )
  total_miss = data1.isnull().sum().sort_values(ascending=False)
  percent_miss = ((data1.isnull().sum()/data1.isnull().count())*100).sort_values(ascending=False) #df1.isnull().sum() returns only number of missing values,df1.isnull().count() returns whole number of observations (True=1 for null and False=0 for not missing ) 
  missing_data = pd.concat([total_miss, percent_miss], axis=1, keys=['Number of Missing', 'Percentage'])
  return(missing_data)

# %%
percentage_of_miss()
# Out:
#                                            Number of Missing  Percentage
# Duration                                               62665   94.768919
# Network Impact_left                                    29662   44.858145
# Service Impacted_right                                 27314   41.307241
# Service Impacted_left                                  21707   32.827718
# Service Impact_right                                   17834   26.970540
# Region_right                                           17435   26.367128
# Site_right                                             17350   26.238582
# Severity_right                                         17147   25.931583
# Element Type_right                                     16906   25.567116
# Site Id_right                                          16824   25.443107
# Com Network Element Id_right                           16799   25.405299
# Network Impact_right                                   16799   25.405299
# ...

# %% [markdown]
# #### 4.2.3. Drop columns that have 80% or more missing values

# %%
df = data.dropna(axis=1, thresh=13224)

# %%
df['ComNetworkElementId_left_F'] = df['Com Network Element Id_left'].str[3:]
df['ComNetworkElementId_right_F'] = df['Com Network Element Id_right'].str[3:]
print(df['ComNetworkElementId_left_F']) 
print(df['ComNetworkElementId_right_F'])
# Out:
# 0        000030330632
# 1        000030330876
# 2        000030289562
# 3        000030382953
# 4        000030272112
#              ...
# 23602    000030586045
# 23603    000030586662
# 23604    000030595668
# 23605    000030607594
# 23606    000030609692
# Name: ComNetworkElementId_left_F, Length: 66124, dtype: object
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 23602             NaN
# 23603             NaN
# 23604             NaN
# 23605             NaN
# 23606    000030485852
# Name: ComNetworkElementId_right_F, Length: 66124, dtype: object

# %% [markdown]
# ### 4.3. Filling Missing Values

# %% [markdown]
# #### 4.3.1. Filling Missing Values by "unkown" or "zero"

# %%
df['ComNetworkElementId_left_F'] = df['ComNetworkElementId_left_F'].fillna(999, inplace=True) 
df['ComNetworkElementId_left_F'] = df['ComNetworkElementId_left_F'].fillna(999, inplace=True)

# %%
def replace_missing_value(df, number_features):

    imputer = Imputer(strategy="median")
    df_num = df[number_features]
    imputer.fit(df_num)
    X = imputer.transform(df_num)
    res_def = pd.DataFrame(X, columns=df_num.columns)
    return res_def

# %%
number_features = ['ComNetworkElementId_left_F', 'ComNetworkElementId_left_F','Start Date',
                   'End Date','Days Between Networkelement Start and End','Duration of Networkelement']

# %% [raw]
# df['Start Date'] = df['Start Date'].fillna(9999, inplace=True)
# df['End Date'] = df['End Date'].fillna(9999, inplace=True)
# df['Days Between Networkelement Start and End'] = df['Days Between Networkelement Start and End'].fillna(9999, inplace=True)
# df['Duration of Networkelement'] = df['Duration of Networkelement'].fillna(9999, inplace=True)

# %%
# string to int
df['ComNetworkElementId_left_F'] = df['ComNetworkElementId_left_F'].astype('float64')
df['ComNetworkElementId_right_F'] = df['ComNetworkElementId_right_F'].astype('float64')
df.dtypes
# Out:
# Start Date                                   datetime64[ns]
# Com Network Element Id_left                          object
# Service Impact_left                                   int64
# Network Impact_left                                 float64
# Severity_left                                        object
# Site_left                                            object
# Site Id_left                                         object
# Element                                              object
# Element Type_left                                    object
# Element Sub Type                                     object
# Region_left                                          object
# Service Impacted_left                                object
# End Date                                     datetime64[ns]
# Days Between Networkelement Start and End           float64
# Duration of Networkelement                           object
# Com Network Element Id_right                         object
# ...

# %% [raw]
# Columns=['Start Date','Com Network Element Id_left',"Service Impact_left",'Network Impact_left','Severity_left','Site_left','Site Id_left','Element','Element Type_left',
#          'Element Sub Type','Region_left','Service Impacted_left','End Date','Days Between Networkelement Start and End',
#           'Duration of Networkelement','Com Network Element Id_right','Element Type_right','Network Impact_right',
#          'Region_right','Service Impact_right','Service Impacted_right','Severity_right','Site_right','Site Id_right']
#
#
# #1. Function to impute null value with new category
# #Call function to create new category for variables
#
# def impute_nan_create_category(df,Columns):
#      df[Columns] = df[Columns].fillna("Unkown")
#
# print("Data:",df[Columns])

# %%
df['Com Network Element Id_left'] = df['Com Network Element Id_left'].fillna("Unknown") 
df['Network Impact_left'] = df['Network Impact_left'].fillna("Unknown")
df['Severity_left'] = df['Severity_left'].fillna("Unknown") 
df['Site_left'] = df['Site_left'].fillna("Unknown") 
df['Site Id_left'] = df['Site Id_left'].fillna("Unknown") 
df['Element'] = df['Element'].fillna("Unknown") 
df['Element Type_left'] = df['Element Type_left'].fillna("Unknown") 
#df['Target Time To Restore'] = df['Target Time To Restore'].fillna("Unknown") 
df['Element Sub Type'] = df['Element Sub Type'].fillna("Unknown") 
df['Region_left'] = df['Region_left'].fillna("Unknown") 
df['Service Impacted_left'] = df['Service Impacted_left'].fillna("Unknown") 
df['Com Network Element Id_right'] = df['Com Network Element Id_right'].fillna("Unknown") 
df['Element Type_right'] = df['Element Type_right'].fillna("Unknown") 
df['Network Impact_right'] = df['Network Impact_right'].fillna("Unknown") 
df['Region_right'] = df['Region_right'].fillna("Unknown")
df['Service Impact_right'] = df['Service Impact_right'].fillna("Unknown") 
df['Service Impacted_right'] = df['Service Impacted_right'].fillna("Unknown") 
df['Severity_right'] = df['Severity_right'].fillna("Unknown") 
df['Site_right'] = df['Site_right'].fillna("Unknown") 
df['Site Id_right'] = df['Site Id_right'].fillna("Unknown")

# %%
# REVIEWING MISSING VALUES IN CORE DATASET - IMT
df.apply(lambda X:sum(X.isnull()))
# Out:
# Start Date                                     203
# Com Network Element Id_left                      0
# Service Impact_left                              0
# Network Impact_left                              0
# Severity_left                                    0
# Site_left                                        0
# Site Id_left                                     0
# Element                                          0
# Element Type_left                                0
# Element Sub Type                                 0
# Region_left                                      0
# Service Impacted_left                            0
# End Date                                      7158
# Days Between Networkelement Start and End      203
# Duration of Networkelement                     203
# Com Network Element Id_right                     0
# Element Type_right                               0
# Network Impact_right                             0
# ...

# %%
#making a copy of filtered data
df_copy=df.copy()

# %%
df['Com Network Element Id_left']=df['Com Network Element Id_left'].astype("category").cat.codes
df['Service Impact_left']=df['Service Impact_left'].astype("category").cat.codes
df['Network Impact_left']=df['Network Impact_left'].astype("category").cat.codes
df['Severity_left']=df['Severity_left'].astype("category").cat.codes
df['Site_left']=df['Site_left'].astype("category").cat.codes
df['Site Id_left']=df['Site Id_left'].astype("category").cat.codes
df['Element']=df['Element'].astype("category").cat.codes
df['Element Type_left']=df['Element Type_left'].astype("category").cat.codes
df['Element Sub Type']=df['Element Sub Type'].astype("category").cat.codes
df['Region_left']=df['Region_left'].astype("category").cat.codes
df['Service Impacted_left']=df['Service Impacted_left'].astype("category").cat.codes
#df['End Date']=df['End Date'].astype("category").cat.codes   
#df['Days Between Networkelement Start and End']=df['Days Between Networkelement Start and End'].astype("category").cat.codes 
#df['Duration of Networkelement']=df['Duration of Networkelement'].astype("category").cat.codes 
df['Com Network Element Id_right']=df['Com Network Element Id_right'].astype("category").cat.codes 
df['Element Type_right']=df['Element Type_right'].astype("category").cat.codes 
df['Network Impact_right']=df['Network Impact_right'].astype("category").cat.codes 
df['Region_right']=df['Region_right'].astype("category").cat.codes
df['Service Impact_right']=df['Service Impact_right'].astype("category").cat.codes 
df['Service Impacted_right']=df['Service Impacted_right'].astype("category").cat.codes 
df['Severity_right']=df['Severity_right'].astype("category").cat.codes 
df['Site_right']=df['Site_right'].astype("category").cat.codes 
df['Site Id_right']=df['Site Id_right'].astype("category").cat.codes

# %%
corr = df.corr()
corr
# Out:
#                                            Com Network Element Id_left  \
# Com Network Element Id_left                                   1.000000
# Service Impact_left                                                NaN
# Network Impact_left                                          -0.015878
# Severity_left                                                -0.015233
# Site_left                                                    -0.025465
# Site Id_left                                                  0.005584
# Element                                                       0.043426
# Element Type_left                                             0.015842
# Element Sub Type                                             -0.014855
# Region_left                                                   0.042305
# Service Impacted_left                                         0.038145
# Days Between Networkelement Start and End                    -0.085775
# ...

# %%
corr_matrix=df.corr()
corr_matrix["ComNetworkElementId_right_F"].sort_values(ascending=False)
# Out:
# ComNetworkElementId_right_F                  1.000000
# Com Network Element Id_right                 0.998898
# Site Id_right                                0.141570
# Site Id_left                                 0.106626
# Region_left                                  0.100179
# Network Impact_left                          0.094518
# Region_right                                 0.087917
# Site_left                                    0.078405
# Site_right                                   0.065284
# Severity_right                               0.038669
# Element Type_left                            0.035541
# Element Type_right                           0.017360
# Element Sub Type                             0.016490
# Com Network Element Id_left                 -0.007603
# Days Between Networkelement Start and End   -0.010586
# Severity_left                               -0.035205
# Element                                     -0.043595
# ...

# %%
plt.figure(figsize=(20,16))
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
                 linewidths=0.2, cmap="YlGnBu",annot=True)
plt.title("Correlation between variables")
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %%
df = df.sample(frac=1, random_state=0)

# %%
X=df.drop('ComNetworkElementId_right_F', axis=1)
y=df['ComNetworkElementId_right_F'].values

# %% [raw]
# vars=['Status','State','Recovery Prime', 'Automation Name (Bot)','Automation Type','Automation Framework','Rule Name','Create Date','Imt Id','Responsibility Department','Submitter','Resolution','Workflow State','Responsibility','Automation Status','Team Name'])

# %% [raw]
# # Pairplot of all the numeric variables
# # Data Visualisation
# #import matplotlib.pyplot as plt
# #import seaborn as sns
# #%matplotlib inline
#
# #import libraries for visualization
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.style.use('ggplot')
#
# sns.pairplot(df, vars=['Status','State','Recovery Prime', 'Automation Name (Bot)','Automation Type','Automation Framework','Rule Name','Create Date','Imt Id','Responsibility Department','Submitter','Resolution','Workflow State','Responsibility','Automation Status','Team Name'])
# plt.show()

# %% [markdown]
# #### 4.3.2. Filling Missing Values by Forward Fill through Visualization

# %% [raw]
# # code here
# fig, ax = plt.subplots(figsize=(12,8))
# ax.scatter(df["Humidity"], df["Dewpoint"], c=df["Temperature"], s=df["Windspeed"]*20, cmap="coolwarm")
# ax.set_xlabel("Humidity Average(%)")
# ax.set_ylabel("Dew Point Average(F)")
# ax.set_title("Weather")
# plt.show()

# %% [raw]
# df2 = df.sample(1000).fillna(method="ffill")
#
# fig, ax = plt.subplots(figsize=(12,8))
# ax.scatter(df2["Humidity"], df2["Dewpoint"], c=df2["Temperature"], s=df2["Windspeed"]*20, cmap="coolwarm")
# ax.set_xlabel("Humidity Average(%)")
# ax.set_ylabel("Dew Point Average(F)")
# ax.set_title("Weather")
# plt.show()

# %% [raw]
# -- We know that the average air temperature is affected by the dewpoint temperature. The higher the dew point temperature, the higher the air temperature and vice versa.
#
# -- We can also know that the wind speed is affected by the dewpoint temperature. The lower the dew point temperature, the greater the average wind speed (inversely proportional) and vice versa, which is indicated by the number of large points at the bottom.
#
# -- with the handling of missing values, NaN data is also visualized. This is indicated by the data that does not match the group (solid red color at the bottom of the blue). This shows that there is temperature data filled by the upper value.

# %% [raw]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## '''''''''''''''''''''''''''''''''''''''''''''''' Data Exploration Analyasis Step TWO"'''''''''''''''''''''''''''''''''''''''''''''''''

# %% [raw]
# 1. Identify Variables
# 2. Univariate Analysis
# 3. Bivariate Analysis

# %% [markdown]
# ## '''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''

# %% [markdown]
# ## 5. Data Exploration Analyasis Step TWO
#
# ###############################################################################################################################

# %% [markdown]
# ### 5.1. Identify variables

# %% [markdown]
# #### 5.1.1.  Find the Unique values

# %%
df.apply(lambda X:len(X.unique()))
# Out:
# Start Date                                   14673
# Com Network Element Id_left                  23607
# Service Impact_left                              1
# Network Impact_left                              4
# Severity_left                                    4
# Site_left                                     2903
# Site Id_left                                  2997
# Element                                      12659
# Element Type_left                              329
# Element Sub Type                               215
# Region_left                                     12
# Service Impacted_left                           21
# End Date                                     13880
# Days Between Networkelement Start and End    14172
# Duration of Networkelement                    5034
# Com Network Element Id_right                 17260
# Element Type_right                             129
# Network Impact_right                             2
# ...

# %% [markdown]
# #### 5.1.2. Finding Information of the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66124 entries, 6004 to 15946
# Data columns (total 26 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Start Date                                 65921 non-null  datetime64[ns]
#  1   Com Network Element Id_left                66124 non-null  int16
#  2   Service Impact_left                        66124 non-null  int8
#  3   Network Impact_left                        66124 non-null  int8
#  4   Severity_left                              66124 non-null  int8
#  5   Site_left                                  66124 non-null  int16
#  6   Site Id_left                               66124 non-null  int16
#  7   Element                                    66124 non-null  int16
#  8   Element Type_left                          66124 non-null  int16
#  9   Element Sub Type                           66124 non-null  int16
# ...

# %% [raw]
# -- All of features have a same data type, therefore we do not need to convert all of them as a same data type (float64).
#
# -- "sorce" is a object data type, but we need "source" to split it after cleaning the dataset.

# %% [raw]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5.2. Univarate Analysis

# %% [raw]
# data type:Numeric and categoric
# Note: Numeric variable can be continouse or dicrete , we can treat dicrete varaible like ordinal variable ( categorical) specially if it has limitted options ( like number of childeren in family : it is numeric( disrete), so you can apply mean ,standard deviation and so on but you can treat it like categorical variable and for example draw bar chart for it or ...)
#
# For categorical columns: for summarization:freq, Mode, leveles
#                          for visulaization:Bar chart or Pie chart
#
# For numerical columns  : for summarization:Central tedency(mean, median, mode,...) and five_number_summary(min,Q1,median(Q2),Q3,Max), stdandard deviation ,...
#                          for visulaization:Histogram and dencity, Box plot,...

# %% [markdown]
# #### 5.2.1. Getting the summary for Numeric Columns of Dataset

# %%
# Getting the summary of Data
pd.options.display.float_format = "{:.2f}".format
df.describe().T# for numeric columns
# Out:
#                                              count        mean       std  \
# Com Network Element Id_left               66124.00    12097.20   6913.22
# Service Impact_left                       66124.00        0.00      0.00
# Network Impact_left                       66124.00        1.81      1.19
# Severity_left                             66124.00        0.73      0.47
# Site_left                                 66124.00     1741.40    848.90
# Site Id_left                              66124.00     1456.89    914.23
# Element                                   66124.00     7983.51   3408.87
# Element Type_left                         66124.00      130.43    108.66
# Element Sub Type                          66124.00      118.14     69.64
# Region_left                               66124.00        5.45      3.39
# Service Impacted_left                     66124.00       11.63      6.19
# Days Between Networkelement Start and End 65921.00        1.34      2.43
# ...

# %% [markdown]
# #### 5.2.2. Getting the summary for Discrete Vriables of Dataset

# %% [raw]
# --The "year" and "month" are the numerical data. But they are considered as data DISCRETE, so they are treated as categorical data.

# %% [markdown]
# #### 5.2.2.1. Convert Date to year, month, and day

# %% [raw]
# # convert column to datetime pandas
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['End Date'] = pd.to_datetime(df['End Date'])
# df['Days Between Networkelement Start and End'] = pd.to_datetime(df['Days Between Networkelement Start and End'])
# df['Duration of Networkelement'] = pd.to_datetime(df['Duration of Networkelement'])
# df.info()

# %% [raw]
# df['Start Date']= pd.to_datetime(df['Start Date'].str.strip(), dayfirst=True)

# %% [raw]
# import io
# # convert column to datetime pandas
# #df['Start Date'] = pd.to_datetime(df['Start Date'])
# dfStartDate=pd.read_csv(io.StringIO('Start Date'), sep=";", parse_dates=False)
# #df['End Date'] = pd.to_datetime(df['End Date'])
# #df['Days Between Networkelement Start and End'] = pd.to_datetime(df['Days Between Networkelement Start and End'])
# #df['Duration of Networkelement'] = pd.to_datetime(df['Duration of Networkelement'])
# df.info()

# %% [raw]
# # Extract year, month, and day. Assign all these date component to new column.
# df['year_SD'] = df['Start Date'].dt.year
# df['month_SD'] = df['Start Date'].dt.month
# df['day_SD'] = df['Start Date'].dt.day
#
# df['year_ED'] = df['End Date'].dt.year
# df['month_ED'] = df['End Date'].dt.month
# df['day_ED'] = df['End Date'].dt.day
#
# df['year_BSED'] = df['Days Between Networkelement Start and End'].dt.year
# df['month_BSED'] = df['Days Between Networkelement Start and End'].dt.month
# df['day_BSED'] = df['Days Between Networkelement Start and End'].dt.day
#
# df['year_DN'] = df['Duration of Networkelement'].dt.year
# df['month_DN'] = df['Duration of Networkelement'].dt.month
# df['day_DN'] = df['Duration of Networkelement'].dt.day
#
# # drop a column based on name
# df = df.drop('Start Date',axis=1)
# df = df.drop('End Date',axis=1)
# df = df.drop('Days Between Networkelement Start and End',axis=1)
# df = df.drop('Duration of Networkelement',axis=1)
#
# df.head()

# %% [raw]
# --The "year" and "month" are Numerical Data Type and Discrite Varible Type. So, they are dealed as Categorical variables.

# %% [raw]
# Month = df['month_SD'].value_counts()
# Month

# %% [raw]
# Year = df['year_SD'].value_counts()
# Year

# %% [markdown]
# ### 5.3. Data Visualization for Univarate Analysis

# %% [raw]
# *************************************........ Going through columns one by one........*****************************************

# %% [markdown]
# #### 5.3.1. Histogram for Numerical variables

# %%
plt.figure(figsize=(5,5))
df['ComNetworkElementId_right_F'].hist(bins=5)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df['ComNetworkElementId_left_F'].hist(bins=5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 5.3.2. Barchart for Categorical or "Discrete"variables

# %% [raw]
# #countplot
# plt.figure(figsize=(5,5))
# sns.countplot(df['Com Network Element Id_left'])
# plt.title("Com Network Element Id_left", y=1, fontdict={"fontsize": 20})

# %%
#countplot
plt.figure(figsize=(5,5))
sns.countplot(df['Service Impact_left'])
plt.title("Service Impact_left", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Service Impact_left')

# %%
#countplot
plt.figure(figsize=(5,5))
sns.countplot(df['Network Impact_left'])
plt.title("Network Impact_left", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Network Impact_left')

# %%
#countplot
plt.figure(figsize=(25,5))
sns.countplot(df['Site_left'])
plt.title("Site_left", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Site_left')

# %%
#countplot
plt.figure(figsize=(5,5))
sns.countplot(df['Site Id_left'])
plt.title("Site Id_left", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Site Id_left')

# %%
#countplot
plt.figure(figsize=(5,5))
sns.countplot(df['Element'])
plt.title("Element", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Element')

# %%
#countplot
plt.figure(figsize=(25,5))
sns.countplot(df['Element Type_left'])
plt.title("Element Type_left", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Element Type_left')

# %%
#countplot
plt.figure(figsize=(25,5))
sns.countplot(df['Element Sub Type'])
plt.title("Element Sub Type", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Element Sub Type')

# %%
#countplot
plt.figure(figsize=(5,5))
sns.countplot(df['Region_left'])
plt.title("Region_left", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Region_left')

# %%
#countplot
plt.figure(figsize=(25,5))
sns.countplot(df['Service Impacted_left'])
plt.title("Service Impacted_left", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Service Impacted_left')

# %%
#countplot
plt.figure(figsize=(5,5))
sns.countplot(df['Element Type_right'])
plt.title("Element Type_right", y=1, fontdict={"fontsize": 20})
# Out:
# Text(0.5, 1, 'Element Type_right')

# %% [raw]
# #countplot
# plt.figure(figsize=(25,5))
# sns.countplot(df['Com Network Element Id_right'])
# plt.title("Com Network Element Id_right", y=1, fontdict={"fontsize": 20})

# %% [markdown]
# #### 5.3.3. Box plot for Outliers Detection

# %% [raw]
# plt.figure(figsize=(5,5))
# df.boxplot(column = 'Start Date')

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Com Network Element Id_left')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Service Impact_left')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Network Impact_left')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Severity_left')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Site_left')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Element')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Element Type_left')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Element Sub Type')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Region_left')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Element Type_right')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Region_right')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Service Impact_right')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,5))
df.boxplot(column = 'Site_right')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5.3.4. Visulaization Histogram, Dencity, Box plot and Frequency in ONE GRAPH

# %% [markdown]
# #### 5.3.4.1. Density Distribution

# %% [raw]
# #densityPlot
# data.plot(kind = 'density', subplots= True, layout = (3,4), sharex =False, figsize = (15, 8));

# %% [markdown]
# #### 5.3.4.2. Frequency Distribution

# %% [raw]
# plt.rcParams['figure.figsize']=15,5
#
#
# plt.subplot(121)
# sns.countplot(df['ComNetworkElementId_right_F'],
#              order=df['ComNetworkElementId_right_F'].value_counts().head(10).index,
#              palette='plasma')
# plt.xticks(rotation=90)
# plt.title('Most of the ComNetworkElementId_right_F')
#
#
# plt.subplot(122)
# sns.countplot(df['ComNetworkElementId_left_F'],
#              order=df['ComNetworkElementId_left_F'].value_counts().head(10).index,
#              palette='plasma')
# plt.xticks(rotation=90)
# plt.title('Most of the ComNetworkElementId_left_F')
#
#
# plt.show()

# %% [markdown]
# #### 5.3.4.3. Outliers Detection

# %% [raw]
# df_Out = df.drop(columns = ['year','day','month'])

# %%
# Finding outliers by using BOXPLOT
sns.set_theme(style="ticks", palette="pastel")
plt.figure(figsize=(40,15))
sns.boxplot(data=df)
sns.despine()
#plt.xticks(rotation=90)

# %% [markdown]
# #### 5.3.4.4. Histogram Plot¶

# %% [raw]
# df.hist(figsize=[15,8])
# plt.hist(df['year','day','month','MinTemperature','MaxTemperature'].dropna().values, bins=bins)
# plt.show()

# %% [raw]
# bins = 25
#
# plt.figure(figsize=(10,5))
#
# df['Root Cause'].plot.hist(bins, histtype='bar', label='RootLowF')
# df['MaxRootCause'].plot.hist(bins, histtype='bar', label='RootAvgF')
# df['MinRootCause'].plot.hist(bins, histtype='bar', label='RootHighF')
#
# plt.title('Distribution of RootCause')
# plt.xlabel('RootCause')
# plt.legend()
# plt.show()

# %% [markdown]
# ### 5.3. Bivariate Analysis

# %% [raw]
# Bivariate Analysis:
#
#   Continouse Vs. Continouse   : For Visulaization scatter plot,...
#                                 For test of independence: pearson correlation or spearman or  ...
#
#   Categorical Vs. Categorical : For summaraization: contingency table (two-way table)
#                                 For visualization :stacked bar chart,Grouped bar chart,...
#                                 For test of independence:chi-square test
#   Continouse Vs. Categorical  : For summaraization:gropup by categorical column an aggragte for numerical column
#                                 For visualization: Grouped box plot,...
#                                 For test of independence :1) if categorical column has only two levels :t-test
#                                                           2) if categorical column has more than two levels: ANOVA

# %% [markdown]
# ### 5.3.1. Summaraization  Continouse Vs. Categorical

# %% [raw]
# # Shall we combine each year together
#
# df.pivot_table(values='Element',index='Strat date')

# %% [markdown]
# In pandas, the groupby function can be combined with one or more aggregation functions to quickly and easily summarize data.

# %% [raw]
# agg_func_math = {
#     'Element':
#     ['count','mean', 'median', 'min','max','std', 'var']
# }
# df.groupby(['year']).agg(agg_func_math).round(2)

# %% [raw]
# df.pivot_table(values='Element',index='year')

# %% [raw]
# Here we are scattering the daily low temperatures vs the high temperatures. We see a positive linear relationship, as expected, since the daily low temperature should not be drastically lower than a daily high temperature.

# %% [markdown]
# ### 5.3.2. Visualization Continouse Vs. Continouse

# %% [raw]
# How is Temperature and Average barometer related? Does increased Temperature mean more Average barometer?
# How is Temperature and humidity related? Does increased tempature mean more humidity? and so on...

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['ComNetworkElementId_right_F'], df['ComNetworkElementId_left_F'], alpha=.1)

plt.title('ComNetworkElementId_right_F vs ComNetworkElementId_left_F')
plt.xlabel('ComNetworkElementId_right_F')
plt.ylabel('Average ComNetworkElementId_right_F')
plt.show()

# %% [raw]
# plt.figure(figsize=(5,5))
# sns.scatterplot(x="Temperature", y="MinTemperature",data=df)
#
# plt.title('Dewpoint vs Average barometer')
# plt.xlabel('Dewpoint')
# plt.ylabel('Average barometer')
# plt.show()

# %% [markdown]
# ### 5.4. Univariate and  Bivariate Analysis

# %% [markdown]
# #### 5.4.1Scatter Matrix Plot

# %% [raw]
# sns.pairplot(df)

# %% [raw]
# datay = data.drop(['Root Cause'], axis=1)

# %% [raw]
# plt.rcParams['figure.figsize'] = (10,20) #Set the figure size
# data.plot(subplots = True, title = "Variable Visualization") #Plot all the variables

# %% [markdown]
# ## 6.  Fixing and Handling  Outliers
#
# ###############################################################################################################################

# %%
#lower inner fence: Q1 - 1.5*IQR
#upper inner fence: Q3 + 1.5*IQR
def outlier_analysis(col):
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    UIF=Q3+1.5*(IQR)#UIF=upper inner fence
    LIF=Q1-1.5*(IQR) #LIF=lower inner fence
    df_out =df[(df[col]<LIF) | (df[col]>UIF)] # I created a new data set that has just include potential outliers
    sns.distplot(df_out[col])#Plotting univariate distributions.By default, this will draw a histogram and fit a kernel density estimate (KDE)
   
    return df_out[col] .describe()

# %% [raw]
# --Outlier Treatment
#
# Note: For handling outliers we have several approaches:
#         1. Dropping outliers that it is not good idea if you have same type of outliers in your test data set that you want to            predict for them
#         2.Changing Outliers and bring them to acceptable domain(range) like what I did for credit score
#         3.Using some modeles that they are not sensitive to outliers

# %% [markdown]
# ## 7. Transform Variables
#
# ###############################################################################################################################

# %% [markdown]
# ### 7.1. Finding Skewness and Kurtosis

# %%
from scipy.stats import norm

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Element'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Element', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Element'].skew())
print("Kurtosis: %f" % df['Element'].kurt())
# Out:
# Skewness: -0.644714
# Kurtosis: -0.742327

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Com Network Element Id_left'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Com Network Element Id_left', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Com Network Element Id_left'].skew())
print("Kurtosis: %f" % df['Com Network Element Id_left'].kurt())
# Out:
# Skewness: -0.000669
# Kurtosis: -1.234782

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Site_right'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Site_right', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Site_right'].skew())
print("Kurtosis: %f" % df['Site_right'].kurt())
# Out:
# Skewness: -0.713858
# Kurtosis: -0.707783

# %%
from scipy.stats import norm
plt.figure(figsize=(5,5))
sns.distplot(df['Severity_left'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Severity_left', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Severity_left'].skew())
print("Kurtosis: %f" % df['Severity_left'].kurt())
# Out:
# Skewness: -0.542098
# Kurtosis: 0.580856

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Site_left'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Site_left', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Site_left'].skew())
print("Kurtosis: %f" % df['Site_left'].kurt())
# Out:
# Skewness: -0.385823
# Kurtosis: -0.988807

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Element'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Element', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Element'].skew())
print("Kurtosis: %f" % df['Element'].kurt())
# Out:
# Skewness: -0.644714
# Kurtosis: -0.742327

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Service Impact_right'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Service Impact_right', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Service Impact_right'].skew())
print("Kurtosis: %f" % df['Service Impact_right'].kurt())
# Out:
# Skewness: 0.375089
# Kurtosis: -1.663457

# %%
plt.figure(figsize=(5,5))
sns.distplot(df['Service Impacted_right'], fit= norm)
# Out:
# <AxesSubplot:xlabel='Service Impacted_right', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Service Impacted_right'].skew())
print("Kurtosis: %f" % df['Service Impacted_right'].kurt())
# Out:
# Skewness: -0.550418
# Kurtosis: -1.405180

# %% [raw]
# ['Start Date','Com Network Element Id_left',"Service Impact_left",'Network Impact_left','Severity_left','Site_left','Site Id_left','Element','Element Type_left',
#          'Element Sub Type','Region_left','Service Impacted_left','End Date','Days Between Networkelement Start and End',
#           'Duration of Networkelement','Com Network Element Id_right','Element Type_right','Network Impact_right',
#          'Region_right','Service Impact_right','Service Impacted_right','Severity_right','Site_right','Site Id_right']

# %% [raw]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8. The Null and Alternate Hypotheses
#
# ###############################################################################################################################

# %% [raw]
# Recall that we are interested in knowing if there is a relationship between 'Temperature' and ('Average barometer','Dewpoint', 'Humidity', 'Windspeed', 'month','year'). In order to do so, we would have to use the Chi-squared test. But first, let's state our null hypothesis and the alternative hypothesis.
#
# H0:There is no statistically significant relationship between Temperature and Average barometer.
#
# Ha:There is a statistically significant relationship between Temperature and Average barometer.

# %% [markdown]
# ### 8.1.  Correlation Heatmap¶

# %% [markdown]
# ###### Correlation Concepts, Matrix & Heatmap using Seaborn:
#
#
# Correlation is a term used to represent the statistical measure of linear relationship between two variables. It can also be defined as the measure of dependence between two different variables. If there are multiple variables and the goal is to find correlation between all of these variables and store them using appropriate data structure, the matrix data structure is used. Such matrix is called as correlation matrix.
#
# Dependence between two variables, also termed as correlation, can be measured using the following:
#
# ***Correlation coefficient / Pearson correlation coefficient which measures how the value of two different variables vary with respect to each other.
#
# ***Rank correlation coefficient metric such as Spearman correlation coefficient is used to measure the extent to which one variable increases / decreases as the other variable increases / decreases.

# %%
# Drop Service Impact_left
df= df.drop(['Service Impact_left'], axis=1)

# %%
corr_matrix=df.corr()

# %%
corrs = df.corr()
corrs
# Out:
#                                            Com Network Element Id_left  \
# Com Network Element Id_left                                       1.00
# Network Impact_left                                              -0.02
# Severity_left                                                    -0.02
# Site_left                                                        -0.03
# Site Id_left                                                      0.01
# Element                                                           0.04
# Element Type_left                                                 0.02
# Element Sub Type                                                 -0.01
# Region_left                                                       0.04
# Service Impacted_left                                             0.04
# Days Between Networkelement Start and End                        -0.09
# Com Network Element Id_right                                     -0.03
# ...

# %%
plt.figure(figsize=(20,16))
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
                 linewidths=0.2, cmap="YlGnBu",annot=True)
plt.title("Correlation between variables")
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %% [raw]
# #Correlation Plot for finding the relation between variables
# corr = df.corr()
# plt.figure(figsize=(15,10))
# sns.heatmap(corr, vmin=-1,vmax=1,cmap ="YlGnBu", annot=True,square=True)

# %% [raw]
# Is there any association between home Root Cause and Rule Name?
# and so on....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66124 entries, 6004 to 15946
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Start Date                                 65921 non-null  datetime64[ns]
#  1   Com Network Element Id_left                66124 non-null  int16
#  2   Network Impact_left                        66124 non-null  int8
#  3   Severity_left                              66124 non-null  int8
#  4   Site_left                                  66124 non-null  int16
#  5   Site Id_left                               66124 non-null  int16
#  6   Element                                    66124 non-null  int16
#  7   Element Type_left                          66124 non-null  int16
#  8   Element Sub Type                           66124 non-null  int16
#  9   Region_left                                66124 non-null  int8
# ...

# %% [raw]
# #Analysing the ranges of the various features of the datset
#
# #Showing Important Time in Prediction
# data_one_day = data.loc['2016-09-29':'2016-09-30',:]
#
# plt.figure(figsize = (12,3))
# plt.plot(data_one_day.Radiation, 'o', markerfacecolor = 'w')
#
# #Plotting vertical line at sunrise
# plt.axvline(data_one_day.sunrise_time.iloc[0], label = 'Sunrise time', color = 'blue')
#
# #Plotting vertical line at sunset
# plt.axvline(data_one_day.sunset_time.iloc[0], label = 'Sunset time', color = 'red')
#
# #Adjusting timezone of x-axis
# plt.gca().xaxis_date('HST')
#
# plt.legend()
# plt.show()

# %% [markdown]
# ### 8.2. Chi-squared test of independence

# %% [raw]
# The Chi-square test statistic can be used if the following conditions are satisfied:
#
# 1.N, the total frequency, should be reasonably large, say greater than 50.
#
# 2.The sample observations should be independent. This implies that no individual item should be included twice or more in the sample.
# 3.expected frequencies shouldn't be small. Small is a relative term. Preferably each expected frequencies should be larger than 10 but in any case not less than 5.

# %% [raw]
# ['Start Date','Com Network Element Id_left',"Service Impact_left",'Network Impact_left','Severity_left','Site_left','Site Id_left','Element','Element Type_left',
#          'Element Sub Type','Region_left','Service Impacted_left','End Date','Days Between Networkelement Start and End',
#           'Duration of Networkelement','Com Network Element Id_right','Element Type_right','Network Impact_right',
#          'Region_right','Service Impact_right','Service Impacted_right','Severity_right','Site_right','Site Id_right']

# %% [raw]
# from scipy.stats import chi2_contingency
#
# chi_2, p_val, dof, exp_val = chi2_contingency(pd.crosstab(df['Element'],df['Com Network Element Id_left'],margins = False))# make sure margins = False
#
# print(exp_val)
# print('\nChi-square is : %f'%chi_2, '\n\np_value is : %f'%p_val, '\n\ndegree of freedom is : %i'%dof)
#
# if p_val < 0.05:# consider significan level is 5%
#     print("\nThere is some correlation between the two variables at significance level 0.05")
# else:
#     print("\nThere is no correlation between the two variables")

# %% [raw]
# def chi_square(c1,c2):
#     chi_2, p_val, dof, exp_val = chi2_contingency(pd.crosstab(df[c1],df[c2],margins = False))# make sure margins = False
#
#     print(exp_val)
#     print('\nChi-square is : %f'%chi_2, '\n\np_value is : %f'%p_val, '\n\ndegree of freedom is : %i'%dof)
#
#     if p_val < 0.05:# consider significan level is 5%
#         print("\nThere is some correlation between the two variables at significance level 0.05")
#     else:
#         print("\nThere is no correlation between the two variables")

# %% [raw]
# chi_square("Element",'Com Network Element Id_left')

# %% [raw]
# Bivariate Analysis
#   Continouse Vs. Categorical  : For summaraization:gropup by categorical column an aggragte for numerical column
#                                 For visualization: Grouped box plot or Gouped histogram or grouped density, ...
#                                 For test of independence :1) if categorical column has only two levels :t-test
#                                                           2) if categorical column has more than two levels: ANOVA
#  Here home ownership has 3 leveles so I will run ANOVA

# %% [raw]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9. Feature Engieering
#
# ###############################################################################################################################

# %% [markdown]
# ### 9.1. Frequency of Categories of the Dataset

# %%
#Filter categorical variables 
categorical_columns = [x for x in df.dtypes.index if df.dtypes[x]=='object']
#Exclude ID cols and source:
categorical_columns = [x for x in categorical_columns
                      if x not in ['Date','source']]
#Print frequency of categories:
for col in categorical_columns:
    print('\nFrequency of Categories for variable %s' %col)
    print(df[col].value_counts())
# Out:
# Frequency of Categories for variable Duration of Networkelement
# 0 days, 0 Hrs, 0 Minutes      1786
# 0 days, 0 Hrs, 9 Minutes       736
# 0 days, 0 Hrs, 17 Minutes      676
# 0 days, 0 Hrs, 11 Minutes      638
# 0 days, 9 Hrs, 44 Minutes      608
#                               ...
# 3 days, 22 Hrs, 9 Minutes        1
# 0 days, 20 Hrs, 32 Minutes       1
# 2 days, 6 Hrs, 23 Minutes        1
# 2 days, 15 Hrs, 31 Minutes       1
# 4 days, 4 Hrs, 6 Minutes         1
# Name: Duration of Networkelement, Length: 5033, dtype: int64

# %% [raw]
# df['year'].value_counts()

# %% [raw]
# df['month'].value_counts()

# %% [markdown]
# ### 9.3. Memory reduction

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.
    """
    start_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %% [markdown]
# ### 9.4. Export the data back (Split Dataset)

# %% [raw]
# Convert back Train and Test data sets.
# Useful for multiple iterations of the Feature Engineering steps

# %% [raw]
# train=df[df['source']=='train']
# test=df[df['source']=='test']

# %% [markdown]
# ### 9.3. Choosing Target

# %% [raw]
# *** Target: Average Temperature

# %% [markdown]
# ### 9.4. Drop unnecessary columns

# %%
#Renaming dataset
#df = data

#Splitting dataset into labels and features
X =df.drop(columns = ['ComNetworkElementId_right_F'])
y = df['ComNetworkElementId_right_F']

# %%
X.head(2)
# Out:
#                Start Date  Com Network Element Id_left  Network Impact_left  \
# 6004  2022-03-30 21:49:31                         5880                    2
# 11908 2022-04-03 19:22:22                        11775                    2
#
#        Severity_left  Site_left  Site Id_left  Element  Element Type_left  \
# 6004               0        594          2295    10883                 17
# 11908              0       1493           787     4418                  4
#
#        Element Sub Type  Region_left  ...  Com Network Element Id_right  \
# 6004                 16           10  ...                         16722
# 11908                 4            6  ...                          1320
#
#       Element Type_right  Network Impact_right Region_right  \
# 6004                  11                     0            8
# 11908                  4                     0            5
#
#        Service Impact_right  Service Impacted_right  Severity_right  \
# ...

# %% [raw]
# dates_input = df["Incident Start"].values.astype('datetime64[D]')
# dates_input = df["Incident End"].values.astype('datetime64[D]')
# dates_input = df["Duration of Incident"].values.astype('datetime64[D]')
# dates_input = df["Target Time To Restore"].values.astype('datetime64[D]')

# %%
#X =df.drop(columns = ['Start Date',"Duration of Networkelement","Days Between Networkelement Start and End","End Date"])

# %%
X.head(5)
# Out:
#                Start Date  Com Network Element Id_left  Network Impact_left  \
# 6004  2022-03-30 21:49:31                         5880                    2
# 11908 2022-04-03 19:22:22                        11775                    2
# 6946  2022-03-31 09:37:07                         6719                    2
# 19347 2022-04-07 14:10:09                        18985                    2
# 4510  2022-03-30 04:58:32                         4085                    0
#
#        Severity_left  Site_left  Site Id_left  Element  Element Type_left  \
# 6004               0        594          2295    10883                 17
# 11908              0       1493           787     4418                  4
# 6946               0        743           208     9454                238
# 19347              0       1033          2101     2902                179
# 4510               1       2191          1302     6045                 17
#
# ...

# %%
y
# Out:
# 6004    30597650.00
# 11908   30238013.00
# 6946    30282678.00
# 19347   30547061.00
# 4510    30438322.00
#             ...
# 15331   30537259.00
# 7647            NaN
# 16601   30582135.00
# 15497   30460627.00
# 15946   30471150.00
# Name: ComNetworkElementId_right_F, Length: 66124, dtype: float64

# %% [markdown]
# ### 9.5. Export files as modified versions

# %%
#Export files as modified versions:
df.to_csv("April2022_dataframe_Element.csv",index=False)

# %% [markdown]
# ## 10. Standardize Data
#
# ###############################################################################################################################

# %% [raw]
# - Variables that are measured at different scales do not contribute equally to the model fitting & model learned function and might end up creating a bias. Thus, to deal with this potential problem feature-wise standardized (μ=0, σ=1) is usually used prior to model fitting.
#
# - StandardScaler removes the mean and scales each feature/variable to unit variance. This operation is performed feature-wise in an independent way.
#
# - StandardScaler can be influenced by outliers (if they exist in the dataset) since it involves the estimation of the empirical mean and standard deviation of each feature.

# %% [raw]
# # DATA PREPROCESSING - Scaling Data
#
# #standardizing all the columns
# sc=StandardScaler()
# scaled=sc.fit_transform(X)
#
# #converted to dataframe to work easily on columns
# X_scaled=pd.DataFrame(scaled, columns=X.columns)
# #print(data)

# %% [raw]
# Dataset is well STANDARDISED.

# %% [markdown]
# ========================================================================================================================
#
# # --------------------------------   PART TWO MODEL BUILDING   -------------------------------
#
# ========================================================================================================================

# %% [raw]
# ![image.png](attachment:image.png)

# %% [markdown]
# *******************************************************************************************************************************
# ###############################################################################################################################
#
# # ''''''''''''''''''''''...Data Handling - Predictive / Supervised Learning...''''''''''''''''''''
#
# ###############################################################################################################################
# *******************************************************************************************************************************

# %% [raw]
# from collections import Counter
# def cumulatively_categorise(column,threshold=0.75,return_categories_list=True):
#   #Find the threshold value using the percentage and number of instances in the column
#   threshold_value=int(threshold*len(column))
#   #Initialise an empty list for our new minimised categories
#   categories_list=[]
#   #Initialise a variable to calculate the sum of frequencies
#   s=0
#   #Create a counter dictionary of the form unique_value: frequency
#   counts=Counter(column)
#
#   #Loop through the category name and its corresponding frequency after sorting the categories by descending order of frequency
#   for i,j in counts.most_common():
#     #Add the frequency to the global sum
#     s+=dict(counts)[i]
#     #Append the category name to the list
#     categories_list.append(i)
#     #Check if the global sum has reached the threshold value, if so break the loop
#     if s>=threshold_value:
#       break
#   #Append the category Other to the list
#   categories_list.append('Other')
#
#   #Replace all instances not in our new categories by Other
#   new_column=column.apply(lambda x: x if x in categories_list else 'Other')
#
#   #Return transformed column and unique values if return_categories=True
#   if(return_categories_list):
#     return new_column,categories_list
#   #Return only the transformed column if return_categories=False
#   else:
#     return new_column
#
#
# #Call the function with a default threshold of 75%
# transformed_column,new_category_list=cumulatively_categorise(df['Start Date'],return_categories_list=True)

# %% [raw]
# transformed_column.describe()

# %% [raw]
# #Call the function with a default threshold of 75%
# transformed_column,new_category_list=cumulatively_categorise(df['End Date'],return_categories_list=True)

# %% [raw]
# transformed_column.describe()

# %% [raw]
# #Call the function with a default threshold of 75%
# transformed_column,new_category_list=cumulatively_categorise(df['ComNetworkElementId_left_F'],return_categories_list=True)

# %% [raw]
# transformed_column.describe()

# %% [raw]
# Feature Technicalities:
# PCA Transformation: The description of the data says that all the features went through a PCA transformation (Dimensionality Reduction technique) (Except for time and amount).
# Scaling: Keep in mind that in order to implement a PCA transformation features need to be previously scaled. (In this case, all the V features have been scaled or at least that is what we are assuming the people that develop the dataset did.)

# %%
from sklearn.preprocessing import StandardScaler

# %%
x = StandardScaler().fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [104], in <cell line: 1>()
# ----> 1 x = StandardScaler().fit_transform(X)
#
# File ~\Anaconda3\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:806, in StandardScaler.fit(self, X, y, sample_weight)
#     804 # Reset internal state before fitting
#     805 self._reset()
# ...

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784')

# %%
from sklearn.model_selection import train_test_split
# test_size: what proportion of original data is used for test set
train_img, test_img, train_lbl, test_lbl = train_test_split( mnist.data, mnist.target, test_size=1/7.0, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(train_img)
# Apply transform to both the training set and the test set.
train_img = scaler.transform(train_img)
test_img = scaler.transform(test_img)

# %%
from sklearn.decomposition import PCA
# Make an instance of the Model
pca = PCA(.95)

# %%
pca.fit(train_img)

# %%
train_img = pca.transform(train_img)
test_img = pca.transform(test_img)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# all parameters not specified are set to their defaults
# default solver is incredibly slow which is why it was changed to 'lbfgs'
logisticRegr = LogisticRegression(solver = 'lbfgs')

# %%
logisticRegr.fit(train_img, train_lbl)

# %%
# Predict for One Observation (image)
logisticRegr.predict(test_img[0].reshape(1,-1))

# %%
# Predict for One Observation (image)
logisticRegr.predict(test_img[0:10])

# %%
logisticRegr.score(test_img, test_lbl)

# %%
print(X['DESCR'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DESCR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
